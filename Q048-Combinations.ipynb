# %% [markdown]
# # Q048 - Il risultato della tua attivitá é un'innovazione? Se sí, di che tipo?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q048[SQ001] - Q048[SQ005] - Q048[other]

innovation_columns = ['Q048[SQ001]','Q048[SQ002]','Q048[SQ003]','Q048[SQ004]','Q048[SQ005]']
innovation_options = ['Innovazione di prodotto',
                  'Innovazione di processo (progettazione, produzione, distribuzione)',
                  'Innovazione di sistema-prodotto (prodotto, servizio e processo)',
                  'Innovazione tecnologica',
                  'Innovazione sociale']
innovation = data[innovation_columns]
innovation.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
innovation_other = data['Q048[other]'].str.lower().value_counts()
# Out:
# -c:10: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %%
#places[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(innovation_columns)+1):
    comb = list(itertools.combinations(innovation_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in innovation_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = innovation_columns.index(j) # Get position
            comb_list.append(innovation_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in innovation.index:
    current_bool_list = list(innovation.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
innovation["Combination"] = pd.Series(str_values)

# %%
# Gather data
resulting_combinations = innovation["Combination"].value_counts()
resulting_combinations_percentage = innovation["Combination"].value_counts(normalize=True)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.savefig("pdf/Q048-Combinazioni.pdf")

# %%
# Data of the combinations
resulting_combinations
# Out:
# Innovazione di prodotto                                         19
# Innovazione di processo (progettazione, produzione, distribuzione)    13
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione)     9
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione sociale     8
# Innovazione di sistema-prodotto (prodotto, servizio e processo)     8
# Innovazione sociale                                              7
# Innovazione di prodotto, Innovazione tecnologica                 6
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione tecnologica     5
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione tecnologica, Innovazione sociale     4
# Innovazione tecnologica                                          4
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione sociale     3
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo)     3
# Innovazione di prodotto, Innovazione sociale                     3
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione tecnologica     2
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione sociale     2
# Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione sociale     2
# Innovazione tecnologica, Innovazione sociale                     2
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione tecnologica, Innovazione sociale     1
# Innovazione di prodotto, Innovazione di sistema-prodotto (prodotto, servizio e processo)     1
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione tecnologica     1
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione tecnologica     1
# Innovazione di prodotto, Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione sociale     1
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo)     1
# Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione tecnologica, Innovazione sociale     1
# dtype: int64

# %%
# Data of the combinations: percentage
resulting_combinations_percentage
# Out:
# Innovazione di prodotto                                         14.179104
# Innovazione di processo (progettazione, produzione, distribuzione)     9.701493
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione)     6.716418
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione sociale     5.970149
# Innovazione di sistema-prodotto (prodotto, servizio e processo)     5.970149
# Innovazione sociale                                              5.223881
# Innovazione di prodotto, Innovazione tecnologica                 4.477612
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione tecnologica     3.731343
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione tecnologica, Innovazione sociale     2.985075
# Innovazione tecnologica                                          2.985075
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione sociale     2.238806
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo)     2.238806
# Innovazione di prodotto, Innovazione sociale                     2.238806
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione tecnologica     1.492537
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione sociale     1.492537
# Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione sociale     1.492537
# Innovazione tecnologica, Innovazione sociale                     1.492537
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione tecnologica, Innovazione sociale     0.746269
# Innovazione di prodotto, Innovazione di sistema-prodotto (prodotto, servizio e processo)     0.746269
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione tecnologica     0.746269
# Innovazione di prodotto, Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione tecnologica     0.746269
# Innovazione di prodotto, Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione sociale     0.746269
# Innovazione di processo (progettazione, produzione, distribuzione), Innovazione di sistema-prodotto (prodotto, servizio e processo)     0.746269
# Innovazione di sistema-prodotto (prodotto, servizio e processo), Innovazione tecnologica, Innovazione sociale     0.746269
# dtype: float64
