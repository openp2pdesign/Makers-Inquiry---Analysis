# %% [markdown]
# # Q055 - A quali soggetti offri questi servizi?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q055[SQ001] - Q055[SQ010] - Q055[other]

services_columns = ['Q055[SQ001]','Q055[SQ002]','Q055[SQ003]','Q055[SQ004]','Q055[SQ005]',
                    'Q055[SQ006]','Q055[SQ007]','Q055[SQ008]','Q055[SQ009]','Q055[SQ010]']
services_options = ['Imprese',
                    'Artigiani',
                    'Professionisti',
                    'Enti e Istituzioni pubbliche e private',
                    'Makers',
                    'Bambini',
                    'Studenti',
                    'Pensionati',
                    'Disoccupati',
                    'Finanziatori (crowdfunding/venture capitalist)'                    
                    ]
services = data[services_columns]
services.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
services_other = data['Q055[other]'].str.lower().value_counts()
# Out:
# -c:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#services[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(services_columns)+1):
    comb = list(itertools.combinations(services_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in services_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = services_columns.index(j) # Get position
            comb_list.append(services_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in services.index:
    current_bool_list = list(services.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
services["Combination"] = pd.Series(str_values)
# Out:
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Gather data
resulting_combinations = services["Combination"].value_counts()
resulting_combinations_percentage = services["Combination"].value_counts(normalize=True)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.title(u"A quali soggetti offri questi servizi? Combinazioni", fontsize=18)
plt.ylabel("Persone", fontsize=16)
plt.xlabel("Combinazioni", fontsize=16)
plt.savefig("svg/Q055-Combinazioni.svg")
plt.savefig("png/Q055-Combinazioni.png")

# %%
# Data of the combinations
resulting_combinations
# Out:
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Studenti, Pensionati, Disoccupati, Finanziatori (crowdfunding/venture capitalist)    4
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Studenti, Pensionati, Disoccupati    3
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Studenti    2
# Imprese, Artigiani, Professionisti, Makers, Studenti, Disoccupati    2
# Imprese, Enti e Istituzioni pubbliche e private                 1
# Imprese, Professionisti, Makers                                 1
# Imprese, Artigiani, Professionisti                              1
# Professionisti, Makers, Bambini, Studenti                       1
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Studenti, Pensionati, Finanziatori (crowdfunding/venture capitalist)    1
# Imprese, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Disoccupati, Finanziatori (crowdfunding/venture capitalist)    1
# Artigiani, Makers, Studenti                                     1
# Artigiani, Professionisti, Makers, Bambini, Studenti            1
# Imprese, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Studenti    1
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Studenti, Finanziatori (crowdfunding/venture capitalist)    1
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Bambini, Studenti    1
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Studenti, Disoccupati    1
# Enti e Istituzioni pubbliche e private, Makers                  1
# dtype: int64

# %%
# Data of the combinations: percentage
resulting_combinations_percentage
# Out:
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Studenti, Pensionati, Disoccupati, Finanziatori (crowdfunding/venture capitalist)    2.985075
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Studenti, Pensionati, Disoccupati    2.238806
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Studenti    1.492537
# Imprese, Artigiani, Professionisti, Makers, Studenti, Disoccupati    1.492537
# Imprese, Enti e Istituzioni pubbliche e private                 0.746269
# Imprese, Professionisti, Makers                                 0.746269
# Imprese, Artigiani, Professionisti                              0.746269
# Professionisti, Makers, Bambini, Studenti                       0.746269
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Studenti, Pensionati, Finanziatori (crowdfunding/venture capitalist)    0.746269
# Imprese, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Bambini, Disoccupati, Finanziatori (crowdfunding/venture capitalist)    0.746269
# Artigiani, Makers, Studenti                                     0.746269
# Artigiani, Professionisti, Makers, Bambini, Studenti            0.746269
# Imprese, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Studenti    0.746269
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Studenti, Finanziatori (crowdfunding/venture capitalist)    0.746269
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Bambini, Studenti    0.746269
# Imprese, Artigiani, Professionisti, Enti e Istituzioni pubbliche e private, Makers, Studenti, Disoccupati    0.746269
# Enti e Istituzioni pubbliche e private, Makers                  0.746269
# dtype: float64
