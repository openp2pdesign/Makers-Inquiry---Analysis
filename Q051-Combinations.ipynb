# %% [markdown]
# # Q051 - Quali sono le principali spese che devi affrontare per la tua attivitá?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q051[SQ001] - Q051[SQ006] - Q051[other]

business_columns = ['Q051[SQ001]','Q051[SQ002]','Q051[SQ003]','Q051[SQ004]',
                    'Q051[SQ005]','Q051[SQ006]']
business_options = ['Acquisto di materiali',
                  'Acquisto/affitto di tecnologie',
                  'Acquisto/affitto di luoghi',
                  'Consulenze',
                  'Comunicazione (anche web)',
                  'Utenze'
                  ]
business = data[business_columns]
business.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
business_other = data['Q051[other]'].str.lower().value_counts()
# Out:
# -c:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#business[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(business_columns)+1):
    comb = list(itertools.combinations(business_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in business_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = business_columns.index(j) # Get position
            comb_list.append(business_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in business.index:
    current_bool_list = list(business.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
business["Combination"] = pd.Series(str_values)
# Out:
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Gather data
resulting_combinations = business["Combination"].value_counts(dropna=False)
resulting_combinations_percentage = business["Combination"].value_counts(normalize=True,dropna=False)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.title(u"Quali sono le principali spese che devi affrontare per la tua attivitá? Combinazioni", fontsize=18, y=1.02)
plt.ylabel("Persone", fontsize=16)
plt.xlabel("Combinazioni", fontsize=16)
plt.savefig("svg/Q051-Combinazioni.svg")
plt.savefig("png/Q051-Combinazioni.png")
plt.savefig("pdf/Q051-Combinazioni.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Data of the combinations
print "Data:"
print resulting_combinations
print
# Data of the combinations: percentage
print "Data %:"
print resulting_combinations_percentage

# %%
# Save+show the output to a text file
# %save Q051-Combinazioni.py str(output)
shutil.move("Q051-Combinazioni.py", "text/Q051-Combinazioni.txt")
# Out:
# The following commands were written to file `Q051-Combinazioni.py`:
# Data:
# Acquisto di materiali                                           33
# Acquisto di materiali, Acquisto/affitto di tecnologie           20
# NaN                                                             12
# Acquisto di materiali, Utenze                                    8
# Acquisto di materiali, Comunicazione (anche web)                 8
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi     5
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Utenze     5
# Acquisto di materiali, Acquisto/affitto di luoghi, Utenze        4
# Acquisto di materiali, Acquisto/affitto di tecnologie, Comunicazione (anche web)     4
# Acquisto di materiali, Acquisto/affitto di luoghi, Comunicazione (anche web), Utenze     3
# Acquisto di materiali, Comunicazione (anche web), Utenze         3
# Acquisto di materiali, Acquisto/affitto di tecnologie, Utenze     2
# Acquisto di materiali, Acquisto/affitto di luoghi, Comunicazione (anche web)     2
# Acquisto di materiali, Acquisto/affitto di luoghi                2
# Acquisto/affitto di tecnologie, Consulenze                       2
# Acquisto di materiali, Acquisto/affitto di tecnologie, Comunicazione (anche web), Utenze     2
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Consulenze, Comunicazione (anche web)     1
# Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Utenze     1
# Acquisto di materiali, Acquisto/affitto di tecnologie, Consulenze     1
# Comunicazione (anche web), Utenze                                1
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Comunicazione (anche web)     1
# Utenze                                                           1
# Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi       1
# Acquisto di materiali, Consulenze, Comunicazione (anche web)     1
# Comunicazione (anche web)                                        1
# Consulenze, Comunicazione (anche web)                            1
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Comunicazione (anche web), Utenze     1
# Acquisto di materiali, Acquisto/affitto di tecnologie, Consulenze, Comunicazione (anche web), Utenze     1
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Consulenze, Comunicazione (anche web), Utenze     1
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Consulenze, Utenze     1
# Acquisto/affitto di tecnologie                                   1
# Acquisto di materiali, Acquisto/affitto di tecnologie, Consulenze, Comunicazione (anche web)     1
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Consulenze     1
# Acquisto di materiali, Consulenze, Utenze                        1
# Acquisto/affitto di tecnologie, Comunicazione (anche web)        1
# dtype: int64
#
# Data %:
# Acquisto di materiali                                           24.626866
# Acquisto di materiali, Acquisto/affitto di tecnologie           14.925373
# NaN                                                              8.955224
# Acquisto di materiali, Utenze                                    5.970149
# Acquisto di materiali, Comunicazione (anche web)                 5.970149
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi     3.731343
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Utenze     3.731343
# Acquisto di materiali, Acquisto/affitto di luoghi, Utenze        2.985075
# Acquisto di materiali, Acquisto/affitto di tecnologie, Comunicazione (anche web)     2.985075
# Acquisto di materiali, Acquisto/affitto di luoghi, Comunicazione (anche web), Utenze     2.238806
# Acquisto di materiali, Comunicazione (anche web), Utenze         2.238806
# Acquisto di materiali, Acquisto/affitto di tecnologie, Utenze     1.492537
# Acquisto di materiali, Acquisto/affitto di luoghi, Comunicazione (anche web)     1.492537
# Acquisto di materiali, Acquisto/affitto di luoghi                1.492537
# Acquisto/affitto di tecnologie, Consulenze                       1.492537
# Acquisto di materiali, Acquisto/affitto di tecnologie, Comunicazione (anche web), Utenze     1.492537
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Consulenze, Comunicazione (anche web)     0.746269
# Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Utenze     0.746269
# Acquisto di materiali, Acquisto/affitto di tecnologie, Consulenze     0.746269
# Comunicazione (anche web), Utenze                                0.746269
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Comunicazione (anche web)     0.746269
# Utenze                                                           0.746269
# Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi       0.746269
# Acquisto di materiali, Consulenze, Comunicazione (anche web)     0.746269
# Comunicazione (anche web)                                        0.746269
# Consulenze, Comunicazione (anche web)                            0.746269
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Comunicazione (anche web), Utenze     0.746269
# Acquisto di materiali, Acquisto/affitto di tecnologie, Consulenze, Comunicazione (anche web), Utenze     0.746269
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Consulenze, Comunicazione (anche web), Utenze     0.746269
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Consulenze, Utenze     0.746269
# Acquisto/affitto di tecnologie                                   0.746269
# Acquisto di materiali, Acquisto/affitto di tecnologie, Consulenze, Comunicazione (anche web)     0.746269
# Acquisto di materiali, Acquisto/affitto di tecnologie, Acquisto/affitto di luoghi, Consulenze     0.746269
# Acquisto di materiali, Consulenze, Utenze                        0.746269
# Acquisto/affitto di tecnologie, Comunicazione (anche web)        0.746269
# dtype: float64
