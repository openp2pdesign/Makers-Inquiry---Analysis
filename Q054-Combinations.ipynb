# %% [markdown]
# # Q054 - Quali fra i seguenti elementi costituiscono la tua offerta di servizi?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q054[SQ001] - Q054[SQ010] - Q059[other]

services_columns = ['Q054[SQ001]','Q054[SQ002]','Q054[SQ003]','Q054[SQ004]','Q054[SQ005]',
                    'Q054[SQ006]','Q054[SQ007]','Q054[SQ008]','Q054[SQ009]','Q054[SQ010]']
services_options = ['Servizi per la progettazione on demand (workshop)',
                    'Servizi per la fabbricazione on demand',
                    'Servizi per la formazione (corsi e workshop didattici)',
                    'Servizi per la ricerca',
                    'Servizi per la progettazione di sistemi-prodotto (workshop progettuali)',
                    'Servizi per la progettazione di software (coding)',
                    'Servizi per la progettazione di tecnologie e macchine utensili',
                    'Servizi per la riparazione, rigenerazione e manutenzione di prodotti e tecnologie',
                    'Organizzazione di eventi culturali',
                    'Spazi Coworking'                    
                    ]
services = data[services_columns]
services.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
services_other = data['Q054[other]'].str.lower().value_counts()
# Out:
# -c:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#services[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(services_columns)+1):
    comb = list(itertools.combinations(services_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in services_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = services_columns.index(j) # Get position
            comb_list.append(services_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in services.index:
    current_bool_list = list(services.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
services["Combination"] = pd.Series(str_values)
# Out:
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Gather data
resulting_combinations = services["Combination"].value_counts(dropna=False)
resulting_combinations_percentage = services["Combination"].value_counts(normalize=True,dropna=False)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.title(u"Quali fra i seguenti elementi costituiscono la tua offerta di servizi? Combinazioni", fontsize=18, y=1.02)
plt.ylabel("Persone", fontsize=16)
plt.xlabel("Combinazioni", fontsize=16)
plt.savefig("svg/Q054-Combinazioni.svg")
plt.savefig("png/Q054-Combinazioni.png")
plt.savefig("pdf/Q054-Combinazioni.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Data of the combinations
print "Data:"
print resulting_combinations
print
# Data of the combinations: percentage
print "Data %:"
print resulting_combinations_percentage

# %%
# Save+show the output to a text file
# %save Q054-Combinazioni.py str(output)
shutil.move("Q054-Combinazioni.py", "text/Q054-Combinazioni.txt")
# Out:
# The following commands were written to file `Q054-Combinazioni.py`:
# Data:
# NaN                                                             109
# Servizi per la progettazione on demand (workshop), Servizi per la fabbricazione on demand, Servizi per la formazione (corsi e workshop didattici), Servizi per la ricerca, Servizi per la progettazione di sistemi-prodotto (workshop progettuali), Servizi per la progettazione di software (coding), Servizi per la progettazione di tecnologie e macchine utensili, Servizi per la riparazione, rigenerazione e manutenzione di prodotti e tecnologie, Organizzazione di eventi culturali, Spazi Coworking      2
# Servizi per la progettazione on demand (workshop), Servizi per la fabbricazione on demand, Servizi per la formazione (corsi e workshop didattici), Servizi per la progettazione di sistemi-prodotto (workshop progettuali)      1
# ...
