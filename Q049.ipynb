# %% [markdown]
# # Q049 - Generalmente come sostieni la tua attivitá di making?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q049[SQ001] - Q049[SQ004] - Q049[other]

business_columns = ['Q049[SQ001]','Q049[SQ002]','Q049[SQ003]','Q049[SQ004]']
business_options = ['Attraverso la vendita di progetti o prodotti',
                  'Attraverso prestiti e finanziamenti',
                  'Crowdfunding',
                  'Autofinanziamento']
business = data[business_columns]
business.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
business_other = data['Q049[other]'].str.lower().value_counts()
# Out:
# -c:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#business[0:4]

# %%
# Gather data
business_b = {}
for k,i in enumerate(business_columns):
    business_b[k] = business[i].value_counts(dropna=False)
    print "Data:",business_options[k]
    print business_b[k]
    print
    print "Data %:",business_options[k]
    print business[i].value_counts(normalize=True,dropna=False)*100
    print
    
yes = []
no = []
nanvalue = []

for k,i in enumerate(business_columns):
    business_presents = business_b[k].index.tolist()
    
    # Convert NaN to "NaN"
    for o,h in enumerate(business_presents):
        if type(h) is float:
            business_presents.pop(o)
            business_presents.append("NaN")
    
    # Reassign new list with "NaN"
    business_b[k].index = business_presents
    
    # Check for empty values, and put a 0 instead
    if "Si" not in business_presents:
        yes.append(0)
    if "No" not in business_presents:
        no.append(0)
    if "NaN" not in business_presents:
        nanvalue.append(0)
    
    for j in business_presents:
        if j == "Si":
            yes.append(business_b[k].ix["Si"])
        elif j == "No":
            no.append(business_b[k].ix["No"])
        elif j == "NaN":
            nanvalue.append(business_b[k].ix["NaN"])
# Out:
# Data: Attraverso la vendita di progetti o prodotti
# No     70
# Si     62
# NaN     2
# dtype: int64
#
# Data %: Attraverso la vendita di progetti o prodotti
# No     52.238806
# Si     46.268657
# NaN     1.492537
# dtype: float64
#
# Data: Attraverso prestiti e finanziamenti
# No     119
# Si      13
# NaN      2
# dtype: int64
#
# Data %: Attraverso prestiti e finanziamenti
# No     88.805970
# Si      9.701493
# NaN     1.492537
# dtype: float64
#
# Data: Crowdfunding
# No     121
# Si      11
# NaN      2
# dtype: int64
#
# Data %: Crowdfunding
# No     90.298507
# Si      8.208955
# NaN     1.492537
# dtype: float64
#
# Data: Autofinanziamento
# Si     96
# No     36
# NaN     2
# dtype: int64
#
# Data %: Autofinanziamento
# Si     71.641791
# No     26.865672
# NaN     1.492537
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Modalitá', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u'Generalmente come sostieni la tua attivitá di making?', fontsize=18)
plt.xticks(range(len(business_options)+1),business_options,rotation=90)
ind = np.arange(len(business_columns))   # the x locations for the groups
width = 0.25                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 3) # Set color palette
rect1 = plt.bar(ind,yes,width,color=my_colors[1],align='center') # Plot Yes
rect2 = plt.bar(ind+width,no,width,color=my_colors[0],align='center') # Plot No 
rect3 = plt.bar(ind+width*2,nanvalue,width,color=my_colors[2],align='center') # Plot NaN
plt.legend( (rect1, rect2, rect3), ('Si', 'No', 'NaN') )
plt.savefig("svg/Q049-MakerBusiness01.svg")
plt.savefig("png/Q049-MakerBusiness01.png")

# %%
# Get "other" data
business_other = data["Q049[other]"].str.lower().value_counts()
print "Data:"
print business_other
print ""
print "Data %:"
print data["Q049[other]"].str.lower().value_counts(normalize=True) * 100

# Plot bar
plt.figure(figsize=(8,6))
plt.title(u'Generalmente come sostieni la tua attivitá di making? Altro', fontsize=18)
plt.xticks(range(len(business_other.index)),business_other.index,rotation=90)
plt.xlabel(u'Modalitá', fontsize=16)
plt.ylabel('Persone', fontsize=16)
ind = np.arange(len(business_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(business_other)) # Set color palette
rect1 = plt.bar(ind,business_other,width,color=my_colors,align='center')
plt.savefig("svg/Q049-MakerBusiness02.svg")
plt.savefig("png/Q049-MakerBusiness02.png")
# Out:
# Data:
# con i proventi del mio lavoro                1
# lavoro come disegnatore tecnico freelance    1
# ci smeno!                                    1
# colletta/associazionismo                     1
# borsa regionale                              1
# dtype: int64
#
# Data %:
# con i proventi del mio lavoro                0.746269
# lavoro come disegnatore tecnico freelance    0.746269
# ci smeno!                                    0.746269
# colletta/associazionismo                     0.746269
# borsa regionale                              0.746269
# dtype: float64
