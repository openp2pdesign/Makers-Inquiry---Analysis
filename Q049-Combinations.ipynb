# %% [markdown]
# # Q049 - Generalmente come sostieni la tua attivitá di making?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q049[SQ001] - Q049[SQ004] - Q049[other]

business_columns = ['Q049[SQ001]','Q049[SQ002]','Q049[SQ003]','Q049[SQ004]']
business_options = ['Attraverso la vendita di progetti o prodotti',
                  'Attraverso prestiti e finanziamenti',
                  'Crowdfunding',
                  'Autofinanziamento']
business = data[business_columns]
business.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
business_other = data['Q049[other]'].str.lower().value_counts()
# Out:
# -c:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#business[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(business_columns)+1):
    comb = list(itertools.combinations(business_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in business_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = business_columns.index(j) # Get position
            comb_list.append(business_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in business.index:
    current_bool_list = list(business.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
business["Combination"] = pd.Series(str_values)
# Out:
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Gather data
resulting_combinations = business["Combination"].value_counts(dropna=False)
resulting_combinations_percentage = business["Combination"].value_counts(normalize=True,dropna=False)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.title(u"Generalmente come sostieni la tua attivitá di making? Combinazioni", fontsize=18, y=1.02)
plt.ylabel("Persone", fontsize=16)
plt.xlabel("Combinazioni", fontsize=16)
plt.savefig("svg/Q049-Combinazioni.svg")
plt.savefig("png/Q049-Combinazioni.png")
plt.savefig("pdf/Q049-Combinazioni.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Data of the combinations
print "Data:"
print resulting_combinations
print
# Data of the combinations: percentage
print "Data %:"
print resulting_combinations_percentage

# %%
# Save+show the output to a text file
# %save Q049-Combinazioni.py str(output)
shutil.move("Q049-Combinazioni.py", "text/Q049-Combinazioni.txt")
# Out:
# The following commands were written to file `Q049-Combinazioni.py`:
# Data:
# Autofinanziamento                                               53
# Attraverso la vendita di progetti o prodotti, Autofinanziamento    32
# Attraverso la vendita di progetti o prodotti                    14
# NaN                                                             14
# Attraverso la vendita di progetti o prodotti, Attraverso prestiti e finanziamenti     4
# Attraverso la vendita di progetti o prodotti, Attraverso prestiti e finanziamenti, Autofinanziamento     4
# Attraverso la vendita di progetti o prodotti, Crowdfunding, Autofinanziamento     3
# Attraverso la vendita di progetti o prodotti, Crowdfunding       3
# Attraverso prestiti e finanziamenti                              1
# Attraverso la vendita di progetti o prodotti, Attraverso prestiti e finanziamenti, Crowdfunding, Autofinanziamento     1
# Attraverso prestiti e finanziamenti, Autofinanziamento           1
# Attraverso prestiti e finanziamenti, Crowdfunding, Autofinanziamento     1
# Crowdfunding, Autofinanziamento                                  1
# Crowdfunding                                                     1
# Attraverso la vendita di progetti o prodotti, Attraverso prestiti e finanziamenti, Crowdfunding     1
# dtype: int64
#
# Data %:
# Autofinanziamento                                               39.552239
# Attraverso la vendita di progetti o prodotti, Autofinanziamento    23.880597
# Attraverso la vendita di progetti o prodotti                    10.447761
# NaN                                                             10.447761
# Attraverso la vendita di progetti o prodotti, Attraverso prestiti e finanziamenti     2.985075
# Attraverso la vendita di progetti o prodotti, Attraverso prestiti e finanziamenti, Autofinanziamento     2.985075
# Attraverso la vendita di progetti o prodotti, Crowdfunding, Autofinanziamento     2.238806
# Attraverso la vendita di progetti o prodotti, Crowdfunding       2.238806
# Attraverso prestiti e finanziamenti                              0.746269
# Attraverso la vendita di progetti o prodotti, Attraverso prestiti e finanziamenti, Crowdfunding, Autofinanziamento     0.746269
# Attraverso prestiti e finanziamenti, Autofinanziamento           0.746269
# Attraverso prestiti e finanziamenti, Crowdfunding, Autofinanziamento     0.746269
# Crowdfunding, Autofinanziamento                                  0.746269
# Crowdfunding                                                     0.746269
# Attraverso la vendita di progetti o prodotti, Attraverso prestiti e finanziamenti, Crowdfunding     0.746269
# dtype: float64
