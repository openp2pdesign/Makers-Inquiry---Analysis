# %% [markdown]
# # Q054 - Quali fra i seguenti elementi costituiscono la tua offerta di servizi?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Get rid of the people who did not answer to this section
data = data.loc[data['Q001'] == 'Gestore di makerspace']

# %%
# Range: Q054[SQ001] - Q054[SQ010] - Q059[other]

services_columns = ['Q054[SQ001]','Q054[SQ002]','Q054[SQ003]','Q054[SQ004]','Q054[SQ005]',
                    'Q054[SQ006]','Q054[SQ007]','Q054[SQ008]','Q054[SQ009]','Q054[SQ010]']
services_options = ['Servizi per la progettazione on demand (workshop)',
                    'Servizi per la fabbricazione on demand',
                    'Servizi per la formazione (corsi e workshop didattici)',
                    'Servizi per la ricerca',
                    'Servizi per la progettazione di sistemi-prodotto (workshop progettuali)',
                    'Servizi per la progettazione di software (coding)',
                    'Servizi per la progettazione di tecnologie e macchine utensili',
                    'Servizi per la riparazione, rigenerazione e manutenzione di prodotti e tecnologie',
                    'Organizzazione di eventi culturali',
                    'Spazi Coworking'                    
                    ]
services = data[services_columns]
services.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
services_other = data['Q054[other]'].str.lower().value_counts()
# Out:
# -c:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#services[0:4]

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Gather data
services_b = {}

for k,i in enumerate(services_columns):
    services_b[k] = services[i].value_counts(dropna=False)
    print "Data:",services_options[k]
    print services_b[k]
    print
    print "Data %:",services_options[k]
    print services[i].value_counts(normalize=True,dropna=False)*100
    print

# %%
# Save+show the output to a text file
# %save Q054-MakerspaceServices01.py str(output)
shutil.move("Q054-MakerspaceServices01.py", "text/Q054-MakerspaceServices01.txt")
# Out:
# The following commands were written to file `Q054-MakerspaceServices01.py`:
# Data: Servizi per la progettazione on demand (workshop)
# Si     20
# No      9
# NaN     0
# dtype: int64
#
# Data %: Servizi per la progettazione on demand (workshop)
# Si     68.965517
# No     31.034483
# NaN     0.000000
# dtype: float64
#
# Data: Servizi per la fabbricazione on demand
# Si     15
# No     14
# NaN     0
# dtype: int64
#
# Data %: Servizi per la fabbricazione on demand
# Si     51.724138
# No     48.275862
# NaN     0.000000
# dtype: float64
#
# Data: Servizi per la formazione (corsi e workshop didattici)
# Si     23
# No      6
# NaN     0
# dtype: int64
#
# Data %: Servizi per la formazione (corsi e workshop didattici)
# Si     79.310345
# No     20.689655
# NaN     0.000000
# dtype: float64
#
# Data: Servizi per la ricerca
# No     16
# Si     13
# NaN     0
# dtype: int64
#
# Data %: Servizi per la ricerca
# No     55.172414
# Si     44.827586
# NaN     0.000000
# dtype: float64
#
# ...

# %%
yes = []
no = []
nanvalue = []

for k,i in enumerate(services_columns):
    services_presents = services_b[k].index.tolist()
    
    # Convert NaN to "NaN"
    for o,h in enumerate(services_presents):
        if type(h) is float:
            services_presents.pop(o)
            services_presents.append("NaN")
    
    # Reassign new list with "NaN"
    services_b[k].index = services_presents
    
    # Check for empty values, and put a 0 instead
    if "Si" not in services_presents:
        yes.append(0)
    if "No" not in services_presents:
        no.append(0)
    if "NaN" not in services_presents:
        nanvalue.append(0)
    
    for j in services_presents:
        if j == "Si":
            yes.append(services_b[k].ix["Si"])
        elif j == "No":
            no.append(services_b[k].ix["No"])
        elif j == "NaN":
            nanvalue.append(services_b[k].ix["NaN"])

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Servizi', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u'Quali fra i seguenti elementi costituiscono la tua offerta di servizi?', fontsize=18, y=1.02)
plt.xticks(range(len(services_options)+1),services_options,rotation=90)
ind = np.arange(len(services_columns))   # the x locations for the groups
width = 0.25                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 3) # Set color palette
rect1 = plt.bar(ind,yes,width,color=my_colors[1],align='center') # Plot Yes
rect2 = plt.bar(ind+width,no,width,color=my_colors[0],align='center') # Plot No 
rect3 = plt.bar(ind+width*2,nanvalue,width,color=my_colors[2],align='center') # Plot NaN 
plt.legend( (rect1, rect2, rect3), ('Si', 'No', 'NaN') )
plt.savefig("svg/Q054-MakerspaceServices01.svg")
plt.savefig("png/Q054-MakerspaceServices01.png")
plt.savefig("pdf/Q054-MakerspaceServices01.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get "other" data
services_other = data["Q054[other]"].str.lower().value_counts()
print "Data:"
print services_other
print ""
print "Data %:"
print data["Q054[other]"].str.lower().value_counts(normalize=True) * 100

# %%
# Save+show the output to a text file
# %save Q054-MakerspaceServices02.py str(output)
shutil.move("Q054-MakerspaceServices02.py", "text/Q054-MakerspaceServices02.txt")
# Out:
# The following commands were written to file `Q054-MakerspaceServices02.py`:
# Data:
# come maker non offro servizi    1
# dtype: int64
#
# Data %:
# come maker non offro servizi    3.448276
# dtype: float64

# %%
# Plot bar
plt.figure(figsize=(8,6))
plt.title(u'Quali fra i seguenti elementi costituiscono la tua offerta di servizi? Altro', fontsize=18, y=1.02)
plt.xticks(range(len(services_other.index)),services_other.index,rotation=90)
plt.xlabel(u'Servizi', fontsize=16)
plt.ylabel('Persone', fontsize=16)
ind = np.arange(len(services_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(services_other)) # Set color palette
rect1 = plt.bar(ind,services_other,width,color=my_colors,align='center')
plt.savefig("svg/Q054-MakerspaceServices02.svg")
plt.savefig("png/Q054-MakerspaceServices02.png")
plt.savefig("pdf/Q054-MakerspaceServices02.pdf")
