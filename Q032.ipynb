# %% [markdown]
# # Q032 - Di quale laboratorio/spazio di fabbricazione si tratta?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get the distribution of study titles
lab= data["Q032"].value_counts(dropna=False)
print "Data:"
print lab
print ""
print "Data %:"
print data["Q032"].value_counts(normalize=True,dropna=False) * 100

# %%
# Save+show the output to a text file
# %save Q032-MakerTipiDiLaboratori01.py str(output)
shutil.move("Q032-MakerTipiDiLaboratori01.py", "text/Q032-MakerTipiDiLaboratori01.txt")
# Out:
# The following commands were written to file `Q032-MakerTipiDiLaboratori01.py`:
# Data:
# Fab Lab                             47
# NaN                                 34
# Laboratorio artigiano               25
# Altro                               13
# Makerspace                           7
# Laboratori/officine di quartiere     5
# Living Lab                           3
# dtype: int64
#
# Data %:
# Fab Lab                             35.074627
# NaN                                 25.373134
# Laboratorio artigiano               18.656716
# Altro                                9.701493
# Makerspace                           5.223881
# Laboratori/officine di quartiere     3.731343
# Living Lab                           2.238806
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Tipi di laboratori frequentati', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title("Di quale laboratorio/spazio di fabbricazione si tratta?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(lab)) # Set color palette
lab.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q032-MakerTipiDiLaboratori01.svg")
plt.savefig("png/Q032-MakerTipiDiLaboratori01.png")
plt.savefig("pdf/Q032-MakerTipiDiLaboratori01.pdf")
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:1279: UserWarning: findfont: Font family ['Source Sans Pro'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get "other" data
lab_other = data["Q032[other]"].str.lower().value_counts()
print "Data:"
print lab_other
print ""
print "Data %:"
print data["Q032[other]"].str.lower().value_counts(normalize=True) * 100

# %%
# Save+show the output to a text file
# %save Q032-MakerTipiDiLaboratori02.py str(output)
shutil.move("Q032-MakerTipiDiLaboratori02.py", "text/Q032-MakerTipiDiLaboratori02.txt")
# Out:
# The following commands were written to file `Q032-MakerTipiDiLaboratori02.py`:
# Data:
# un po' tutte quelle sopra.                                      1
# garage                                                          1
# il mio ufficio/studio                                           1
# studio                                                          1
# laboratorio universitario                                       1
# studio pedrini srl                                              1
# personale                                                       1
# coworking orientato ai makers                                   1
# makern lab, rimini.                                             1
# ufficio/laboratorio                                             1
# fino a poco fa un makerspace/fablab con un paio di stampanti 3d e elettronica varia, ora in cerca di un nuovo spazio per farci un fablab a tutti gli effetti    1
# ...

# %%
# Plot bar
plt.figure(figsize=(8,6))
plt.title('Di quale laboratorio/spazio di fabbricazione si tratta? Altro', fontsize=18, y=1.02)
plt.xticks(range(len(lab_other.index)),lab_other.index,rotation=90)
plt.xlabel('Tipo', fontsize=16)
plt.ylabel('Persone', fontsize=16)
ind = np.arange(len(lab_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(lab_other)) # Set color palette
rect1 = plt.bar(ind,lab_other,width,color=my_colors,align='center')
plt.savefig("svg/Q032-MakerTipiDiLaboratori.svg")
plt.savefig("png/Q032-MakerTipiDiLaboratori.png")
plt.savefig("pdf/Q032-MakerTipiDiLaboratori.pdf")

# %% [markdown]
# ## Merge relevant data

# %%
lab["Fab Lab"] += 2
lab["Makerspace"] += 1
lab["Laboratorio artigiano"] += 1
lab["Altro"] -= 4

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
print "Data:"
print lab
print ""
print "Data %:"
print lab/lab.sum() * 100

# %%
# Save+show the output to a text file
# %save Q032-MakerTipiDiLaboratori03.py str(output)
shutil.move("Q032-MakerTipiDiLaboratori03.py", "text/Q032-MakerTipiDiLaboratori03.txt")
# Out:
# The following commands were written to file `Q032-MakerTipiDiLaboratori03.py`:
# Data:
# Fab Lab                             49
# NaN                                 34
# Laboratorio artigiano               26
# Altro                                9
# Makerspace                           8
# Laboratori/officine di quartiere     5
# Living Lab                           3
# dtype: int64
#
# Data %:
# Fab Lab                             36.567164
# NaN                                 25.373134
# Laboratorio artigiano               19.402985
# Altro                                6.716418
# Makerspace                           5.970149
# Laboratori/officine di quartiere     3.731343
# Living Lab                           2.238806
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Tipi di laboratori frequentati', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title("Di quale laboratorio/spazio di fabbricazione si tratta?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(lab)) # Set color palette
lab.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q032-MakerTipiDiLaboratori03.svg")
plt.savefig("png/Q032-MakerTipiDiLaboratori03.png")
plt.savefig("pdf/Q032-MakerTipiDiLaboratori03.pdf")
