# %% [markdown]
# # Q032 - Di quale laboratorio/spazio di fabbricazione si tratta?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Get the distribution of study titles
lab= data["Q032"].value_counts(dropna=False)
print "Data:"
print lab
print ""
print "Data %:"
print data["Q032"].value_counts(normalize=True,dropna=False) * 100

# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Tipi di laboratori frequentati')
plt.ylabel('Persone')
my_colors = seaborn.color_palette("husl", len(lab)) # Set color palette
lab.plot(kind="bar",title="Maker: Tipi di laboratori frequentati",color=my_colors)
plt.savefig("pdf/Q032-MakerTipiDiLaboratori01.pdf") # Save pdf
# Out:
# Data:
# NaN                                 29
# Fab Lab                             28
# Laboratorio artigiano               23
# Altro                                9
# Makerspace                           6
# Laboratori/officine di quartiere     5
# Living Lab                           3
# dtype: int64
# Data %:
# NaN                                 28.155340
# Fab Lab                             27.184466
# Laboratorio artigiano               22.330097
# Altro                                8.737864
# Makerspace                           5.825243
# Laboratori/officine di quartiere     4.854369
# Living Lab                           2.912621
# dtype: float64

# %%
# Get "other" data
lab_other = data["Q032[other]"].str.lower().value_counts()
print "Data:"
print lab_other
print ""
print "Data %:"
print data["Q032[other]"].str.lower().value_counts(normalize=True) * 100

# Plot bar
plt.figure(figsize=(8,6))
plt.title('Maker: Tipi di laboratori frequentati. Altro')
plt.xticks(range(len(lab_other.index)),lab_other.index,rotation=90)
plt.xlabel('Tipo')
plt.ylabel('Persone')
ind = np.arange(len(lab_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(lab_other)) # Set color palette
rect1 = plt.bar(ind,lab_other,width,color=my_colors,align='center')
plt.savefig("pdf/Q032-MakerTipiDiLaboratori.pdf") # Save pdf
# Out:
# Data:
# studio pedrini srl                                              1
# un po' tutte quelle sopra.                                      1
# personale                                                       1
# makern lab, rimini.                                             1
# ufficio/laboratorio                                             1
# scuola                                                          1
# studio                                                          1
# fino a poco fa un makerspace/fablab con un paio di stampanti 3d e elettronica varia, ora in cerca di un nuovo spazio per farci un fablab a tutti gli effetti    1
# garage                                                          1
# dtype: int64
#
# Data %:
# studio pedrini srl                                              0.970874
# un po' tutte quelle sopra.                                      0.970874
# personale                                                       0.970874
# makern lab, rimini.                                             0.970874
# ufficio/laboratorio                                             0.970874
# scuola                                                          0.970874
# studio                                                          0.970874
# fino a poco fa un makerspace/fablab con un paio di stampanti 3d e elettronica varia, ora in cerca di un nuovo spazio per farci un fablab a tutti gli effetti    0.970874
# garage                                                          0.970874
# dtype: float64
