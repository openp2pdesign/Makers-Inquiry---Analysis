# %% [markdown]
# # Q062 - Cosa chiederesti alle istituzioni per facilitare la tua attivitá di making?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q062[SQ001] - Q062[SQ005] - Q062[other]

policy_columns = ['Q062[SQ001]','Q062[SQ002]','Q062[SQ003]','Q062[SQ004]','Q062[SQ005]']
policy_options = ['Agevolazioni fiscali',
                  'Accesso facilitato al credito',
                  'Semplificazione burocratica',
                  u"Riconoscimento giuridico dell'attivitá di maker",
                  u'Opportunità di finanziamento']
policy = data[policy_columns]
policy.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
policy_other = data['Q062[other]'].str.lower().value_counts()
# Out:
# -c:10: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %%
policy[0:4]
# Out:
#   Q062[SQ001] Q062[SQ002] Q062[SQ003] Q062[SQ004] Q062[SQ005]
# 0          Si          Si          Si          No          Si
# 1          No          No          No          No          Si
# 2          Si          Si          No          No          Si
# 3          No          No          Si          No          No

# %%
# Gather data
policy_b = {}
for k,i in enumerate(policy_columns):
    policy_b[k] = policy[i].value_counts()
    print "Data:",policy_options[k]
    print policy_b[k]
    print
    print "Data %:",policy_options[k]
    print policy[i].value_counts(normalize=True)*100
    print
    
yes = []
no = []

# Get data for plotting, and check that we have all the values for Yes and No
for k,i in enumerate(policy_columns):
    if len(policy_b[k].index) == 2:
        if policy_b[k].index[0] == "Si":
            yes.append(policy_b[k].iloc[0])
            no.append(policy_b[k].iloc[1])
        elif policy_b[k].index[1] == "Si":
            yes.append(policy_b[k].iloc[1])
            no.append(policy_b[k].iloc[0])
    elif len(policy_b[k].index) == 1:
        if policy_b[k].index[0] == "Si":
            yes.append(policy_b[k].iloc[0])
            no.append(0)
        elif policy_b[k].index[0] == "No":
            yes.append(0)
            no.append(policy_b[k].iloc[0])
    else:
        yes.append(0)
        no.append(0)

# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Richieste')
plt.ylabel('Persone')
plt.title(u'Cosa chiederesti alle istituzioni per facilitare la tua attivitá di making?')
plt.xticks(range(len(policy_options)),policy_options,rotation=90)
ind = np.arange(len(policy_columns))   # the x locations for the groups
width = 0.35                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 2) # Set color palette
rect1 = plt.bar(ind,yes,width,color=my_colors[1],align='center') # Plot Yes
rect2 = plt.bar(ind+width,no,width,color=my_colors[0],align='center') # Plot No 
plt.legend( (rect1, rect2), ('Si', 'No') )
plt.savefig("pdf/Q062-RichiestePolitiche01.pdf")
# Out:
# Data: Agevolazioni fiscali
# Si    92
# No    40
# dtype: int64
#
# Data %: Agevolazioni fiscali
# Si    68.656716
# No    29.850746
# dtype: float64
#
# Data: Accesso facilitato al credito
# No    84
# Si    48
# dtype: int64
#
# Data %: Accesso facilitato al credito
# No    62.686567
# Si    35.820896
# dtype: float64
#
# Data: Semplificazione burocratica
# Si    82
# No    50
# dtype: int64
#
# Data %: Semplificazione burocratica
# Si    61.194030
# No    37.313433
# dtype: float64
#
# Data: Riconoscimento giuridico dell'attivitá di maker
# No    76
# Si    56
# dtype: int64
#
# Data %: Riconoscimento giuridico dell'attivitá di maker
# No    56.716418
# Si    41.791045
# dtype: float64
#
# Data: Opportunità di finanziamento
# No    75
# Si    57
# dtype: int64
#
# Data %: Opportunità di finanziamento
# No    55.970149
# Si    42.537313
# dtype: float64

# %%
# Get "other" data
business_other = data["Q062[other]"].str.lower().value_counts()
print "Data:"
print business_other
print ""
print "Data %:"
print data["Q062[other]"].str.lower().value_counts(normalize=True) * 100

# Plot bar
plt.figure(figsize=(8,6))
plt.title(u'Cosa chiederesti alle istituzioni per facilitare la tua attivitá di making? Altro')
plt.xticks(range(len(business_other.index)),business_other.index,rotation=90)
plt.xlabel(u'Richieste')
plt.ylabel('Persone')
ind = np.arange(len(business_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(business_other)) # Set color palette
rect1 = plt.bar(ind,business_other,width,color=my_colors,align='center')
plt.savefig("pdf/Q062-RichiestePolitiche02.pdf")
# Out:
# Data:
# nulla                                                           2
# cambio di mentalità                                             1
# promozione                                                      1
# interesse                                                       1
# possibilità, spazi per sperimentazioni, partecipazioni in manifestazioni.    1
# collaborazione per la realizzazione di progetti di valorizzazione del territorio    1
# riconoscimento di titolo come scuola pubblica                   1
# in italia istituzioni non fanno niente che metterti in difficoltà!!!     1
# facilitazione networking e partner                              1
# prima di tutto semplificare il brevetto di idee troppo farraginoso    1
# comprensione di quello che facciamo                             1
# immondizia gratis,assicurazione agevolata                       1
# dtype: int64
#
# Data %:
# nulla                                                           1.492537
# cambio di mentalità                                             0.746269
# promozione                                                      0.746269
# interesse                                                       0.746269
# possibilità, spazi per sperimentazioni, partecipazioni in manifestazioni.    0.746269
# collaborazione per la realizzazione di progetti di valorizzazione del territorio    0.746269
# riconoscimento di titolo come scuola pubblica                   0.746269
# in italia istituzioni non fanno niente che metterti in difficoltà!!!     0.746269
# facilitazione networking e partner                              0.746269
# prima di tutto semplificare il brevetto di idee troppo farraginoso    0.746269
# comprensione di quello che facciamo                             0.746269
# immondizia gratis,assicurazione agevolata                       0.746269
# dtype: float64
