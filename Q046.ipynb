# %% [markdown]
# # Q046 - Nel caso di prodotti materiali quanti ne realizzi annualmente?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get the distribution of way of living
product_output = data["Q046"].value_counts(dropna=False)
print "Data:"
print product_output
print ""
print "Data %:"
print data["Q046"].value_counts(normalize=True,dropna=False) * 100

# %%
# Save+show the output to a text file
# %save Q046-MakerQuantoProduci01.py str(output)
shutil.move("Q046-MakerQuantoProduci01.py", "text/Q046-MakerQuantoProduci01.txt")
# Out:
# The following commands were written to file `Q046-MakerQuantoProduci01.py`:
# Data:
# NaN                  32
# Meno di 10 unità     26
# Meno di 50 unità     25
# Meno di 5 unità      20
# Oltre 100 unità      17
# Meno di 100 unità    14
# dtype: int64
#
# Data %:
# NaN                  23.880597
# Meno di 10 unità     19.402985
# Meno di 50 unità     18.656716
# Meno di 5 unità      14.925373
# Oltre 100 unità      12.686567
# Meno di 100 unità    10.447761
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Quantitá produzione', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title("Nel caso di prodotti materiali quanti ne realizzi annualmente?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(product_output)) # Set color palette
product_output.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q046-MakerQuantoProduci01.svg")
plt.savefig("png/Q046-MakerQuantoProduci01.png")
plt.savefig("pdf/Q046-MakerQuantoProduci01.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Order of the choices
product_output_order = [np.nan,u"Meno di 5 unità",u"Meno di 10 unità",u"Meno di 50 unità",u"Meno di 100 unità",u"Oltre 100 unità"]

product_output2 = product_output.reindex(product_output_order)

# Get the distribution of way of living, reindexed
print "Data:"
print product_output2
print ""
print "Data %:"
product_output2_normalized = data["Q046"].value_counts(normalize=True) * 100
print product_output2_normalized.reindex(product_output_order)

# %%
# Save+show the output to a text file
# %save Q046-MakerQuantoProduci02.py str(output)
shutil.move("Q046-MakerQuantoProduci02.py", "text/Q046-MakerQuantoProduci02.txt")
# Out:
# The following commands were written to file `Q046-MakerQuantoProduci02.py`:
# Data:
# NaN                  32
# Meno di 5 unità      20
# Meno di 10 unità     26
# Meno di 50 unità     25
# Meno di 100 unità    14
# Oltre 100 unità      17
# dtype: int64
#
# Data %:
# NaN                        NaN
# Meno di 5 unità      14.925373
# Meno di 10 unità     19.402985
# Meno di 50 unità     18.656716
# Meno di 100 unità    10.447761
# Oltre 100 unità      12.686567
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Quantitá produzione', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title("Nel caso di prodotti materiali quanti ne realizzi annualmente?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(product_output2)) # Set color palette
product_output2.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q046-MakerQuantoProduci02.svg")
plt.savefig("png/Q046-MakerQuantoProduci02.png")
plt.savefig("pdf/Q046-MakerQuantoProduci02.pdf")
