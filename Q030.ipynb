# %% [markdown]
# # Q029 - Quanto sono importanti per te lo scambio, la condivisione e la collaborazione rispetto a...

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q030[SQ001] - Q030[SQ007]

agree_columns = ['Q030[SQ001]','Q030[SQ002]','Q030[SQ003]','Q030[SQ004]','Q030[SQ005]','Q030[SQ006]','Q030[SQ007]']
agree_options = [u"Informazioni di carattere generale sul making e la comunità dei maker",
                 u"Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione",
                 u"Files e dati relativi a progetti esistenti",
                 u"Sviluppo di nuovi progetti",
                 u"Tecnologie, strumenti, macchine e attrezzature",
                 u"Spazi e ambienti di lavoro",
                 u"Organizzazione di nuove iniziative"]
agree = data[agree_columns]
agree_types = [u"Moltissimo",u"Molto",u"Abbastanza",u"Poco",u"Niente",u"Non so / Non risponde"]

# %%
agree
# Out:
#                Q030[SQ001] Q030[SQ002] Q030[SQ003] Q030[SQ004] Q030[SQ005]  \
# 0                    Molto       Molto       Molto       Molto       Molto
# 1               Moltissimo  Moltissimo  Moltissimo       Molto  Moltissimo
# 2                     Poco  Moltissimo        Poco  Moltissimo  Moltissimo
# 3                    Molto       Molto       Molto  Moltissimo  Abbastanza
# 4                      NaN         NaN         NaN         NaN         NaN
# 5                    Molto       Molto  Abbastanza       Molto       Molto
# 6                    Molto  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 7               Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 8               Moltissimo  Moltissimo        Poco  Abbastanza  Abbastanza
# 9               Moltissimo  Abbastanza  Abbastanza  Abbastanza  Abbastanza
# 10              Moltissimo       Molto  Abbastanza  Moltissimo  Abbastanza
# 11              Moltissimo  Moltissimo       Molto       Molto  Abbastanza
# 12              Abbastanza       Molto  Abbastanza  Abbastanza       Molto
# 13                    Poco  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 14              Moltissimo  Moltissimo       Molto  Moltissimo       Molto
# 15                   Molto       Molto       Molto  Moltissimo  Moltissimo
# 16              Abbastanza  Abbastanza        Poco  Abbastanza  Abbastanza
# 17                   Molto       Molto  Abbastanza  Abbastanza       Molto
# 18              Moltissimo  Moltissimo       Molto       Molto       Molto
# 19              Moltissimo  Moltissimo  Abbastanza       Molto  Moltissimo
# 20                     NaN         NaN         NaN         NaN         NaN
# 21              Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 22              Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 23              Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 24                     NaN         NaN         NaN         NaN         NaN
# 25                   Molto  Moltissimo  Moltissimo       Molto       Molto
# 26              Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 27              Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 28              Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
#
# 77        Molto  Moltissimo
# 78        Molto       Molto
# 79       Niente        Poco
# 80   Abbastanza  Moltissimo
# 81         Poco  Abbastanza
# 82        Molto       Molto
# 83         Poco        Poco
# 84        Molto  Moltissimo
# 85   Moltissimo  Moltissimo
# 86   Abbastanza       Molto
# 87        Molto       Molto
# 88         Poco  Moltissimo
# 89   Moltissimo  Moltissimo
# 90   Moltissimo  Moltissimo
# 91        Molto       Molto
# 92   Moltissimo  Abbastanza
# 93   Moltissimo  Moltissimo
# 94         Poco  Moltissimo
# 95   Abbastanza  Moltissimo
# 96   Moltissimo  Abbastanza
# 97   Abbastanza  Moltissimo
# 98   Moltissimo  Moltissimo
# 99   Abbastanza  Moltissimo
# 100  Moltissimo  Moltissimo
# 101  Moltissimo  Moltissimo
# 102       Molto       Molto
#
# [103 rows x 7 columns]

# %%
[u"Moltissimo",u"Molto",u"Abbastanza",u"Poco",u"Niente",u"Non so / Non risponde"]

# Gather data
agree_b = {}
for k,i in enumerate(agree_columns):
    agree_b[k] = agree[i].value_counts()
    print "Data:",agree_options[k]
    print agree_b[k]
    print
    print "Data %:",agree_options[k]
    print agree[i].value_counts(normalize=True)*100
    print

moltissimo = []
molto = []
abbastanza = []
poco = []
niente = []
nonso = []

for k,i in enumerate(agree_columns):
    agree_presents = agree_b[k].index.tolist()
    # Check for empty values, and put a 0 instead
    if u"Moltissimo" not in agree_presents:
        moltissimo.append(0)
    if u"Molto" not in agree_presents:
        molto.append(0)
    if u"Abbastanza" not in agree_presents:
        abbastanza.append(0)
    if u"Poco" not in agree_presents:
        poco.append(0)
    if u"Niente" not in agree_presents:
        niente.append(0)
    if u"Non so / Non risponde" not in agree_presents:
        nonso.append(0)
        
    for j in agree_presents:
        if j == u"Moltissimo":
            moltissimo.append(agree_b[k].ix[u"Moltissimo"])
        elif j == u"Molto":
            molto.append(agree_b[k].ix[u"Molto"])
        elif j == u"Abbastanza":
            abbastanza.append(agree_b[k].ix[u"Abbastanza"])
        elif j == u"Poco":
            poco.append(agree_b[k].ix[u"Poco"])
        elif j == u"Niente":
            niente.append(agree_b[k].ix[u"Niente"])
        elif j == u"Non so / Non risponde":
            nonso.append(agree_b[k].ix[u"Non so / Non risponde"])
            
# Plot the data
plt.figure(figsize=(12,6))
plt.xlabel('Frasi')
plt.ylabel('Persone')
plt.title("Maker: Quanto sono importanti per te lo scambio, la condivisione e la collaborazione rispetto a...")
plt.xticks(range(len(agree_options)),agree_options,rotation=90)
ind = np.arange(len(agree_columns))       # the x locations for the groups
width = 0.15                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 6) # Set color palette
rect1 = plt.bar(ind,moltissimo,width,color=my_colors[0],align='center') # Plot moltissimo
rect2 = plt.bar(ind+width,molto,width,color=my_colors[1],align='center') # Plot molto 
rect3 = plt.bar(ind+width*2,abbastanza,width,color=my_colors[2],align='center') # Plot abbastanza
rect4 = plt.bar(ind+width*3,poco,width,color=my_colors[3],align='center') # Plot poco
rect5 = plt.bar(ind+width*4,niente,width,color=my_colors[4],align='center') # Plot niente
rect6 = plt.bar(ind+width*5,nonso,width,color=my_colors[5],align='center') # Plot non so
plt.legend( (rect1, rect2, rect3, rect4, rect5, rect6), agree_types )
plt.savefig("pdf/Q030-MakerAccordo01.pdf")
# Out:
# Data: Informazioni di carattere generale sul making e la comunità dei maker
# Moltissimo               45
# Molto                    35
# Abbastanza               15
# Non so / Non risponde     2
# Poco                      2
# dtype: int64
# Data %: Informazioni di carattere generale sul making e la comunità dei maker
# Moltissimo               43.689320
# Molto                    33.980583
# Abbastanza               14.563107
# Non so / Non risponde     1.941748
# Poco                      1.941748
# dtype: float64
#
# Data: Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione
# Moltissimo    58
# Molto         32
# Abbastanza     9
# Poco           1
# dtype: int64
#
# Data %: Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione
# Moltissimo    56.310680
# Molto         31.067961
# Abbastanza     8.737864
# Poco           0.970874
# dtype: float64
#
# Data: Files e dati relativi a progetti esistenti
# Moltissimo               29
# Abbastanza               27
# Molto                    27
# Poco                     11
# Niente                    2
# Non so / Non risponde     1
# dtype: int64
#
# Data %: Files e dati relativi a progetti esistenti
# Moltissimo               28.155340
# Abbastanza               26.213592
# Molto                    26.213592
# Poco                     10.679612
# Niente                    1.941748
# Non so / Non risponde     0.970874
# dtype: float64
#
# Data: Sviluppo di nuovi progetti
# Moltissimo    46
# Molto         30
# Abbastanza    17
# Poco           5
# Niente         1
# dtype: int64
#
# Data %: Sviluppo di nuovi progetti
# Moltissimo    44.660194
# Molto         29.126214
# Abbastanza    16.504854
# Poco           4.854369
# Niente         0.970874
# dtype: float64
#
# Data: Tecnologie, strumenti, macchine e attrezzature
# Moltissimo    45
# Molto         33
# Abbastanza    17
# Poco           5
# dtype: int64
#
# Data %: Tecnologie, strumenti, macchine e attrezzature
# Moltissimo    43.689320
# Molto         32.038835
# Abbastanza    16.504854
# Poco           4.854369
# dtype: float64
#
# Data: Spazi e ambienti di lavoro
# Moltissimo               45
# Molto                    28
# Abbastanza               18
# Poco                      7
# Non so / Non risponde     1
# Niente                    1
# dtype: int64
#
# Data %: Spazi e ambienti di lavoro
# Moltissimo               43.689320
# Molto                    27.184466
# Abbastanza               17.475728
# Poco                      6.796117
# Non so / Non risponde     0.970874
# Niente                    0.970874
# dtype: float64
#
# Data: Organizzazione di nuove iniziative
# Moltissimo               51
# Molto                    29
# Abbastanza               14
# Poco                      4
# Non so / Non risponde     1
# dtype: int64
#
# Data %: Organizzazione di nuove iniziative
# Moltissimo               49.514563
# Molto                    28.155340
# Abbastanza               13.592233
# Poco                      3.883495
# Non so / Non risponde     0.970874
# dtype: float64
