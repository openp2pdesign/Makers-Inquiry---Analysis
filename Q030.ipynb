# %% [markdown]
# # Q029 - Quanto sono importanti per te lo scambio, la condivisione e la collaborazione rispetto a...

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q030[SQ001] - Q030[SQ007]

agree_columns = ['Q030[SQ001]','Q030[SQ002]','Q030[SQ003]','Q030[SQ004]','Q030[SQ005]','Q030[SQ006]','Q030[SQ007]']
agree_options = [u"Informazioni di carattere generale sul making e la comunità dei maker",
                 u"Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione",
                 u"Files e dati relativi a progetti esistenti",
                 u"Sviluppo di nuovi progetti",
                 u"Tecnologie, strumenti, macchine e attrezzature",
                 u"Spazi e ambienti di lavoro",
                 u"Organizzazione di nuove iniziative"]
agree = data[agree_columns]
agree_types = [u"Moltissimo",u"Molto",u"Abbastanza",u"Poco",u"Niente",u"Non so / Non risponde"]

# %%
agree
# Out:
#     Q030[SQ001] Q030[SQ002] Q030[SQ003] Q030[SQ004] Q030[SQ005] Q030[SQ006]  \
# 0         Molto       Molto       Molto       Molto       Molto       Molto
# 1    Moltissimo  Moltissimo  Moltissimo       Molto  Moltissimo  Moltissimo
# 2          Poco  Moltissimo        Poco  Moltissimo  Moltissimo  Moltissimo
# 3         Molto       Molto       Molto  Moltissimo  Abbastanza  Abbastanza
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# 5         Molto       Molto  Abbastanza       Molto       Molto  Moltissimo
# 6         Molto  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 7    Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 8    Moltissimo  Moltissimo        Poco  Abbastanza  Abbastanza       Molto
# 9    Moltissimo  Abbastanza  Abbastanza  Abbastanza  Abbastanza  Moltissimo
# 10   Moltissimo       Molto  Abbastanza  Moltissimo  Abbastanza  Moltissimo
# 11   Moltissimo  Moltissimo       Molto       Molto  Abbastanza  Moltissimo
# 12   Abbastanza       Molto  Abbastanza  Abbastanza       Molto  Abbastanza
# 13         Poco  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 14   Moltissimo  Moltissimo       Molto  Moltissimo       Molto  Moltissimo
# 15        Molto       Molto       Molto  Moltissimo  Moltissimo  Moltissimo
# 16   Abbastanza  Abbastanza        Poco  Abbastanza  Abbastanza  Abbastanza
# 17        Molto       Molto  Abbastanza  Abbastanza       Molto       Molto
# 18   Moltissimo  Moltissimo       Molto       Molto       Molto       Molto
# 19   Moltissimo  Moltissimo  Abbastanza       Molto  Moltissimo  Abbastanza
# 20          NaN         NaN         NaN         NaN         NaN         NaN
# 21   Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 22   Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 23   Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 24          NaN         NaN         NaN         NaN         NaN         NaN
# 25        Molto  Moltissimo  Moltissimo       Molto       Molto       Molto
# 26   Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
#
# 105  Non so / Non risponde
# 106                  Molto
# 107             Moltissimo
# 108             Moltissimo
# 109                   Poco
# 110                  Molto
# 111             Moltissimo
# 112             Moltissimo
# 113             Moltissimo
# 114                  Molto
# 115             Moltissimo
# 116                  Molto
# 117             Abbastanza
# 118                  Molto
# 119             Moltissimo
# 120             Moltissimo
# 121             Abbastanza
# 122                  Molto
# 123             Moltissimo
# 124             Abbastanza
# 125                    NaN
# 126             Moltissimo
# 127                  Molto
# 128             Abbastanza
# 129             Abbastanza
# 130                  Molto
# 131             Moltissimo
# 132             Moltissimo
# 133             Moltissimo
#
# [134 rows x 7 columns]

# %%
[u"Moltissimo",u"Molto",u"Abbastanza",u"Poco",u"Niente",u"Non so / Non risponde"]

# Gather data
agree_b = {}
for k,i in enumerate(agree_columns):
    agree_b[k] = agree[i].value_counts()
    print "Data:",agree_options[k]
    print agree_b[k]
    print
    print "Data %:",agree_options[k]
    print agree[i].value_counts(normalize=True)*100
    print

moltissimo = []
molto = []
abbastanza = []
poco = []
niente = []
nonso = []

for k,i in enumerate(agree_columns):
    agree_presents = agree_b[k].index.tolist()
    # Check for empty values, and put a 0 instead
    if u"Moltissimo" not in agree_presents:
        moltissimo.append(0)
    if u"Molto" not in agree_presents:
        molto.append(0)
    if u"Abbastanza" not in agree_presents:
        abbastanza.append(0)
    if u"Poco" not in agree_presents:
        poco.append(0)
    if u"Niente" not in agree_presents:
        niente.append(0)
    if u"Non so / Non risponde" not in agree_presents:
        nonso.append(0)
        
    for j in agree_presents:
        if j == u"Moltissimo":
            moltissimo.append(agree_b[k].ix[u"Moltissimo"])
        elif j == u"Molto":
            molto.append(agree_b[k].ix[u"Molto"])
        elif j == u"Abbastanza":
            abbastanza.append(agree_b[k].ix[u"Abbastanza"])
        elif j == u"Poco":
            poco.append(agree_b[k].ix[u"Poco"])
        elif j == u"Niente":
            niente.append(agree_b[k].ix[u"Niente"])
        elif j == u"Non so / Non risponde":
            nonso.append(agree_b[k].ix[u"Non so / Non risponde"])
            
# Plot the data
plt.figure(figsize=(12,6))
plt.xlabel('Frasi')
plt.ylabel('Persone')
plt.title("Maker: Quanto sono importanti per te lo scambio, la condivisione e la collaborazione rispetto a...")
plt.xticks(range(len(agree_options)),agree_options,rotation=90)
ind = np.arange(len(agree_columns))       # the x locations for the groups
width = 0.15                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 6) # Set color palette
rect1 = plt.bar(ind,moltissimo,width,color=my_colors[0],align='center') # Plot moltissimo
rect2 = plt.bar(ind+width,molto,width,color=my_colors[1],align='center') # Plot molto 
rect3 = plt.bar(ind+width*2,abbastanza,width,color=my_colors[2],align='center') # Plot abbastanza
rect4 = plt.bar(ind+width*3,poco,width,color=my_colors[3],align='center') # Plot poco
rect5 = plt.bar(ind+width*4,niente,width,color=my_colors[4],align='center') # Plot niente
rect6 = plt.bar(ind+width*5,nonso,width,color=my_colors[5],align='center') # Plot non so
plt.legend( (rect1, rect2, rect3, rect4, rect5, rect6), agree_types )
plt.savefig("pdf/Q030-MakerAccordo01.pdf")
# Out:
# Data: Informazioni di carattere generale sul making e la comunità dei maker
# Moltissimo               63
# Molto                    43
# Abbastanza               19
# Poco                      3
# Non so / Non risponde     2
# dtype: int64
# Data %: Informazioni di carattere generale sul making e la comunità dei maker
# Moltissimo               47.014925
# Molto                    32.089552
# Abbastanza               14.179104
# Poco                      2.238806
# Non so / Non risponde     1.492537
# dtype: float64
#
# Data: Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione
# Moltissimo    78
# Molto         38
# Abbastanza    13
# Poco           2
# dtype: int64
#
# Data %: Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione
# Moltissimo    58.208955
# Molto         28.358209
# Abbastanza     9.701493
# Poco           1.492537
# dtype: float64
#
# Data: Files e dati relativi a progetti esistenti
# Moltissimo               46
# Abbastanza               35
# Molto                    32
# Poco                     12
# Niente                    2
# Non so / Non risponde     1
# dtype: int64
#
# Data %: Files e dati relativi a progetti esistenti
# Moltissimo               34.328358
# Abbastanza               26.119403
# Molto                    23.880597
# Poco                      8.955224
# Niente                    1.492537
# Non so / Non risponde     0.746269
# dtype: float64
#
# Data: Sviluppo di nuovi progetti
# Moltissimo    63
# Molto         38
# Abbastanza    22
# Poco           6
# Niente         1
# dtype: int64
#
# Data %: Sviluppo di nuovi progetti
# Moltissimo    47.014925
# Molto         28.358209
# Abbastanza    16.417910
# Poco           4.477612
# Niente         0.746269
# dtype: float64
#
# Data: Tecnologie, strumenti, macchine e attrezzature
# Moltissimo    64
# Molto         39
# Abbastanza    22
# Poco           6
# dtype: int64
#
# Data %: Tecnologie, strumenti, macchine e attrezzature
# Moltissimo    47.761194
# Molto         29.104478
# Abbastanza    16.417910
# Poco           4.477612
# dtype: float64
#
# Data: Spazi e ambienti di lavoro
# Moltissimo               59
# Molto                    37
# Abbastanza               25
# Poco                      8
# Non so / Non risponde     1
# Niente                    1
# dtype: int64
#
# Data %: Spazi e ambienti di lavoro
# Moltissimo               44.029851
# Molto                    27.611940
# Abbastanza               18.656716
# Poco                      5.970149
# Non so / Non risponde     0.746269
# Niente                    0.746269
# dtype: float64
#
# Data: Organizzazione di nuove iniziative
# Moltissimo               65
# Molto                    38
# Abbastanza               19
# Poco                      5
# Non so / Non risponde     2
# dtype: int64
#
# Data %: Organizzazione di nuove iniziative
# Moltissimo               48.507463
# Molto                    28.358209
# Abbastanza               14.179104
# Poco                      3.731343
# Non so / Non risponde     1.492537
# dtype: float64
