# %% [markdown]
# # Q030 - Quanto sono importanti per te lo scambio, la condivisione e la collaborazione rispetto a...

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q030[SQ001] - Q030[SQ007]

agree_columns = ['Q030[SQ001]','Q030[SQ002]','Q030[SQ003]','Q030[SQ004]','Q030[SQ005]','Q030[SQ006]','Q030[SQ007]']
agree_options = [u"Informazioni di carattere generale sul making e la comunità dei maker",
                 u"Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione",
                 u"Files e dati relativi a progetti esistenti",
                 u"Sviluppo di nuovi progetti",
                 u"Tecnologie, strumenti, macchine e attrezzature",
                 u"Spazi e ambienti di lavoro",
                 u"Organizzazione di nuove iniziative"]
agree = data[agree_columns]
agree_types = [u"Moltissimo",u"Molto",u"Abbastanza",u"Poco",u"Niente",u"Non so / Non risponde", "Nessuna risposta"]
agree.replace(np.nan, 'Nessuna risposta', inplace=True) # Simplify text
# Out:
# -c:13: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %%
#agree

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Gather data
agree_b = {}
for k,i in enumerate(agree_columns):
    agree_b[k] = agree[i].value_counts()
    print "Data:",agree_options[k].encode('utf-8')
    print agree_b[k]
    print
    print "Data %:",agree_options[k].encode('utf-8')
    print agree[i].value_counts(normalize=True)*100
    print

# %%
# Save+show the output to a text file
# %save Q030-MakerAccordo.py str(output)
shutil.move("Q030-MakerAccordo.py", "text/Q030-MakerAccordo.txt")
# Out:
# The following commands were written to file `Q030-MakerAccordo.py`:
# Data: Informazioni di carattere generale sul making e la comunità dei maker
# Moltissimo               63
# Molto                    43
# Abbastanza               19
# Nessuna risposta          4
# Poco                      3
# Non so / Non risponde     2
# dtype: int64
#
# Data %: Informazioni di carattere generale sul making e la comunità dei maker
# Moltissimo               47.014925
# Molto                    32.089552
# Abbastanza               14.179104
# Nessuna risposta          2.985075
# Poco                      2.238806
# Non so / Non risponde     1.492537
# dtype: float64
#
# Data: Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione
# Moltissimo          78
# Molto               38
# Abbastanza          13
# Nessuna risposta     3
# Poco                 2
# dtype: int64
#
# Data %: Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione
# Moltissimo          58.208955
# Molto               28.358209
# Abbastanza           9.701493
# Nessuna risposta     2.238806
# Poco                 1.492537
# dtype: float64
#
# Data: Files e dati relativi a progetti esistenti
# Moltissimo               46
# Abbastanza               35
# Molto                    32
# Poco                     12
# Nessuna risposta          6
# Niente                    2
# Non so / Non risponde     1
# dtype: int64
#
# Data %: Files e dati relativi a progetti esistenti
# Moltissimo               34.328358
# Abbastanza               26.119403
# Molto                    23.880597
# Poco                      8.955224
# Nessuna risposta          4.477612
# Niente                    1.492537
# Non so / Non risponde     0.746269
# dtype: float64
#
# Data: Sviluppo di nuovi progetti
# Moltissimo          63
# Molto               38
# Abbastanza          22
# Poco                 6
# Nessuna risposta     4
# Niente               1
# dtype: int64
#
# Data %: Sviluppo di nuovi progetti
# Moltissimo          47.014925
# Molto               28.358209
# Abbastanza          16.417910
# Poco                 4.477612
# Nessuna risposta     2.985075
# Niente               0.746269
# dtype: float64
#
# Data: Tecnologie, strumenti, macchine e attrezzature
# Moltissimo          64
# Molto               39
# Abbastanza          22
# Poco                 6
# Nessuna risposta     3
# dtype: int64
#
# Data %: Tecnologie, strumenti, macchine e attrezzature
# Moltissimo          47.761194
# Molto               29.104478
# Abbastanza          16.417910
# Poco                 4.477612
# Nessuna risposta     2.238806
# dtype: float64
#
# Data: Spazi e ambienti di lavoro
# Moltissimo               59
# Molto                    37
# Abbastanza               25
# Poco                      8
# Nessuna risposta          3
# Non so / Non risponde     1
# Niente                    1
# dtype: int64
#
# Data %: Spazi e ambienti di lavoro
# Moltissimo               44.029851
# Molto                    27.611940
# Abbastanza               18.656716
# Poco                      5.970149
# Nessuna risposta          2.238806
# Non so / Non risponde     0.746269
# Niente                    0.746269
# dtype: float64
#
# Data: Organizzazione di nuove iniziative
# Moltissimo               65
# Molto                    38
# Abbastanza               19
# Nessuna risposta          5
# Poco                      5
# Non so / Non risponde     2
# dtype: int64
#
# Data %: Organizzazione di nuove iniziative
# Moltissimo               48.507463
# Molto                    28.358209
# Abbastanza               14.179104
# Nessuna risposta          3.731343
# Poco                      3.731343
# Non so / Non risponde     1.492537
# dtype: float64

# %%
moltissimo = []
molto = []
abbastanza = []
poco = []
niente = []
nonso = []
nanvalue = []

for k,i in enumerate(agree_columns):
    agree_presents = agree_b[k].index.tolist()
    # Check for empty values, and put a 0 instead
    if u"Moltissimo" not in agree_presents:
        moltissimo.append(0)
    if u"Molto" not in agree_presents:
        molto.append(0)
    if u"Abbastanza" not in agree_presents:
        abbastanza.append(0)
    if u"Poco" not in agree_presents:
        poco.append(0)
    if u"Niente" not in agree_presents:
        niente.append(0)
    if u"Non so / Non risponde" not in agree_presents:
        nonso.append(0)
    if "Nessuna risposta" not in agree_presents:
        nanvalue.append(0)
        
    for j in agree_presents:
        if j == u"Moltissimo":
            moltissimo.append(agree_b[k].ix[u"Moltissimo"])
        elif j == u"Molto":
            molto.append(agree_b[k].ix[u"Molto"])
        elif j == u"Abbastanza":
            abbastanza.append(agree_b[k].ix[u"Abbastanza"])
        elif j == u"Poco":
            poco.append(agree_b[k].ix[u"Poco"])
        elif j == u"Niente":
            niente.append(agree_b[k].ix[u"Niente"])
        elif j == u"Non so / Non risponde":
            nonso.append(agree_b[k].ix[u"Non so / Non risponde"])
        elif j == "Nessuna risposta":
            nanvalue.append(agree_b[k].ix[j])

# %%
# Plot the data
plt.figure(figsize=(12,6))
plt.xlabel('Frasi', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title("Quanto sono importanti per te lo scambio, la condivisione e la collaborazione rispetto a...", fontsize=18, y=1.02)
plt.xticks(range(len(agree_options)),agree_options,rotation=90)
ind = np.arange(len(agree_columns))       # the x locations for the groups
width = 0.10                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 7) # Set color palette
rect1 = plt.bar(ind,moltissimo,width,color=my_colors[0],align='center') # Plot moltissimo
rect2 = plt.bar(ind+width,molto,width,color=my_colors[1],align='center') # Plot molto 
rect3 = plt.bar(ind+width*2,abbastanza,width,color=my_colors[2],align='center') # Plot abbastanza
rect4 = plt.bar(ind+width*3,poco,width,color=my_colors[3],align='center') # Plot poco
rect5 = plt.bar(ind+width*4,niente,width,color=my_colors[4],align='center') # Plot niente
rect6 = plt.bar(ind+width*5,nonso,width,color=my_colors[5],align='center') # Plot non so
rect7 = plt.bar(ind+width*6,nonso,width,color=my_colors[6],align='center') # Plot NaN
plt.legend( (rect1, rect2, rect3, rect4, rect5, rect6, rect7), agree_types )
plt.savefig("svg/Q030-MakerAccordo.svg")
plt.savefig("png/Q030-MakerAccordo.png")
plt.savefig("pdf/Q030-MakerAccordo.pdf")
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:1279: UserWarning: findfont: Font family ['Source Sans Pro'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
