# %% [markdown]
# # Q029 - Quanto sono importanti per te lo scambio, la condivisione e la collaborazione rispetto a...

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers.csv", encoding="utf-8")

# %%
# Re-format colums to fix a mistake
# Comment/delete this if not part of the Italian research
substitutes = ['id','submitdate','lastpage','startlanguage','startdate','datestamp','ipaddr',
               'Q001','Q002','Q003','Q004','Q005','Q006','Q007','Q007[other]','Q008','Q009[SQ001]',
               'Q009[SQ002]','Q009[SQ003]','Q009[SQ004]','Q009[SQ005]','Q009[SQ006]','Q009[other]',
               'Q010','Q011','Q011[other]','Q012','Q013','Q014','Q015','Q016','Q016[other]','Q017',
               'Q018','Q019[SQ001]','Q019[SQ002]','Q019[SQ003]','Q019[SQ004]','Q019[SQ005]','Q019[SQ006]',
               'Q019[SQ007]','Q019[SQ008]','Q019[SQ009]','Q019[other]','Q020[SQ001]','Q021[SQ001]',
               'Q021[SQ002]','Q021[SQ003]','Q021[SQ004]','Q021[SQ005]','Q022[SQ001]','Q022[SQ002]',
               'Q022[SQ003]','Q022[SQ004]','Q022[SQ005]','Q023[SQ001]','Q023[SQ002]','Q023[SQ003]',
               'Q023[SQ004]','Q023[SQ005]','Q024[SQ001]','Q024[SQ002]','Q024[SQ003]','Q024[SQ004]',
               'Q024[SQ005]','Q024[other]','Q025','Q026','Q027[SQ001]','Q027[SQ002]','Q027[SQ003]',
               'Q027[SQ004]','Q027[SQ005]','Q027[SQ006]','Q027[SQ007]','Q027[SQ008]','Q027[other]',
               'Q028[SQ001]','Q028[SQ002]','Q028[SQ003]','Q028[SQ004]','Q028[SQ005]','Q028[SQ006]',
               'Q028[SQ007]','Q028[SQ008]','Q028[SQ009]','Q028[SQ010]','Q028[SQ011]','Q028[other]',
               'Q029[SQ001]','Q029[SQ002]','Q029[SQ003]','Q029[SQ004]','Q029[SQ005]','Q030[SQ001]',
               'Q030[SQ002]','Q030[SQ003]','Q030[SQ004]','Q030[SQ005]','Q030[SQ006]','Q030[SQ007]',
               'Q031','Q032','Q032[other]','Q033[SQ001]','Q033[SQ002]','Q033[SQ003]','Q033[SQ004]',
               'Q033[other]','Q034','Q035','Q036[SQ001]','Q036[SQ002]','Q036[SQ013]','Q036[SQ003]',
               'Q036[SQ004]','Q036[SQ005]','Q036[SQ006]','Q036[SQ007]','Q036[SQ008]','Q036[SQ009]',
               'Q036[SQ010]','Q036[SQ011]','Q036[SQ012]','Q036[other]','Q037[SQ001]','Q037[SQ002]',
               'Q037[SQ003]','Q037[SQ004]','Q037[SQ005]','Q037[other]','Q038','Q039[SQ001]','Q039[SQ002]',
               'Q039[SQ003]','Q039[SQ004]','Q039[SQ005]','Q039[other]','Q040[SQ001]','Q040[SQ002]',
               'Q040[SQ003]','Q041[SQ001]','Q041[SQ002]','Q041[SQ003]','Q042[SQ001]','Q042[SQ002]',
               'Q042[SQ003]','Q042[SQ004]','Q042[other]','Q043[SQ001]','Q043[SQ002]','Q043[SQ003]',
               'Q043[SQ004]','Q043[SQ005]','Q043[SQ006]','Q043[other]','Q044[SQ001]','Q044[SQ002]',
               'Q044[SQ003]','Q044[SQ004]','Q044[SQ005]','Q044[SQ006]','Q044[SQ007]','Q044[SQ008]',
               'Q044[SQ009]','Q045','Q046','Q047[SQ001]','Q047[SQ002]','Q047[SQ003]','Q047[SQ004]',
               'Q047[other]','Q048[SQ001]','Q048[SQ002]','Q048[SQ003]','Q048[SQ004]','Q048[SQ005]',
               'Q048[other]','Q049[SQ001]','Q049[SQ002]','Q049[SQ003]','Q049[SQ004]','Q049[other]',
               'Q050[SQ001]','Q050[SQ002]','Q050[SQ003]','Q050[SQ004]','Q050[SQ005]','Q050[SQ006]',
               'Q050[SQ007]','Q050[SQ008]','Q050[other]','Q051[SQ001]','Q051[SQ002]','Q051[SQ003]',
               'Q051[SQ004]','Q051[SQ005]','Q051[SQ006]','Q051[other]','Q052[SQ001]','Q052[SQ002]',
               'Q052[SQ003]','Q052[SQ004]','Q052[SQ005]','Q052[SQ006]','Q052[SQ007]','Q052[SQ008]',
               'Q052[SQ009]','Q052[SQ010]','Q052[SQ011]','Q052[other]','Q053[SQ001]','Q053[SQ002]',
               'Q053[SQ003]','Q053[SQ004]','Q053[other]','Q054[SQ001]','Q054[SQ002]','Q054[SQ003]',
               'Q054[SQ004]','Q054[SQ005]','Q054[SQ006]','Q054[SQ007]','Q054[SQ008]','Q054[SQ009]',
               'Q054[SQ010]','Q054[other]','Q055[SQ001]','Q055[SQ002]','Q055[SQ003]','Q055[SQ004]',
               'Q055[SQ005]','Q055[SQ006]','Q055[SQ007]','Q055[SQ008]','Q055[SQ009]','Q055[SQ010]',
               'Q055[other]','Q056[SQ001]','Q056[SQ002]','Q056[SQ003]','Q056[SQ004]','Q056[SQ005]',
               'Q056[other]','Q057[SQ001]','Q057[SQ002]','Q057[other]','Q058[SQ001]','Q058[SQ002]',
               'Q058[SQ003]','Q058[SQ004]','Q058[SQ005]','Q058[other]','Q059[SQ001]','Q059[SQ002]',
               'Q059[SQ003]','Q059[other]','Q060','Q061','Q062[SQ001]','Q062[SQ002]','Q062[SQ003]',
               'Q062[SQ004]','Q062[SQ005]','Q062[other]','Q063[SQ001]','Q063[SQ002]','Q063[SQ003]',
               'Q064','Q065','Q065[filecount]','Q066[SQ001]','Q066[SQ002]','Q066[SQ003]','Q067','Q067[filecount]'
               ]

data.columns = substitutes

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q030[SQ001] - Q030[SQ007]

agree_columns = ['Q030[SQ001]','Q030[SQ002]','Q030[SQ003]','Q030[SQ004]','Q030[SQ005]','Q030[SQ006]','Q030[SQ007]']
agree_options = [u"Informazioni di carattere generale sul making e la comunità dei maker",
                 u"Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione",
                 u"Files e dati relativi a progetti esistenti",
                 u"Sviluppo di nuovi progetti",
                 u"Tecnologie, strumenti, macchine e attrezzature",
                 u"Spazi e ambienti di lavoro",
                 u"Organizzazione di nuove iniziative"]
agree = data[agree_columns]
agree_types = [u"Moltissimo",u"Molto",u"Abbastanza",u"Poco",u"Niente",u"Non so / Non risponde"]

# %%
agree
# Out:
#    Q030[SQ001] Q030[SQ002] Q030[SQ003] Q030[SQ004] Q030[SQ005] Q030[SQ006]  \
# 0        Molto       Molto       Molto       Molto       Molto       Molto
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4   Moltissimo  Moltissimo  Moltissimo       Molto  Moltissimo  Moltissimo
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN         NaN         NaN
# 14        Poco  Moltissimo        Poco  Moltissimo  Moltissimo  Moltissimo
# 15       Molto       Molto       Molto  Moltissimo  Abbastanza  Abbastanza
# 16         NaN         NaN         NaN         NaN         NaN         NaN
# 17       Molto       Molto  Abbastanza       Molto       Molto  Moltissimo
# 18         NaN         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN         NaN         NaN
# 20       Molto  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 21         NaN         NaN         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN         NaN         NaN
# 23  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 24  Moltissimo  Moltissimo        Poco  Abbastanza  Abbastanza       Molto
# 25         NaN         NaN         NaN         NaN         NaN         NaN
# 26  Moltissimo  Abbastanza  Abbastanza  Abbastanza  Abbastanza  Moltissimo
# 27  Moltissimo       Molto  Abbastanza  Moltissimo  Abbastanza  Moltissimo
# 28         NaN         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN         NaN
# 30         NaN         NaN         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN         NaN         NaN
# 33         NaN         NaN         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN         NaN         NaN
# 35         NaN         NaN         NaN         NaN         NaN         NaN
# 36  Moltissimo  Moltissimo       Molto       Molto  Abbastanza  Moltissimo
# 37         NaN         NaN         NaN         NaN         NaN         NaN
# 38         NaN         NaN         NaN         NaN         NaN         NaN
# 39  Abbastanza       Molto  Abbastanza  Abbastanza       Molto  Abbastanza
# 40        Poco  Moltissimo  Moltissimo  Moltissimo  Moltissimo  Moltissimo
# 41         NaN         NaN         NaN         NaN         NaN         NaN
# 42         NaN         NaN         NaN         NaN         NaN         NaN
# 43  Moltissimo  Moltissimo       Molto  Moltissimo       Molto  Moltissimo
# 44       Molto       Molto       Molto  Moltissimo  Moltissimo  Moltissimo
# 45         NaN         NaN         NaN         NaN         NaN         NaN
# 46         NaN         NaN         NaN         NaN         NaN         NaN
# 47         NaN         NaN         NaN         NaN         NaN         NaN
# 48  Abbastanza  Abbastanza        Poco  Abbastanza  Abbastanza  Abbastanza
# 49       Molto       Molto  Abbastanza  Abbastanza       Molto       Molto
# 50  Moltissimo  Moltissimo       Molto       Molto       Molto       Molto
# 51         NaN         NaN         NaN         NaN         NaN         NaN
# 52         NaN         NaN         NaN         NaN         NaN         NaN
# 53         NaN         NaN         NaN         NaN         NaN         NaN
# 54         NaN         NaN         NaN         NaN         NaN         NaN
# 55         NaN         NaN         NaN         NaN         NaN         NaN
# 56         NaN         NaN         NaN         NaN         NaN         NaN
# 57       Molto  Moltissimo  Abbastanza       Molto       Molto       Molto
# 58         NaN         NaN         NaN         NaN         NaN         NaN
# 59  Moltissimo  Moltissimo  Abbastanza       Molto  Moltissimo  Abbastanza
#            ...         ...         ...         ...         ...         ...
#
#    Q030[SQ007]
# 0        Molto
# 1          NaN
# 2          NaN
# 3          NaN
# 4   Moltissimo
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14  Moltissimo
# 15  Abbastanza
# 16         NaN
# 17  Moltissimo
# 18         NaN
# 19         NaN
# 20  Moltissimo
# 21         NaN
# 22         NaN
# 23  Moltissimo
# 24  Abbastanza
# 25         NaN
# 26       Molto
# 27  Moltissimo
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36  Moltissimo
# 37         NaN
# 38         NaN
# 39       Molto
# 40        Poco
# 41         NaN
# 42         NaN
# 43  Moltissimo
# 44  Moltissimo
# 45         NaN
# 46         NaN
# 47         NaN
# 48  Abbastanza
# 49       Molto
# 50       Molto
# 51         NaN
# 52         NaN
# 53         NaN
# 54         NaN
# 55         NaN
# 56         NaN
# 57       Molto
# 58         NaN
# 59  Moltissimo
#            ...
#
# [175 rows x 7 columns]

# %%
[u"Moltissimo",u"Molto",u"Abbastanza",u"Poco",u"Niente",u"Non so / Non risponde"]

# Gather data
agree_b = {}
for k,i in enumerate(agree_columns):
    agree_b[k] = agree[i].value_counts()
    print "Data:",agree_options[k]
    print agree_b[k]
    print
    print "Data %:",agree_options[k]
    print agree[i].value_counts(normalize=True)*100
    print

moltissimo = []
molto = []
abbastanza = []
poco = []
niente = []
nonso = []

for k,i in enumerate(agree_columns):
    agree_presents = agree_b[k].index.tolist()
    # Check for empty values, and put a 0 instead
    if u"Moltissimo" not in agree_presents:
        moltissimo.append(0)
    if u"Molto" not in agree_presents:
        molto.append(0)
    if u"Abbastanza" not in agree_presents:
        abbastanza.append(0)
    if u"Poco" not in agree_presents:
        poco.append(0)
    if u"Niente" not in agree_presents:
        niente.append(0)
    if u"Non so / Non risponde" not in agree_presents:
        nonso.append(0)
        
    for j in agree_presents:
        if j == u"Moltissimo":
            moltissimo.append(agree_b[k].ix[u"Moltissimo"])
        elif j == u"Molto":
            molto.append(agree_b[k].ix[u"Molto"])
        elif j == u"Abbastanza":
            abbastanza.append(agree_b[k].ix[u"Abbastanza"])
        elif j == u"Poco":
            poco.append(agree_b[k].ix[u"Poco"])
        elif j == u"Niente":
            niente.append(agree_b[k].ix[u"Niente"])
        elif j == u"Non so / Non risponde":
            nonso.append(agree_b[k].ix[u"Non so / Non risponde"])
            
# Plot the data
plt.figure(figsize=(12,6))
plt.xlabel('Frasi')
plt.ylabel('Persone')
plt.title("Maker: Quanto sono importanti per te lo scambio, la condivisione e la collaborazione rispetto a...")
plt.xticks(range(len(agree_options)),agree_options,rotation=90)
ind = np.arange(len(agree_columns))       # the x locations for the groups
width = 0.15                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 6) # Set color palette
rect1 = plt.bar(ind,moltissimo,width,color=my_colors[0],align='center') # Plot moltissimo
rect2 = plt.bar(ind+width,molto,width,color=my_colors[1],align='center') # Plot molto 
rect3 = plt.bar(ind+width*2,abbastanza,width,color=my_colors[2],align='center') # Plot abbastanza
rect4 = plt.bar(ind+width*3,poco,width,color=my_colors[3],align='center') # Plot poco
rect5 = plt.bar(ind+width*4,niente,width,color=my_colors[4],align='center') # Plot niente
rect6 = plt.bar(ind+width*5,nonso,width,color=my_colors[5],align='center') # Plot non so
plt.legend( (rect1, rect2, rect3, rect4, rect5, rect6), agree_types )
plt.savefig("pdf/Q030-MakerAccordo01.pdf")
# Out:
# Data: Informazioni di carattere generale sul making e la comunità dei maker
# Moltissimo               36
# Molto                    24
# Abbastanza               13
# Poco                      2
# Non so / Non risponde     1
# dtype: int64
# Data %: Informazioni di carattere generale sul making e la comunità dei maker
# Moltissimo               20.571429
# Molto                    13.714286
# Abbastanza                7.428571
# Poco                      1.142857
# Non so / Non risponde     0.571429
# dtype: float64
#
# Data: Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione
# Moltissimo    47
# Molto         24
# Abbastanza     5
# Poco           1
# dtype: int64
#
# Data %: Conoscenze tecniche e tecnologiche sui processi di progettazione e produzione
# Moltissimo    26.857143
# Molto         13.714286
# Abbastanza     2.857143
# Poco           0.571429
# dtype: float64
#
# Data: Files e dati relativi a progetti esistenti
# Moltissimo               25
# Abbastanza               22
# Molto                    19
# Poco                      8
# Niente                    2
# Non so / Non risponde     1
# dtype: int64
#
# Data %: Files e dati relativi a progetti esistenti
# Moltissimo               14.285714
# Abbastanza               12.571429
# Molto                    10.857143
# Poco                      4.571429
# Niente                    1.142857
# Non so / Non risponde     0.571429
# dtype: float64
#
# Data: Sviluppo di nuovi progetti
# Moltissimo    35
# Molto         26
# Abbastanza    12
# Poco           3
# dtype: int64
#
# Data %: Sviluppo di nuovi progetti
# Moltissimo    20.000000
# Molto         14.857143
# Abbastanza     6.857143
# Poco           1.714286
# dtype: float64
#
# Data: Tecnologie, strumenti, macchine e attrezzature
# Moltissimo    33
# Molto         30
# Abbastanza    12
# Poco           2
# dtype: int64
#
# Data %: Tecnologie, strumenti, macchine e attrezzature
# Moltissimo    18.857143
# Molto         17.142857
# Abbastanza     6.857143
# Poco           1.142857
# dtype: float64
#
# Data: Spazi e ambienti di lavoro
# Moltissimo               38
# Molto                    23
# Abbastanza               12
# Poco                      3
# Non so / Non risponde     1
# dtype: int64
#
# Data %: Spazi e ambienti di lavoro
# Moltissimo               21.714286
# Molto                    13.142857
# Abbastanza                6.857143
# Poco                      1.714286
# Non so / Non risponde     0.571429
# dtype: float64
#
# Data: Organizzazione di nuove iniziative
# Moltissimo               37
# Molto                    25
# Abbastanza               11
# Poco                      2
# Non so / Non risponde     1
# dtype: int64
#
# Data %: Organizzazione di nuove iniziative
# Moltissimo               21.142857
# Molto                    14.285714
# Abbastanza                6.285714
# Poco                      1.142857
# Non so / Non risponde     0.571429
# dtype: float64
