# %% [markdown]
# # Q051 - Quali sono le principali spese che devi affrontare per la tua attivitá?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q051[SQ001] - Q051[SQ006] - Q051[other]

business_columns = ['Q051[SQ001]','Q051[SQ002]','Q051[SQ003]','Q051[SQ004]',
                    'Q051[SQ005]','Q051[SQ006]']
business_options = ['Acquisto di materiali',
                  'Acquisto/affitto di tecnologie',
                  'Acquisto/affitto di luoghi',
                  'Consulenze',
                  'Comunicazione (anche web)',
                  'Utenze'
                  ]
business = data[business_columns]
business.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
business_other = data['Q051[other]'].str.lower().value_counts()
# Out:
# -c:13: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %%
business[0:4]
# Out:
#   Q051[SQ001] Q051[SQ002] Q051[SQ003] Q051[SQ004] Q051[SQ005] Q051[SQ006]
# 0          Si          Si          No          Si          No          No
# 1          Si          No          No          No          No          No
# 2          Si          No          No          No          No          No
# 3          Si          No          No          No          No          No

# %%
# Gather data
business_b = {}
for k,i in enumerate(business_columns):
    business_b[k] = business[i].value_counts(dropna=False)
    print "Data:",business_options[k]
    print business_b[k]
    print
    print "Data %:",business_options[k]
    print business[i].value_counts(normalize=True,dropna=False)*100
    print
    
yes = []
no = []
nanvalue = []

for k,i in enumerate(business_columns):
    business_presents = business_b[k].index.tolist()
    
    # Convert NaN to "NaN"
    for o,h in enumerate(business_presents):
        if type(h) is float:
            business_presents.pop(o)
            business_presents.append("NaN")
    
    # Reassign new list with "NaN"
    business_b[k].index = business_presents
    
    # Check for empty values, and put a 0 instead
    if "Si" not in business_presents:
        yes.append(0)
    if "No" not in business_presents:
        no.append(0)
    if "NaN" not in business_presents:
        nanvalue.append(0)
    
    for j in business_presents:
        if j == "Si":
            yes.append(business_b[k].ix["Si"])
        elif j == "No":
            no.append(business_b[k].ix["No"])
        elif j == "NaN":
            nanvalue.append(business_b[k].ix["NaN"])
# Out:
# Data: Acquisto di materiali
# Si     112
# No      20
# NaN      2
# dtype: int64
# Data %: Acquisto di materiali
# Si     83.582090
# No     14.925373
# NaN     1.492537
# dtype: float64
#
# Data: Acquisto/affitto di tecnologie
# No     79
# Si     53
# NaN     2
# dtype: int64
#
# Data %: Acquisto/affitto di tecnologie
# No     58.955224
# Si     39.552239
# NaN     1.492537
# dtype: float64
#
# Data: Acquisto/affitto di luoghi
# No     103
# Si      29
# NaN      2
# dtype: int64
#
# Data %: Acquisto/affitto di luoghi
# No     76.865672
# Si     21.641791
# NaN     1.492537
# dtype: float64
#
# Data: Consulenze
# No     120
# Si      12
# NaN      2
# dtype: int64
#
# Data %: Consulenze
# No     89.552239
# Si      8.955224
# NaN     1.492537
# dtype: float64
#
# Data: Comunicazione (anche web)
# No     99
# Si     33
# NaN     2
# dtype: int64
#
# Data %: Comunicazione (anche web)
# No     73.880597
# Si     24.626866
# NaN     1.492537
# dtype: float64
#
# Data: Utenze
# No     97
# Si     35
# NaN     2
# dtype: int64
#
# Data %: Utenze
# No     72.388060
# Si     26.119403
# NaN     1.492537
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Spese')
plt.ylabel('Persone')
plt.title(u'Quali sono le principali spese che devi affrontare per la tua attivitá?')
plt.xticks(range(len(business_options)+1),business_options,rotation=90)
ind = np.arange(len(business_columns))   # the x locations for the groups
width = 0.25                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 3) # Set color palette
rect1 = plt.bar(ind,yes,width,color=my_colors[1],align='center') # Plot Yes
rect2 = plt.bar(ind+width,no,width,color=my_colors[0],align='center') # Plot No 
rect3 = plt.bar(ind+width*2,nanvalue,width,color=my_colors[2],align='center') # Plot NaN
plt.legend( (rect1, rect2, rect3), ('Si', 'No', 'NaN') )
plt.savefig("pdf/Q051-MakerBusiness01.pdf")

# %%
# Get "other" data
business_other = data["Q051[other]"].str.lower().value_counts()
print "Data:"
print business_other
print ""
print "Data %:"
print data["Q051[other]"].str.lower().value_counts(normalize=True) * 100

# Plot bar
plt.figure(figsize=(8,6))
plt.title(u'Quali sono le principali spese che devi affrontare per la tua attivitá? Altro')
plt.xticks(range(len(business_other.index)),business_other.index,rotation=90)
plt.xlabel(u'Spese')
plt.ylabel('Persone')
ind = np.arange(len(business_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(business_other)) # Set color palette
rect1 = plt.bar(ind,business_other,width,color=my_colors,align='center')
plt.savefig("pdf/Q051-MakerBusiness02.pdf")
# Out:
# Data:
# tasse                         1
# gestione associazione         1
# stipendi                      1
# esposizioni ed eventi         1
# lavorazioni esterne           1
# esposizioni-mostre mercato    1
# utensili                      1
# acquisto attrezzature         1
# benzina, burocrazia.          1
# dtype: int64
#
# Data %:
# tasse                         0.746269
# gestione associazione         0.746269
# stipendi                      0.746269
# esposizioni ed eventi         0.746269
# lavorazioni esterne           0.746269
# esposizioni-mostre mercato    0.746269
# utensili                      0.746269
# acquisto attrezzature         0.746269
# benzina, burocrazia.          0.746269
# dtype: float64
