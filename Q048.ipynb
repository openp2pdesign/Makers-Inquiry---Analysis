# %% [markdown]
# # Q048 - Il risultato della tua attivitá é un'innovazione? Se sí, di che tipo?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q048[SQ001] - Q048[SQ005] - Q048[other]

innovation_columns = ['Q048[SQ001]','Q048[SQ002]','Q048[SQ003]','Q048[SQ004]','Q048[SQ005]']
innovation_options = ['Innovazione di prodotto',
                  'Innovazione di processo (progettazione, produzione, distribuzione)',
                  'Innovazione di sistema-prodotto (prodotto, servizio e processo)',
                  'Innovazione tecnologica',
                  'Innovazione sociale']
innovation = data[innovation_columns]
innovation.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
innovation_other = data['Q048[other]'].str.lower().value_counts()
# Out:
# -c:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#innovation[0:4]

# %%
# Gather data
innovation_b = {}
for k,i in enumerate(innovation_columns):
    innovation_b[k] = innovation[i].value_counts(dropna=False)
    print "Data:",innovation_options[k]
    print innovation_b[k]
    print
    print "Data %:",innovation_options[k]
    print innovation[i].value_counts(normalize=True,dropna=False)*100
    print
    
yes = []
no = []
nanvalue = []

for k,i in enumerate(innovation_columns):
    innovation_presents = innovation_b[k].index.tolist()
    
    # Convert NaN to "NaN"
    for o,h in enumerate(innovation_presents):
        if type(h) is float:
            innovation_presents.pop(o)
            innovation_presents.append("NaN")
    
    # Reassign new list with "NaN"
    innovation_b[k].index = innovation_presents
    
    # Check for empty values, and put a 0 instead
    if "Si" not in innovation_presents:
        yes.append(0)
    if "No" not in innovation_presents:
        no.append(0)
    if "NaN" not in innovation_presents:
        nanvalue.append(0)
    
    for j in innovation_presents:
        if j == "Si":
            yes.append(innovation_b[k].ix["Si"])
        elif j == "No":
            no.append(innovation_b[k].ix["No"])
        elif j == "NaN":
            nanvalue.append(innovation_b[k].ix["NaN"])
# Out:
# Data: Innovazione di prodotto
# No     76
# Si     56
# NaN     2
# dtype: int64
#
# Data %: Innovazione di prodotto
# No     56.716418
# Si     41.791045
# NaN     1.492537
# dtype: float64
#
# Data: Innovazione di processo (progettazione, produzione, distribuzione)
# No     79
# Si     53
# NaN     2
# dtype: int64
#
# Data %: Innovazione di processo (progettazione, produzione, distribuzione)
# No     58.955224
# Si     39.552239
# NaN     1.492537
# dtype: float64
#
# Data: Innovazione di sistema-prodotto (prodotto, servizio e processo)
# No     107
# Si      25
# NaN      2
# dtype: int64
#
# Data %: Innovazione di sistema-prodotto (prodotto, servizio e processo)
# No     79.850746
# Si     18.656716
# NaN     1.492537
# dtype: float64
#
# Data: Innovazione tecnologica
# No     105
# Si      27
# NaN      2
# dtype: int64
#
# Data %: Innovazione tecnologica
# No     78.358209
# Si     20.149254
# NaN     1.492537
# dtype: float64
#
# Data: Innovazione sociale
# No     98
# Si     34
# NaN     2
# dtype: int64
#
# Data %: Innovazione sociale
# No     73.134328
# Si     25.373134
# NaN     1.492537
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Tipi di innovazione', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u"Il risultato della tua attivitá é un'innovazione? Se sí, di che tipo?", fontsize=18, y=1.02)
plt.xticks(range(len(innovation_options)+1),innovation_options,rotation=90)
ind = np.arange(len(innovation_columns))   # the x locations for the groups
width = 0.25                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 3) # Set color palette
rect1 = plt.bar(ind,yes,width,color=my_colors[1],align='center') # Plot Yes
rect2 = plt.bar(ind+width,no,width,color=my_colors[0],align='center') # Plot No 
rect3 = plt.bar(ind+width*2,nanvalue,width,color=my_colors[2],align='center') # Plot NaN
plt.legend( (rect1, rect2, rect3), ('Si', 'No', 'NaN') )
plt.savefig("svg/Q048-MakerQualeInnovazione01.svg")
plt.savefig("png/Q048-MakerQualeInnovazione01.png")
plt.savefig("pdf/Q048-MakerQualeInnovazione01.pdf")

# %%
# Get "other" data
access_other = data["Q048[other]"].str.lower().value_counts()
print "Data:"
print access_other
print ""
print "Data %:"
print data["Q048[other]"].str.lower().value_counts(normalize=True) * 100

# Plot bar
plt.figure(figsize=(8,6))
plt.title(u"Il risultato della tua attivitá é un'innovazione? Se sí, di che tipo? Altro", fontsize=18, y=1.02)
plt.xticks(range(len(access_other.index)),access_other.index,rotation=90)
plt.xlabel(u'Tipi di innovazione', fontsize=16)
plt.ylabel('Persone', fontsize=16)
ind = np.arange(len(access_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(access_other)) # Set color palette
rect1 = plt.bar(ind,access_other,width,color=my_colors,align='center')
plt.savefig("svg/Q048-MakerQualeInnovazione02.svg")
plt.savefig("png/Q048-MakerQualeInnovazione02.png")
plt.savefig("pdf/Q048-MakerQualeInnovazione02.pdf")
# Out:
# Data:
# no                                          2
# innovazione d'interazione.                  1
# innovazione formale                         1
# recupero materiali di scarto industriale    1
# non so                                      1
# invenzione                                  1
# no, e cio che dovrebbero fare tutti         1
# non credo                                   1
# dtype: int64
#
# Data %:
# no                                          1.492537
# innovazione d'interazione.                  0.746269
# innovazione formale                         0.746269
# recupero materiali di scarto industriale    0.746269
# non so                                      0.746269
# invenzione                                  0.746269
# no, e cio che dovrebbero fare tutti         0.746269
# non credo                                   0.746269
# dtype: float64
