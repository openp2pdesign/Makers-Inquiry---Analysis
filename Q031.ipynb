# %% [markdown]
# # Q031 - Frequenti un laboratorio/spazio di fabbricazione?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Get the distribution of places
places = data["Q031"].value_counts(dropna=False)
print "Data:"
print places
print ""
print "Data %:"
print data["Q031"].value_counts(normalize=True,dropna=False) * 100

# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Frequentazione laboratori')
plt.ylabel('Persone')
my_colors = seaborn.color_palette("husl", len(places)) # Set color palette
places.plot(kind="bar",title=u"Maker: Frequenti un laboratorio/spazio di fabbricazione?",color=my_colors)
plt.savefig("pdf/Q031-MakerFrequentiLaboratorio.pdf") # Save pdf
# Out:
# Data:
# No, ho un mio laboratorio/spazio di fabbricazione privato       37
# Si, sono socio/membro                                           30
# No                                                              17
# Si, occasionalmente (una o più volte all’anno) anche se non sono socio/membro    10
# Si, periodicamente (una o più volte al mese) anche se non sono socio/membro     6
# Si, assiduamente (una o più volte a settimana) anche se non sono socio/membro     3
# NaN                                                              0
# dtype: int64
# Data %:
# No, ho un mio laboratorio/spazio di fabbricazione privato       35.922330
# Si, sono socio/membro                                           29.126214
# No                                                              16.504854
# Si, occasionalmente (una o più volte all’anno) anche se non sono socio/membro     9.708738
# Si, periodicamente (una o più volte al mese) anche se non sono socio/membro     5.825243
# ...
