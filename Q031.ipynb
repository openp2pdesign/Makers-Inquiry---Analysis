# %% [markdown]
# # Q031 - Frequenti un laboratorio/spazio di fabbricazione?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Get the distribution of places
places = data["Q031"].value_counts(dropna=False)
print "Data:"
print places
print ""
print "Data %:"
print data["Q031"].value_counts(normalize=True,dropna=False) * 100

# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Frequentazione laboratori', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u"Frequenti un laboratorio/spazio di fabbricazione?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(places)) # Set color palette
places.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q031-MakerFrequentiLaboratorio.svg")
plt.savefig("png/Q031-MakerFrequentiLaboratorio.png")
plt.savefig("pdf/Q031-MakerFrequentiLaboratorio.pdf")
# Out:
# Data:
# Si, sono socio/membro                                           48
# No, ho un mio laboratorio/spazio di fabbricazione privato       40
# No                                                              22
# Si, occasionalmente (una o più volte all’anno) anche se non sono socio/membro    12
# Si, periodicamente (una o più volte al mese) anche se non sono socio/membro     7
# Si, assiduamente (una o più volte a settimana) anche se non sono socio/membro     5
# NaN                                                              0
# dtype: int64
#
# Data %:
# Si, sono socio/membro                                           35.820896
# No, ho un mio laboratorio/spazio di fabbricazione privato       29.850746
# No                                                              16.417910
# Si, occasionalmente (una o più volte all’anno) anche se non sono socio/membro     8.955224
# Si, periodicamente (una o più volte al mese) anche se non sono socio/membro     5.223881
# ...
