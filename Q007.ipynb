# %% [markdown]
# # Q007 - Qual è il tuo titolo di studio?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get the distribution of study titles
study = data["Q007"].value_counts(dropna=False)
print "Data:"
print study
print ""
print "Data %:"
print data["Q007"].value_counts(normalize=True,dropna=False) * 100

# %%
# Save+show the output to a text file
# %save Q007-MakerTitoliDiStudio01.py str(output)
shutil.move("Q007-MakerTitoliDiStudio01.py", "text/Q007-MakerTitoliDiStudio01.txt")
# Out:
# The following commands were written to file `Q007-MakerTitoliDiStudio01.py`:
# Data:
# Laurea specialistica (Master)                 53
# Diploma scuola superiore (Upper secondary)    21
# Laurea triennale (Bachelor)                   18
# Corsi post diploma (Post secondary)           11
# Altro                                         10
# Dottorato di ricerca (PhD)                     8
# Diploma post-laurea (Post-Master)              7
# NaN                                            5
# Licenza media inferiore (Lower secondary)      1
# dtype: int64
#
# Data %:
# Laurea specialistica (Master)                 39.552239
# Diploma scuola superiore (Upper secondary)    15.671642
# Laurea triennale (Bachelor)                   13.432836
# Corsi post diploma (Post secondary)            8.208955
# Altro                                          7.462687
# Dottorato di ricerca (PhD)                     5.970149
# Diploma post-laurea (Post-Master)              5.223881
# ...

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Titoli di studio', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u"Qual è il tuo titolo di studio?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(study)) # Set color palette
study.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q007-MakerTitoliDiStudio01.svg")
plt.savefig("png/Q007-MakerTitoliDiStudio01.png")
plt.savefig("pdf/Q007-MakerTitoliDiStudio01.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get "other" data
study_other = data["Q007[other]"].str.lower().value_counts()
print "Data:"
print study_other
print ""
print "Data %:"
print data["Q007[other]"].str.lower().value_counts(normalize=True) * 100

# %%
# Save+show the output to a text file
# %save Q007-MakerTitoliDiStudio02.py str(Q007b)
shutil.move("Q007-MakerTitoliDiStudio02.py", "text/Q007-MakerTitoliDiStudio02.txt")
# Out:
# The following commands were written to file `Q007-MakerTitoliDiStudio02.py`:
# Data:
# laurea in architettura                                  2
# accademia di belle arti                                 2
# laureando                                               2
# laurea magistrale in progettazione dell'architettura    1
# master in interior design                               1
# laurea quinquennale vecchio ordinamento                 1
# laurea quinquennale in architettura                     1
# dtype: int64
#
# Data %:
# laurea in architettura                                  1.492537
# accademia di belle arti                                 1.492537
# laureando                                               1.492537
# laurea magistrale in progettazione dell'architettura    0.746269
# master in interior design                               0.746269
# laurea quinquennale vecchio ordinamento                 0.746269
# ...

# %%
# Plot bar
plt.figure(figsize=(8,6))
plt.title(u'Qual è il tuo titolo di studio? Altro', fontsize=18, y=1.02)
plt.xticks(range(len(study_other.index)),study_other.index,rotation=90)
plt.xlabel('Titolo', fontsize=16)
plt.ylabel('Persone', fontsize=16)
ind = np.arange(len(study_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(study_other)) # Set color palette
rect1 = plt.bar(ind,study_other,width,color=my_colors,align='center')
plt.savefig("svg/Q007-MakerTitoliDiStudio02.svg")
plt.savefig("png/Q007-MakerTitoliDiStudio02.png")
plt.savefig("pdf/Q007-MakerTitoliDiStudio02.pdf")

# %%
# Filter and integrate "other" data with data manually
study["Laurea specialistica (Master)"] += 7
study["Diploma scuola superiore (Upper secondary)"] += 2
study["Diploma post-laurea (Post-Master)"] += 1
study = study.drop("Altro")
study
# Out:
# Laurea specialistica (Master)                 60
# Diploma scuola superiore (Upper secondary)    23
# Laurea triennale (Bachelor)                   18
# Corsi post diploma (Post secondary)           11
# Dottorato di ricerca (PhD)                     8
# Diploma post-laurea (Post-Master)              8
# NaN                                            5
# Licenza media inferiore (Lower secondary)      1
# dtype: int64

# %%
# Plot the updated data
plt.figure(figsize=(8,6))
plt.xlabel(u'Titoli di studio', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u"Qual è il tuo titolo di studio?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(study)) # Set color palette
study.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q007-MakerTitoliDiStudio01.svg")
plt.savefig("png/Q007-MakerTitoliDiStudio01.png")
plt.savefig("pdf/Q007-MakerTitoliDiStudio01.pdf")

# %%
# Percentage of the updated data
percentage_study = study / study.sum() * 100
percentage_study
# Out:
# Laurea specialistica (Master)                 44.776119
# Diploma scuola superiore (Upper secondary)    17.164179
# Laurea triennale (Bachelor)                   13.432836
# Corsi post diploma (Post secondary)            8.208955
# Dottorato di ricerca (PhD)                     5.970149
# Diploma post-laurea (Post-Master)              5.970149
# NaN                                            3.731343
# Licenza media inferiore (Lower secondary)      0.746269
# dtype: float64
