# %% [markdown]
# # Q053 - Chi sono i tuoi principali fornitori?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q053[SQ001] - Q053[SQ004] - Q053[other]

business_columns = ['Q053[SQ001]','Q053[SQ002]','Q053[SQ003]','Q053[SQ004]']
business_options = ['Fornitori di servizi',
                  'Fornitori di beni intermedi',
                  'Fornitori di tecnologie',
                  'Fornitori di semilavorati']
business = data[business_columns]
business.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
business_other = data['Q053[other]'].str.lower().value_counts()
# Out:
# -c:9: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %%
#places[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(business_columns)+1):
    comb = list(itertools.combinations(business_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in business_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = business_columns.index(j) # Get position
            comb_list.append(business_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in business.index:
    current_bool_list = list(business.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
business["Combination"] = pd.Series(str_values)

# %%
# Gather data
resulting_combinations = business["Combination"].value_counts()
resulting_combinations_percentage = business["Combination"].value_counts(normalize=True)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.savefig("pdf/Q053-Combinazioni.pdf")

# %%
# Data of the combinations
resulting_combinations
# Out:
# Fornitori di semilavorati                                       30
# Fornitori di tecnologie                                         14
# Fornitori di tecnologie, Fornitori di semilavorati              13
# Fornitori di beni intermedi                                     12
# Fornitori di servizi                                             9
# Fornitori di servizi, Fornitori di tecnologie                    7
# Fornitori di beni intermedi, Fornitori di semilavorati           6
# Fornitori di servizi, Fornitori di beni intermedi, Fornitori di tecnologie, Fornitori di semilavorati     5
# Fornitori di servizi, Fornitori di semilavorati                  2
# Fornitori di beni intermedi, Fornitori di tecnologie             2
# Fornitori di servizi, Fornitori di beni intermedi                2
# Fornitori di servizi, Fornitori di beni intermedi, Fornitori di semilavorati     2
# Fornitori di servizi, Fornitori di tecnologie, Fornitori di semilavorati     1
# Fornitori di beni intermedi, Fornitori di tecnologie, Fornitori di semilavorati     1
# dtype: int64

# %%
# Data of the combinations: percentage
resulting_combinations_percentage
# Out:
# Fornitori di semilavorati                                       22.388060
# Fornitori di tecnologie                                         10.447761
# Fornitori di tecnologie, Fornitori di semilavorati               9.701493
# Fornitori di beni intermedi                                      8.955224
# Fornitori di servizi                                             6.716418
# Fornitori di servizi, Fornitori di tecnologie                    5.223881
# Fornitori di beni intermedi, Fornitori di semilavorati           4.477612
# Fornitori di servizi, Fornitori di beni intermedi, Fornitori di tecnologie, Fornitori di semilavorati     3.731343
# Fornitori di servizi, Fornitori di semilavorati                  1.492537
# Fornitori di beni intermedi, Fornitori di tecnologie             1.492537
# Fornitori di servizi, Fornitori di beni intermedi                1.492537
# Fornitori di servizi, Fornitori di beni intermedi, Fornitori di semilavorati     1.492537
# Fornitori di servizi, Fornitori di tecnologie, Fornitori di semilavorati     0.746269
# Fornitori di beni intermedi, Fornitori di tecnologie, Fornitori di semilavorati     0.746269
# dtype: float64
