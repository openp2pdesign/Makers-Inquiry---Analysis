# %% [markdown]
# # Q039 - Qual é il tuo approccio alla progettazione?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q039[SQ001] - Q039[SQ005] - Q039[other]

approach_columns = ['Q039[SQ001]','Q039[SQ002]','Q039[SQ003]','Q039[SQ004]','Q039[SQ005]']
approach_options = ['Creo da zero i miei progetti',
                  'Utilizzo e modifico progetti esistenti (open design)',
                  'Sviluppo progetti in collaborazione con una community (codesign)',
                  'Utilizzo applicazioni che generano modelli (design generativo)',
                  'Sviluppo il progetto mentre lo realizzo materialmente (tinkering)']
approach = data[approach_columns]
approach.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
approach_other = data['Q039[other]'].str.lower().value_counts()
# Out:
# -c:10: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %%
#places[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(approach_columns)+1):
    comb = list(itertools.combinations(approach_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in approach_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = approach_columns.index(j) # Get position
            comb_list.append(approach_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in approach.index:
    current_bool_list = list(approach.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
approach["Combination"] = pd.Series(str_values)

# %%
# Gather data
resulting_combinations = approach["Combination"].value_counts()
resulting_combinations_percentage = approach["Combination"].value_counts(normalize=True)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.savefig("pdf/Q039-Combinazioni.pdf")

# %%
# Data of the combinations
resulting_combinations
# Out:
# Creo da zero i miei progetti                                    45
# Creo da zero i miei progetti, Sviluppo il progetto mentre lo realizzo materialmente (tinkering)    17
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)    11
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     9
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design)     8
# Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign)     5
# Utilizzo e modifico progetti esistenti (open design), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     5
# Sviluppo progetti in collaborazione con una community (codesign)     4
# Utilizzo e modifico progetti esistenti (open design)             4
# Creo da zero i miei progetti, Utilizzo applicazioni che generano modelli (design generativo)     3
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Utilizzo applicazioni che generano modelli (design generativo), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     3
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign)     3
# Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     3
# Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     2
# Creo da zero i miei progetti, Utilizzo applicazioni che generano modelli (design generativo), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     2
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign), Utilizzo applicazioni che generano modelli (design generativo), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     2
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Utilizzo applicazioni che generano modelli (design generativo)     1
# Creo da zero i miei progetti, Sviluppo progetti in collaborazione con una community (codesign), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     1
# Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign), Utilizzo applicazioni che generano modelli (design generativo), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     1
# Utilizzo applicazioni che generano modelli (design generativo)     1
# Creo da zero i miei progetti, Sviluppo progetti in collaborazione con una community (codesign)     1
# dtype: int64

# %%
# Data of the combinations: percentage
resulting_combinations_percentage
# Out:
# Creo da zero i miei progetti                                    33.582090
# Creo da zero i miei progetti, Sviluppo il progetto mentre lo realizzo materialmente (tinkering)    12.686567
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     8.208955
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     6.716418
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design)     5.970149
# Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign)     3.731343
# Utilizzo e modifico progetti esistenti (open design), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     3.731343
# Sviluppo progetti in collaborazione con una community (codesign)     2.985075
# Utilizzo e modifico progetti esistenti (open design)             2.985075
# Creo da zero i miei progetti, Utilizzo applicazioni che generano modelli (design generativo)     2.238806
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Utilizzo applicazioni che generano modelli (design generativo), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     2.238806
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign)     2.238806
# Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     2.238806
# Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     1.492537
# Creo da zero i miei progetti, Utilizzo applicazioni che generano modelli (design generativo), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     1.492537
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign), Utilizzo applicazioni che generano modelli (design generativo), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     1.492537
# Creo da zero i miei progetti, Utilizzo e modifico progetti esistenti (open design), Utilizzo applicazioni che generano modelli (design generativo)     0.746269
# Creo da zero i miei progetti, Sviluppo progetti in collaborazione con una community (codesign), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     0.746269
# Utilizzo e modifico progetti esistenti (open design), Sviluppo progetti in collaborazione con una community (codesign), Utilizzo applicazioni che generano modelli (design generativo), Sviluppo il progetto mentre lo realizzo materialmente (tinkering)     0.746269
# Utilizzo applicazioni che generano modelli (design generativo)     0.746269
# Creo da zero i miei progetti, Sviluppo progetti in collaborazione con una community (codesign)     0.746269
# dtype: float64
