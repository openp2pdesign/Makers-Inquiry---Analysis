# %% [markdown]
# # Q047 - Offri servizi collegati al prodotto?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q047[SQ001] - Q047[SQ004] - Q047[other]

services_columns = ['Q047[SQ001]','Q047[SQ002]','Q047[SQ003]','Q047[SQ004]']
services_options = ['Consegna a domicilio',
                  u'Certificato di qualitá',
                  'Assistenza postvendita (riparazione, sostituzione)',
                  'Garanzia']
services = data[services_columns]
services.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
services_other = data['Q047[other]'].str.lower().value_counts()
# Out:
# -c:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#services[0:4]

# %%
# Gather data
services_b = {}
for k,i in enumerate(services_columns):
    services_b[k] = services[i].value_counts(dropna=False)
    print "Data:",services_options[k]
    print services_b[k]
    print
    print "Data %:",services_options[k]
    print services[i].value_counts(normalize=True,dropna=False)*100
    print
    
yes = []
no = []
nanvalue = []

for k,i in enumerate(services_columns):
    services_presents = services_b[k].index.tolist()
    
    # Convert NaN to "NaN"
    for o,h in enumerate(services_presents):
        if type(h) is float:
            services_presents.pop(o)
            services_presents.append("NaN")
    
    # Reassign new list with "NaN"
    services_b[k].index = services_presents
    
    # Check for empty values, and put a 0 instead
    if "Si" not in services_presents:
        yes.append(0)
    if "No" not in services_presents:
        no.append(0)
    if "NaN" not in services_presents:
        nanvalue.append(0)
    
    for j in services_presents:
        if j == "Si":
            yes.append(services_b[k].ix["Si"])
        elif j == "No":
            no.append(services_b[k].ix["No"])
        elif j == "NaN":
            nanvalue.append(services_b[k].ix["NaN"])
# Out:
# Data: Consegna a domicilio
# No     92
# Si     40
# NaN     2
# dtype: int64
#
# Data %: Consegna a domicilio
# No     68.656716
# Si     29.850746
# NaN     1.492537
# dtype: float64
#
# Data: Certificato di qualitá
# No     121
# Si      11
# NaN      2
# dtype: int64
#
# Data %: Certificato di qualitá
# No     90.298507
# Si      8.208955
# NaN     1.492537
# dtype: float64
#
# Data: Assistenza postvendita (riparazione, sostituzione)
# No     82
# Si     50
# NaN     2
# dtype: int64
#
# Data %: Assistenza postvendita (riparazione, sostituzione)
# No     61.194030
# Si     37.313433
# NaN     1.492537
# dtype: float64
#
# Data: Garanzia
# No     115
# Si      17
# NaN      2
# dtype: int64
#
# Data %: Garanzia
# No     85.820896
# Si     12.686567
# NaN     1.492537
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Servizi offerti', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title('Offri servizi collegati al prodotto?', fontsize=18)
plt.xticks(range(len(services_options)+1),services_options,rotation=90)
ind = np.arange(len(services_columns))   # the x locations for the groups
width = 0.25                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 3) # Set color palette
rect1 = plt.bar(ind,yes,width,color=my_colors[1],align='center') # Plot Yes
rect2 = plt.bar(ind+width,no,width,color=my_colors[0],align='center') # Plot No 
rect3 = plt.bar(ind+width*2,nanvalue,width,color=my_colors[2],align='center') # Plot NaN
plt.legend( (rect1, rect2, rect3), ('Si', 'No', 'NaN') )
plt.savefig("svg/Q047-MakerServiziOfferti01.svg")
plt.savefig("png/Q047-MakerServiziOfferti01.png")

# %%
# Get "other" data
access_other = data["Q047[other]"].str.lower().value_counts()
print "Data:"
print access_other
print ""
print "Data %:"
print data["Q047[other]"].str.lower().value_counts(normalize=True) * 100

# Plot bar
plt.figure(figsize=(8,6))
plt.title('Offri servizi collegati al prodotto? Altro', fontsize=18)
plt.xticks(range(len(access_other.index)),access_other.index,rotation=90)
plt.xlabel(u'Offerta servizi', fontsize=16)
plt.ylabel('Persone', fontsize=16)
ind = np.arange(len(access_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(access_other)) # Set color palette
rect1 = plt.bar(ind,access_other,width,color=my_colors,align='center')
plt.savefig("svg/Q047-MakerServiziOfferti02.svg")
plt.savefig("png/Q047-MakerServiziOfferti02.png")
# Out:
# Data:
# no                                                              4
# nessuno                                                         3
# non offro prodotti ma progetti.                                 1
# autenticità                                                     1
# consulenze e/o progettazione degli ambienti ove si inserisce il prodotto    1
# laboratori, seminari                                            1
# finora nulla                                                    1
# non ho lavoro che cavolo dire. dovevano essere solo ipotesi di vendita    1
# non produco per terzi                                           1
# networking                                                      1
# upgrade                                                         1
# insegno l'autorealizzazione                                     1
# dtype: int64
#
# Data %:
# no                                                              2.985075
# ...
