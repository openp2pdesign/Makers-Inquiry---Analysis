# %% [markdown]
# # Q014 - Qual è la tua attività principale?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get the distribution of activity type
activity_type = data["Q014"].value_counts(dropna=False)
print "Data:"
print activity_type
print ""
print "Data %:"
print data["Q014"].value_counts(normalize=True,dropna=False) * 100

# %%
# Save+show the output to a text file
# %save Q014-MakerTipoAttivitá01.py str(output)
shutil.move("Q014-MakerTipoAttivitá01.py", "text/Q014-MakerTipoAttivitá01.txt")
# Out:
# The following commands were written to file `Q014-MakerTipoAttivitá01.py`:
# Data:
# Sono un libero professionista                                42
# NaN                                                          40
# Sono titolare di un’impresa produttrice di beni o servizi    12
# Sono un lavoratore dipendente (piccola/media impresa)        10
# Sono uno studente                                             9
# Sono un lavoratore dipendente (multinazionale)                6
# Sono un lavoratore dipendente (grande impresa)                5
# Non lavoro                                                    4
# Sono un lavoratore dipendente (microimpresa)                  4
# Sono un artigiano                                             2
# dtype: int64
#
# Data %:
# Sono un libero professionista                                31.343284
# NaN                                                          29.850746
# Sono titolare di un’impresa produttrice di beni o servizi     8.955224
# Sono un lavoratore dipendente (piccola/media impresa)         7.462687
# Sono uno studente                                             6.716418
# Sono un lavoratore dipendente (multinazionale)                4.477612
# Sono un lavoratore dipendente (grande impresa)                3.731343
# Non lavoro                                                    2.985075
# Sono un lavoratore dipendente (microimpresa)                  2.985075
# Sono un artigiano                                             1.492537
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Tipo di Attivitá', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u"Qual è la tua attività principale?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(activity_type)) # Set color palette
activity_type.plot(kind="bar",color=my_colors)
plt.savefig(u"svg/Q014-MakerTipoAttivitá01.svg")
plt.savefig(u"png/Q014-MakerTipoAttivitá01.png")
plt.savefig(u"pdf/Q014-MakerTipoAttivitá01.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Gather makers employed

# Get sum of employed people
employed = activity_type.ix["Sono un lavoratore dipendente (piccola/media impresa)"] + activity_type.ix["Sono un lavoratore dipendente (multinazionale)"] + activity_type.ix["Sono un lavoratore dipendente (grande impresa)"] + activity_type.ix["Sono un lavoratore dipendente (microimpresa)"]

# Remove other types of employment
activity_type = activity_type.drop("Sono un lavoratore dipendente (piccola/media impresa)")
activity_type = activity_type.drop("Sono un lavoratore dipendente (multinazionale)")
activity_type = activity_type.drop("Sono un lavoratore dipendente (grande impresa)")
activity_type = activity_type.drop("Sono un lavoratore dipendente (microimpresa)")

# Add sum of employment
activity_type.ix["Sono un dipendente"] = employed
print activity_type

# %%
# Save+show the output to a text file
# %save Q014-MakerTipoAttivitá02.py str(Q014b)
shutil.move("Q014-MakerTipoAttivitá02.py", "text/Q014-MakerTipoAttivitá02.txt")
# Out:
# The following commands were written to file `Q014-MakerTipoAttivitá02.py`:
# Sono un libero professionista                                42
# NaN                                                          40
# Sono titolare di un’impresa produttrice di beni o servizi    12
# Sono uno studente                                             9
# Non lavoro                                                    4
# Sono un artigiano                                             2
# Sono un dipendente                                           25
# dtype: int64

# %%
# Plot the update data
plt.figure(figsize=(8,6))
plt.xlabel(u'Tipo di Attivitá', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u"Qual è la tua attività principale?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(activity_type)) # Set color palette
activity_type.plot(kind="bar",color=my_colors)
plt.savefig(u"svg/Q014-MakerTipoAttivitá03.svg")
plt.savefig(u"png/Q014-MakerTipoAttivitá03.png")
plt.savefig(u"pdf/Q014-MakerTipoAttivitá03.pdf")
