# %% [markdown]
# # Q047 - Offri servizi collegati al prodotto?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q047[SQ001] - Q047[SQ004] - Q047[other]

services_columns = ['Q047[SQ001]','Q047[SQ002]','Q047[SQ003]','Q047[SQ004]']
services_options = ['Consegna a domicilio',
                  u'Certificato di qualitá',
                  'Assistenza postvendita (riparazione, sostituzione)',
                  'Garanzia']
services = data[services_columns]
services.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
services_other = data['Q047[other]'].str.lower().value_counts()
# Out:
# -c:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#services[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(services_columns)+1):
    comb = list(itertools.combinations(services_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in services_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = services_columns.index(j) # Get position
            comb_list.append(services_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in services.index:
    current_bool_list = list(services.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
services["Combination"] = pd.Series(str_values)
# Out:
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Gather data
resulting_combinations = services["Combination"].value_counts()
resulting_combinations_percentage = services["Combination"].value_counts(normalize=True)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.title(u"Offri servizi collegati al prodotto? Combinazioni", fontsize=18, y=1.02)
plt.ylabel("Persone", fontsize=16)
plt.xlabel("Combinazioni", fontsize=16)
plt.savefig("svg/Q047-Combinazioni.svg")
plt.savefig("png/Q047-Combinazioni.png")
plt.savefig("pdf/Q047-Combinazioni.pdf")

# %%
# Data of the combinations
resulting_combinations
# Out:
# Assistenza postvendita (riparazione, sostituzione)              21
# Consegna a domicilio, Assistenza postvendita (riparazione, sostituzione)    15
# Consegna a domicilio                                            15
# Assistenza postvendita (riparazione, sostituzione), Garanzia     5
# Certificato di qualitá                                           4
# Consegna a domicilio, Assistenza postvendita (riparazione, sostituzione), Garanzia     4
# Garanzia                                                         3
# Consegna a domicilio, Certificato di qualitá, Assistenza postvendita (riparazione, sostituzione), Garanzia     2
# Consegna a domicilio, Certificato di qualitá, Assistenza postvendita (riparazione, sostituzione)     2
# Consegna a domicilio, Certificato di qualitá                     1
# Certificato di qualitá, Garanzia                                 1
# Consegna a domicilio, Garanzia                                   1
# Certificato di qualitá, Assistenza postvendita (riparazione, sostituzione), Garanzia     1
# dtype: int64

# %%
# Data of the combinations: percentage
resulting_combinations_percentage
# Out:
# Assistenza postvendita (riparazione, sostituzione)              15.671642
# Consegna a domicilio, Assistenza postvendita (riparazione, sostituzione)    11.194030
# Consegna a domicilio                                            11.194030
# Assistenza postvendita (riparazione, sostituzione), Garanzia     3.731343
# Certificato di qualitá                                           2.985075
# Consegna a domicilio, Assistenza postvendita (riparazione, sostituzione), Garanzia     2.985075
# Garanzia                                                         2.238806
# Consegna a domicilio, Certificato di qualitá, Assistenza postvendita (riparazione, sostituzione), Garanzia     1.492537
# Consegna a domicilio, Certificato di qualitá, Assistenza postvendita (riparazione, sostituzione)     1.492537
# Consegna a domicilio, Certificato di qualitá                     0.746269
# Certificato di qualitá, Garanzia                                 0.746269
# Consegna a domicilio, Garanzia                                   0.746269
# Certificato di qualitá, Assistenza postvendita (riparazione, sostituzione), Garanzia     0.746269
# dtype: float64
