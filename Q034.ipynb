# %% [markdown]
# # Q034 - Quante persone lo frequentano?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Get the distribution of contract type
contract = data["Q034"].value_counts(dropna=False)
print "Data:"
print contract
print ""
print "Data %:"
print data["Q034"].value_counts(normalize=True,dropna=False) * 100

# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Frequenza')
plt.ylabel('Persone')
my_colors = seaborn.color_palette("husl", len(contract)) # Set color palette
contract.plot(kind="bar",title="Quante persone lo frequentano?",color=my_colors)
plt.savefig("pdf/Q034-PersoneFrequentanoLab01.pdf") # Save pdf
# Out:
# Data:
# NaN             44
# Meno di 10      32
# Tra 10 e 25     29
# Tra 25 e 50     15
# Tra 50 e 100     8
# Oltre 100        6
# dtype: int64
# Data %:
# NaN             32.835821
# Meno di 10      23.880597
# Tra 10 e 25     21.641791
# Tra 25 e 50     11.194030
# Tra 50 e 100     5.970149
# Oltre 100        4.477612
# dtype: float64

# %%
# Get the distribution of contract type
contract = data["Q034"].value_counts()
print "Data:"
print contract
print ""
print "Data %:"
print data["Q034"].value_counts(normalize=True) * 100

# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Frequenza')
plt.ylabel('Persone')
my_colors = seaborn.color_palette("husl", len(contract)) # Set color palette
contract.plot(kind="bar",title="Quante persone lo frequentano?",color=my_colors)
plt.savefig("pdf/Q034-PersoneFrequentanoLab02.pdf") # Save pdf
# Out:
# Data:
# Meno di 10      32
# Tra 10 e 25     29
# Tra 25 e 50     15
# Tra 50 e 100     8
# Oltre 100        6
# dtype: int64
#
# Data %:
# Meno di 10      23.880597
# Tra 10 e 25     21.641791
# Tra 25 e 50     11.194030
# Tra 50 e 100     5.970149
# Oltre 100        4.477612
# dtype: float64
