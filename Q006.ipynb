# %% [markdown]
# # Q006 - Qual é la tua cittá di residenza?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Get the distribution of cities
data["Q006"] = data["Q006"].str.lower()
city = data["Q006"].value_counts(dropna=False)
print "Data:"
print city
print ""
print "Data %:"
print data["Q006"].value_counts(normalize=True,dropna=False) * 100

# Plot the data
plt.figure(figsize=(16,6))
plt.xlabel(u'Cittá')
plt.ylabel('Persone')
my_colors = seaborn.color_palette("husl", len(city)) # Set color palette
city.plot(kind="bar",title=u"Qual é la tua cittá di residenza?",color=my_colors)
plt.savefig(u"pdf/Q006-CittáMaker.pdf") # Save pdf
# Out:
# Data:
# milano      14
# roma         7
# bologna      7
# NaN          7
# modena       5
# venezia      4
# parma        3
# padova       3
# firenze      3
# l'aquila     2
# torino       2
# vicenza      2
# brescia      2
# verona       2
# catania      2
# ...
# cesena                       1
# milano/amsterdam             1
# gravina in puglia            1
# savigno, valsamoggia (bo)    1
# arona                        1
# prato                        1
# anagni                       1
# novara                       1
# foligno                      1
# rimini                       1
# messina                      1
# cogliate (mb)                1
# la spezia                    1
# gravedona ed uniti (co)      1
# faenza                       1
# Length: 79, dtype: int64
# Data %:
# milano      10.447761
# roma         5.223881
# bologna      5.223881
# NaN          5.223881
# modena       3.731343
# venezia      2.985075
# parma        2.238806
# padova       2.238806
# firenze      2.238806
# l'aquila     1.492537
# torino       1.492537
# vicenza      1.492537
# brescia      1.492537
# verona       1.492537
# catania      1.492537
# ...
# cesena                       0.746269
# milano/amsterdam             0.746269
# gravina in puglia            0.746269
# savigno, valsamoggia (bo)    0.746269
# arona                        0.746269
# prato                        0.746269
# anagni                       0.746269
# novara                       0.746269
# foligno                      0.746269
# rimini                       0.746269
# messina                      0.746269
# cogliate (mb)                0.746269
# la spezia                    0.746269
# gravedona ed uniti (co)      0.746269
# faenza                       0.746269
# Length: 79, dtype: float64
