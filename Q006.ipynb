# %% [markdown]
# # Q006 - Qual é la tua cittá di residenza?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
pd.set_option('max_rows', None) # Display all rows: there are many cities!
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get the distribution of cities
data["Q006"] = data["Q006"].str.lower()
city = data["Q006"].value_counts(dropna=False)
print "Data:"
print city
print ""
print "Data %:"
print data["Q006"].value_counts(normalize=True,dropna=False) * 100

# %%
# Save+show the output to a text file
# %save Q006-CittáMaker.py str(output)
shutil.move("Q006-CittáMaker.py", "text/Q006-CittáMaker.txt")
# Out:
# The following commands were written to file `Q006-CittáMaker.py`:
# Data:
# milano                       14
# roma                          7
# bologna                       7
# NaN                           7
# modena                        5
# venezia                       4
# parma                         3
# padova                        3
# firenze                       3
# l'aquila                      2
# torino                        2
# vicenza                       2
# brescia                       2
# verona                        2
# catania                       2
# treviso                       2
# imperia                       2
# bellaria igea marina          2
# palermo                       2
# napoli                        2
# valsamoggia                   1
# arcore                        1
# pisa                          1
# binasco                       1
# malcesine -vr-                1
# pontirolo                     1
# gioia del colle               1
# ...

# %%
# Plot the data
plt.figure(figsize=(16,6))
plt.xlabel(u'Cittá', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u"Qual é la tua cittá di residenza?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(city)) # Set color palette
city.plot(kind="bar",color=my_colors)
plt.savefig(u"svg/Q006-CittáMaker.svg")
plt.savefig(u"png/Q006-CittáMaker.png")
plt.savefig(u"pdf/Q006-CittáMaker.pdf")
