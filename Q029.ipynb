# %% [markdown]
# # Q028 - Quanto sei d’accordo con le seguenti affermazioni?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q029[SQ001] - Q029[SQ005]

agree_columns = ['Q029[SQ001]','Q029[SQ002]','Q029[SQ003]','Q029[SQ004]','Q029[SQ005]']
agree_options = ["I makers hanno un ruolo sociale","I makers hanno un ruolo politico",
                 "Le istituzioni non capiscono il ruolo del maker","Makers e hackers sono due figure distinte",
                 "I makers costituiscono un nuovo movimento"]
agree = data[agree_columns]
agree_types = [u"Completamente d’accordo",u"Parzialmente d’accordo",u"In disaccordo",u"Totalmente In disaccordo",u"Non so Non rispondo"]

# %%
agree
# Out:
#                  Q029[SQ001]                Q029[SQ002]  \
# 0    Completamente d’accordo     Parzialmente d’accordo
# 1    Completamente d’accordo    Completamente d’accordo
# 2     Parzialmente d’accordo              In disaccordo
# 3     Parzialmente d’accordo     Parzialmente d’accordo
# 4                        NaN                        NaN
# 5     Parzialmente d’accordo  Totalmente  In disaccordo
# 6     Parzialmente d’accordo     Parzialmente d’accordo
# 7    Completamente d’accordo     Parzialmente d’accordo
# 8     Parzialmente d’accordo  Totalmente  In disaccordo
# 9     Parzialmente d’accordo  Totalmente  In disaccordo
# 10   Completamente d’accordo     Parzialmente d’accordo
# 11   Completamente d’accordo              In disaccordo
# 12   Completamente d’accordo    Completamente d’accordo
# 13    Parzialmente d’accordo  Totalmente  In disaccordo
# 14   Completamente d’accordo     Parzialmente d’accordo
# 15    Parzialmente d’accordo     Parzialmente d’accordo
# 16    Parzialmente d’accordo              In disaccordo
# 17    Parzialmente d’accordo              In disaccordo
# 18   Completamente d’accordo              In disaccordo
# 19   Completamente d’accordo     Parzialmente d’accordo
# 20                       NaN                        NaN
# 21   Completamente d’accordo    Completamente d’accordo
# 22   Completamente d’accordo  Totalmente  In disaccordo
# 23   Completamente d’accordo    Completamente d’accordo
# 24                       NaN                        NaN
# 25   Completamente d’accordo     Parzialmente d’accordo
# 26   Completamente d’accordo    Completamente d’accordo
# 27    Parzialmente d’accordo        Non so Non rispondo
# 28   Completamente d’accordo    Completamente d’accordo
# 29    Parzialmente d’accordo     Parzialmente d’accordo
# ..                       ...                        ...
# 73    Parzialmente d’accordo                        NaN
# 74   Completamente d’accordo     Parzialmente d’accordo
# 75    Parzialmente d’accordo                        NaN
# 76   Completamente d’accordo     Parzialmente d’accordo
# 77    Parzialmente d’accordo     Parzialmente d’accordo
# 78    Parzialmente d’accordo  Totalmente  In disaccordo
# 79       Non so Non rispondo  Totalmente  In disaccordo
# 80   Completamente d’accordo     Parzialmente d’accordo
# 81    Parzialmente d’accordo              In disaccordo
# 82    Parzialmente d’accordo     Parzialmente d’accordo
# 83    Parzialmente d’accordo              In disaccordo
# 84   Completamente d’accordo  Totalmente  In disaccordo
# 85       Non so Non rispondo     Parzialmente d’accordo
# 86    Parzialmente d’accordo        Non so Non rispondo
# 87    Parzialmente d’accordo              In disaccordo
# 88    Parzialmente d’accordo              In disaccordo
# 89   Completamente d’accordo    Completamente d’accordo
# 90   Completamente d’accordo     Parzialmente d’accordo
# 91   Completamente d’accordo              In disaccordo
# 92             In disaccordo              In disaccordo
# 93       Non so Non rispondo        Non so Non rispondo
# 94    Parzialmente d’accordo    Completamente d’accordo
# 95   Completamente d’accordo    Completamente d’accordo
# 96   Completamente d’accordo              In disaccordo
# 97    Parzialmente d’accordo     Parzialmente d’accordo
# 98    Parzialmente d’accordo        Non so Non rispondo
# 99   Completamente d’accordo     Parzialmente d’accordo
# 100   Parzialmente d’accordo        Non so Non rispondo
# 101   Parzialmente d’accordo     Parzialmente d’accordo
# 102   Parzialmente d’accordo  Totalmente  In disaccordo
#
#                  Q029[SQ003]                Q029[SQ004]  \
# 0     Parzialmente d’accordo     Parzialmente d’accordo
# 1    Completamente d’accordo              In disaccordo
# 2     Parzialmente d’accordo     Parzialmente d’accordo
# 3    Completamente d’accordo              In disaccordo
# 4                        NaN                        NaN
# 5     Parzialmente d’accordo     Parzialmente d’accordo
# 6    Completamente d’accordo    Completamente d’accordo
# 7    Completamente d’accordo     Parzialmente d’accordo
# 8    Completamente d’accordo    Completamente d’accordo
# 9    Completamente d’accordo     Parzialmente d’accordo
# 10   Completamente d’accordo     Parzialmente d’accordo
# 11   Completamente d’accordo    Completamente d’accordo
# 12   Completamente d’accordo     Parzialmente d’accordo
# 13    Parzialmente d’accordo    Completamente d’accordo
# 14   Completamente d’accordo     Parzialmente d’accordo
# 15       Non so Non rispondo     Parzialmente d’accordo
# 16    Parzialmente d’accordo    Completamente d’accordo
# 17   Completamente d’accordo    Completamente d’accordo
# 18             In disaccordo    Completamente d’accordo
# 19   Completamente d’accordo    Completamente d’accordo
# 20                       NaN                        NaN
# 21    Parzialmente d’accordo              In disaccordo
# 22    Parzialmente d’accordo     Parzialmente d’accordo
# 23   Completamente d’accordo    Completamente d’accordo
# 24                       NaN                        NaN
# 25   Completamente d’accordo     Parzialmente d’accordo
# 26   Completamente d’accordo    Completamente d’accordo
# 27       Non so Non rispondo              In disaccordo
# 28   Completamente d’accordo  Totalmente  In disaccordo
# 29    Parzialmente d’accordo     Parzialmente d’accordo
# ..                       ...                        ...
# 73   Completamente d’accordo    Completamente d’accordo
# 74   Completamente d’accordo    Completamente d’accordo
# 75                       NaN                        NaN
# 76    Parzialmente d’accordo    Completamente d’accordo
# 77             In disaccordo     Parzialmente d’accordo
# 78   Completamente d’accordo    Completamente d’accordo
# 79    Parzialmente d’accordo    Completamente d’accordo
# 80   Completamente d’accordo    Completamente d’accordo
# 81                       NaN     Parzialmente d’accordo
# 82    Parzialmente d’accordo              In disaccordo
# 83   Completamente d’accordo    Completamente d’accordo
# 84   Completamente d’accordo    Completamente d’accordo
# 85   Completamente d’accordo    Completamente d’accordo
# 86       Non so Non rispondo                        NaN
# 87    Parzialmente d’accordo    Completamente d’accordo
# 88    Parzialmente d’accordo    Completamente d’accordo
# 89   Completamente d’accordo                        NaN
# 90    Parzialmente d’accordo              In disaccordo
# 91    Parzialmente d’accordo    Completamente d’accordo
# 92   Completamente d’accordo    Completamente d’accordo
# 93   Completamente d’accordo     Parzialmente d’accordo
# 94    Parzialmente d’accordo     Parzialmente d’accordo
# 95   Completamente d’accordo                        NaN
# 96   Completamente d’accordo              In disaccordo
# 97   Completamente d’accordo     Parzialmente d’accordo
# 98   Completamente d’accordo        Non so Non rispondo
# 99   Completamente d’accordo    Completamente d’accordo
# 100      Non so Non rispondo              In disaccordo
# 101   Parzialmente d’accordo    Completamente d’accordo
# 102  Completamente d’accordo    Completamente d’accordo
#
#                  Q029[SQ005]
# 0     Parzialmente d’accordo
# 1    Completamente d’accordo
# 2              In disaccordo
# 3              In disaccordo
# 4                        NaN
# 5     Parzialmente d’accordo
# 6    Completamente d’accordo
# 7              In disaccordo
# 8     Parzialmente d’accordo
# 9              In disaccordo
# 10             In disaccordo
# 11    Parzialmente d’accordo
# 12   Completamente d’accordo
# 13             In disaccordo
# 14   Completamente d’accordo
# 15    Parzialmente d’accordo
# 16    Parzialmente d’accordo
# 17    Parzialmente d’accordo
# 18   Completamente d’accordo
# 19    Parzialmente d’accordo
# 20                       NaN
# 21             In disaccordo
# 22    Parzialmente d’accordo
# 23   Completamente d’accordo
# 24                       NaN
# 25    Parzialmente d’accordo
# 26   Completamente d’accordo
# 27       Non so Non rispondo
# 28   Completamente d’accordo
# 29    Parzialmente d’accordo
# ..                       ...
# 73                       NaN
# 74    Parzialmente d’accordo
# 75   Completamente d’accordo
# 76   Completamente d’accordo
# 77   Completamente d’accordo
# 78    Parzialmente d’accordo
# 79             In disaccordo
# 80             In disaccordo
# 81    Parzialmente d’accordo
# 82    Parzialmente d’accordo
# 83    Parzialmente d’accordo
# 84   Completamente d’accordo
# 85    Parzialmente d’accordo
# 86    Parzialmente d’accordo
# 87    Parzialmente d’accordo
# 88   Completamente d’accordo
# 89   Completamente d’accordo
# 90   Completamente d’accordo
# 91   Completamente d’accordo
# 92    Parzialmente d’accordo
# 93    Parzialmente d’accordo
# 94    Parzialmente d’accordo
# 95                       NaN
# 96   Completamente d’accordo
# 97   Completamente d’accordo
# 98   Completamente d’accordo
# 99   Completamente d’accordo
# 100   Parzialmente d’accordo
# 101   Parzialmente d’accordo
# 102   Parzialmente d’accordo
#
# [103 rows x 5 columns]

# %%
# Gather data
agree_b = {}
for k,i in enumerate(agree_columns):
    agree_b[k] = agree[i].value_counts()
    print "Data:",agree_options[k]
    print agree_b[k]
    print
    print "Data %:",agree_options[k]
    print agree[i].value_counts(normalize=True)*100
    print

completamente = []
parzialmente = []
disaccordo = []
totalmente = []
nonso = []

for k,i in enumerate(agree_columns):
    agree_presents = agree_b[k].index.tolist()
    # Check for empty values, and put a 0 instead
    if u"Completamente d\u2019accordo" not in agree_presents:
        completamente.append(0)
    if u"Parzialmente d\u2019accordo" not in agree_presents:
        parzialmente.append(0)
    if u"In disaccordo" not in agree_presents:
        disaccordo.append(0)
    if u"Totalmente  In disaccordo" not in agree_presents:
        totalmente.append(0)
    if u"Non so Non rispondo" not in agree_presents:
        nonso.append(0)
        
    for j in agree_presents:
        if j == u"Completamente d\u2019accordo":
            completamente.append(agree_b[k].ix[u"Completamente d\u2019accordo"])
        elif j == u"Parzialmente d\u2019accordo":
            parzialmente.append(agree_b[k].ix[u"Parzialmente d\u2019accordo"])
        elif j == u"In disaccordo":
            disaccordo.append(agree_b[k].ix[u"In disaccordo"])
        elif j == u"Totalmente  In disaccordo":
            totalmente.append(agree_b[k].ix[u"Totalmente  In disaccordo"])
        elif j == u"Non so Non rispondo":
            nonso.append(agree_b[k].ix[u"Non so Non rispondo"])
            
# Plot the data
plt.figure(figsize=(12,6))
plt.xlabel('Frasi')
plt.ylabel('Persone')
plt.title("Maker: sei d'accordo?")
plt.xticks(range(len(agree_options)),agree_options,rotation=90)
ind = np.arange(len(agree_columns))       # the x locations for the groups
width = 0.15                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 6) # Set color palette
rect1 = plt.bar(ind,completamente,width,color=my_colors[0],align='center') # Plot completamente
rect2 = plt.bar(ind+width,parzialmente,width,color=my_colors[1],align='center') # Plot parzialmente 
rect3 = plt.bar(ind+width*2,disaccordo,width,color=my_colors[2],align='center') # Plot disaccordo
rect4 = plt.bar(ind+width*3,totalmente,width,color=my_colors[3],align='center') # Plot totalmente
rect5 = plt.bar(ind+width*4,nonso,width,color=my_colors[4],align='center') # Plot non so
plt.legend( (rect1, rect2, rect3, rect4, rect5), agree_types )
plt.savefig("pdf/Q029-MakerAccordo01.pdf")
# Out:
# Data: I makers hanno un ruolo sociale
# Parzialmente d’accordo     48
# Completamente d’accordo    46
# Non so Non rispondo         4
# In disaccordo               2
# dtype: int64
# Data %: I makers hanno un ruolo sociale
# Parzialmente d’accordo     46.601942
# Completamente d’accordo    44.660194
# Non so Non rispondo         3.883495
# In disaccordo               1.941748
# dtype: float64
#
# Data: I makers hanno un ruolo politico
# Parzialmente d’accordo       33
# In disaccordo                24
# Completamente d’accordo      17
# Totalmente  In disaccordo    15
# Non so Non rispondo           6
# dtype: int64
#
# Data %: I makers hanno un ruolo politico
# Parzialmente d’accordo       32.038835
# In disaccordo                23.300971
# Completamente d’accordo      16.504854
# Totalmente  In disaccordo    14.563107
# Non so Non rispondo           5.825243
# dtype: float64
#
# Data: Le istituzioni non capiscono il ruolo del maker
# Completamente d’accordo    59
# Parzialmente d’accordo     29
# In disaccordo               5
# Non so Non rispondo         4
# dtype: int64
#
# Data %: Le istituzioni non capiscono il ruolo del maker
# Completamente d’accordo    57.281553
# Parzialmente d’accordo     28.155340
# In disaccordo               4.854369
# Non so Non rispondo         3.883495
# dtype: float64
#
# Data: Makers e hackers sono due figure distinte
# Completamente d’accordo      46
# Parzialmente d’accordo       34
# In disaccordo                11
# Totalmente  In disaccordo     2
# Non so Non rispondo           2
# dtype: int64
#
# Data %: Makers e hackers sono due figure distinte
# Completamente d’accordo      44.660194
# Parzialmente d’accordo       33.009709
# In disaccordo                10.679612
# Totalmente  In disaccordo     1.941748
# Non so Non rispondo           1.941748
# dtype: float64
#
# Data: I makers costituiscono un nuovo movimento
# Parzialmente d’accordo       46
# Completamente d’accordo      39
# In disaccordo                 9
# Non so Non rispondo           2
# Totalmente  In disaccordo     1
# dtype: int64
#
# Data %: I makers costituiscono un nuovo movimento
# Parzialmente d’accordo       44.660194
# Completamente d’accordo      37.864078
# In disaccordo                 8.737864
# Non so Non rispondo           1.941748
# Totalmente  In disaccordo     0.970874
# dtype: float64
