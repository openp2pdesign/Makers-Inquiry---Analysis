# %% [markdown]
# # Q016 - Che tipo di contratto hai?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Get the distribution of contract type
contract = data["Q016"].value_counts(dropna=False)
print "Data:"
print contract
print ""
print "Data %:"
print data["Q016"].value_counts(normalize=True,dropna=False) * 100

# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Tipi di contratto')
plt.ylabel('Persone')
my_colors = seaborn.color_palette("husl", len(contract)) # Set color palette
contract.plot(kind="bar",title="Maker: Che tipi di contratto",color=my_colors)
plt.savefig("pdf/Q016-MakerTipiContratto01.pdf") # Save pdf
# Out:
# Data:
# Collaborazione con/senza Partita IVA (Freelance)    34
# NaN                                                 21
# Contratto a tempo indeterminato (Permanent job)     20
# Altro                                               15
# Contratto a tempo determinato (Temporary job)        7
# Contratto a progetto                                 4
# Borsa di studio                                      2
# dtype: int64
# Data %:
# Collaborazione con/senza Partita IVA (Freelance)    33.009709
# NaN                                                 20.388350
# Contratto a tempo indeterminato (Permanent job)     19.417476
# Altro                                               14.563107
# Contratto a tempo determinato (Temporary job)        6.796117
# Contratto a progetto                                 3.883495
# Borsa di studio                                      1.941748
# dtype: float64

# %%
# Get "other" data
contract_other = data["Q016[other]"].str.lower().value_counts()
print "Data:"
print contract_other
print ""
print "Data %:"
print data["Q016[other]"].str.lower().value_counts(normalize=True) * 100

# Plot bar
plt.figure(figsize=(8,6))
plt.title('Maker: Tipi di Contratto. Altro')
plt.xticks(range(len(contract_other.index)),contract_other.index,rotation=90)
plt.xlabel('Tipi di contratto')
plt.ylabel('Persone')
ind = np.arange(len(contract_other))   # the x locations for the groups
width = 0.35                         # the width of the bars

my_colors = seaborn.color_palette("husl", len(contract_other)) # Set color palette
rect1 = plt.bar(ind,contract_other,width,color=my_colors,align='center')
plt.savefig("pdf/Q016-MakerTipiContratto02.pdf") # Save pdf
# Out:
# Data:
# libero professionista             3
# per il momento di volontariato    1
# titolare di ditta individuale     1
# partita iva personale             1
# partita iva                       1
# assegno di ricerca                1
# titolare di partita iva           1
# titolare di una ditta             1
# titolare di azienda               1
# ceo                               1
# contratto di apprendistato        1
# ditta individuale                 1
# titolare studio                   1
# dtype: int64
#
# Data %:
# libero professionista             2.912621
# per il momento di volontariato    0.970874
# titolare di ditta individuale     0.970874
# partita iva personale             0.970874
# partita iva                       0.970874
# assegno di ricerca                0.970874
# titolare di partita iva           0.970874
# titolare di una ditta             0.970874
# titolare di azienda               0.970874
# ceo                               0.970874
# contratto di apprendistato        0.970874
# ditta individuale                 0.970874
# titolare studio                   0.970874
# dtype: float64

# %%
# Filter and integrate "other" data with data manually
contract["Collaborazione con/senza Partita IVA (Freelance)"] += 8
contract.ix["Titolare azienda"] = 4
contract.ix["Volontariato"] = 1
contract.ix["Assegno di ricerca"] = 1
contract.ix["Apprendistato"] = 1
contract = contract.drop("Altro")
print contract
# Out:
# Collaborazione con/senza Partita IVA (Freelance)    74
# NaN                                                 21
# Contratto a tempo indeterminato (Permanent job)     20
# Contratto a tempo determinato (Temporary job)        7
# Contratto a progetto                                 4
# Borsa di studio                                      2
# Titolare azienda                                     4
# Volontariato                                         1
# Assegno di ricerca                                   1
# Apprendistato                                        1
# dtype: int64

# %%
# Plot updated bar
plt.figure(figsize=(8,6))
plt.title('Maker: Tipi di Contratto')
plt.xticks(range(len(contract.index)),contract.index,rotation=90)
plt.xlabel('Tipi di contratto')
plt.ylabel('Persone')
ind = np.arange(len(contract))   # the x locations for the groups
width = 0.35                         # the width of the bars

my_colors = seaborn.color_palette("husl", len(contract)) # Set color palette
rect1 = plt.bar(ind,contract,width,color=my_colors,align='center')
plt.savefig("pdf/Q016-MakerTipiContratto01.pdf") # Save pdf

# %%
# Percentage of the updated data
percentage_contract = contract / contract.sum() * 100
percentage_contract
# Out:
# Collaborazione con/senza Partita IVA (Freelance)    54.814815
# NaN                                                 15.555556
# Contratto a tempo indeterminato (Permanent job)     14.814815
# Contratto a tempo determinato (Temporary job)        5.185185
# Contratto a progetto                                 2.962963
# Borsa di studio                                      1.481481
# Titolare azienda                                     2.962963
# Volontariato                                         0.740741
# Assegno di ricerca                                   0.740741
# Apprendistato                                        0.740741
# dtype: float64
