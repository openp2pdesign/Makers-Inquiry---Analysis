# %% [markdown]
# # Q016 - Che tipo di contratto hai?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get the distribution of contract type
contract = data["Q016"].value_counts(dropna=False)
print "Data:"
print contract
print ""
print "Data %:"
print data["Q016"].value_counts(normalize=True,dropna=False) * 100

# %%
# Save+show the output to a text file
# %save Q016-MakerTipiContratto01.py str(output)
shutil.move("Q016-MakerTipiContratto01.py", "text/Q016-MakerTipiContratto01.txt")
# Out:
# The following commands were written to file `Q016-MakerTipiContratto01.py`:
# Data:
# Collaborazione con/senza Partita IVA (Freelance)    42
# NaN                                                 29
# Contratto a tempo indeterminato (Permanent job)     23
# Altro                                               22
# Contratto a tempo determinato (Temporary job)        7
# Borsa di studio                                      6
# Contratto a progetto                                 5
# dtype: int64
#
# Data %:
# Collaborazione con/senza Partita IVA (Freelance)    31.343284
# NaN                                                 21.641791
# Contratto a tempo indeterminato (Permanent job)     17.164179
# Altro                                               16.417910
# Contratto a tempo determinato (Temporary job)        5.223881
# Borsa di studio                                      4.477612
# Contratto a progetto                                 3.731343
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Tipi di contratto', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title("Che tipo di contratto hai?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(contract)) # Set color palette
contract.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q016-MakerTipiContratto01.svg")
plt.savefig("png/Q016-MakerTipiContratto01.png")
plt.savefig("pdf/Q016-MakerTipiContratto01.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get "other" data
contract_other = data["Q016[other]"].str.lower().value_counts()
print "Data:"
print contract_other
print ""
print "Data %:"
print data["Q016[other]"].str.lower().value_counts(normalize=True) * 100

# %%
# Save+show the output to a text file
# %save Q016-MakerTipiContratto02.py str(Q016b)
shutil.move("Q016-MakerTipiContratto02.py", "text/Q016-MakerTipiContratto02.txt")
# Out:
# The following commands were written to file `Q016-MakerTipiContratto02.py`:
# Data:
# libero professionista                               3
# per il momento di volontariato                      1
# p. iva                                              1
# srl                                                 1
# attivista                                           1
# ditta individuale                                   1
# contratto di apprendistato                          1
# ceo                                                 1
# amministratore unico fablab venezia srls            1
# titolare                                            1
# titolare di azienda                                 1
# titolare di ditta individuale                       1
# amministratore di società, consulente a progetto    1
# titolare di una ditta                               1
# titolare di partita iva                             1
# assegno di ricerca                                  1
# ...

# %%
# Plot bar
plt.figure(figsize=(8,6))
plt.title('Che tipo di contratto hai? Altro', fontsize=18, y=1.02)
plt.xticks(range(len(contract_other.index)),contract_other.index,rotation=90)
plt.xlabel('Tipi di contratto', fontsize=16)
plt.ylabel('Persone', fontsize=16)
ind = np.arange(len(contract_other))   # the x locations for the groups
width = 0.35                         # the width of the bars

my_colors = seaborn.color_palette("husl", len(contract_other)) # Set color palette
rect1 = plt.bar(ind,contract_other,width,color=my_colors,align='center')
plt.savefig("svg/Q016-MakerTipiContratto02.svg")
plt.savefig("png/Q016-MakerTipiContratto02.png")
plt.savefig("pdf/Q016-MakerTipiContratto02.pdf")

# %%
# Filter and integrate "other" data with data manually
contract["Collaborazione con/senza Partita IVA (Freelance)"] += 9
contract.ix["Titolare azienda"] = 9
contract.ix["Volontariato"] = 1
contract.ix["Assegno di ricerca"] = 1
contract.ix["Apprendistato"] = 1
contract.ix["Non specificato"] = 1
contract = contract.drop("Altro")
print contract
# Out:
# Collaborazione con/senza Partita IVA (Freelance)    51
# NaN                                                 29
# Contratto a tempo indeterminato (Permanent job)     23
# Contratto a tempo determinato (Temporary job)        7
# Borsa di studio                                      6
# Contratto a progetto                                 5
# Titolare azienda                                     9
# Volontariato                                         1
# Assegno di ricerca                                   1
# Apprendistato                                        1
# Non specificato                                      1
# dtype: int64

# %%
# Plot updated bar
plt.figure(figsize=(8,6))
plt.title('Che tipo di contratto hai?', fontsize=18, y=1.02)
plt.xticks(range(len(contract.index)),contract.index,rotation=90)
plt.xlabel('Tipi di contratto', fontsize=16)
plt.ylabel('Persone', fontsize=16)
ind = np.arange(len(contract))   # the x locations for the groups
width = 0.35                         # the width of the bars

my_colors = seaborn.color_palette("husl", len(contract)) # Set color palette
rect1 = plt.bar(ind,contract,width,color=my_colors,align='center')
plt.savefig("svg/Q016-MakerTipiContratto01.svg")
plt.savefig("png/Q016-MakerTipiContratto01.png")
plt.savefig("pdf/Q016-MakerTipiContratto01.pdf")

# %%
# Percentage of the updated data
percentage_contract = contract / contract.sum() * 100
percentage_contract
# Out:
# Collaborazione con/senza Partita IVA (Freelance)    38.059701
# NaN                                                 21.641791
# Contratto a tempo indeterminato (Permanent job)     17.164179
# Contratto a tempo determinato (Temporary job)        5.223881
# Borsa di studio                                      4.477612
# Contratto a progetto                                 3.731343
# Titolare azienda                                     6.716418
# Volontariato                                         0.746269
# Assegno di ricerca                                   0.746269
# Apprendistato                                        0.746269
# Non specificato                                      0.746269
# dtype: float64
