# %% [markdown]
# # Q056 - In che modo comunichi la tua offerta di servizi?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q056[SQ001] - Q056[SQ005] - Q056[other]

offer_columns = ['Q056[SQ001]','Q056[SQ002]','Q056[SQ003]','Q056[SQ004]','Q056[SQ005]']
offer_options = ['Sito web del makerspace','Altre piattaforme web','Social media','Partecipazione a fiere ed eventi','Conoscenze personai (passaparola)']
offer = data[offer_columns]
offer.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
offer_other = data['Q057[other]'].str.lower().value_counts()
# Out:
# -c:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#offer[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(offer_columns)+1):
    comb = list(itertools.combinations(offer_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in offer_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = offer_columns.index(j) # Get position
            comb_list.append(offer_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in offer.index:
    current_bool_list = list(offer.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
offer["Combination"] = pd.Series(str_values)
# Out:
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Gather data
resulting_combinations = offer["Combination"].value_counts(dropna=False)
resulting_combinations_percentage = offer["Combination"].value_counts(normalize=True,dropna=False)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.title(u"In che modo comunichi la tua offerta di servizi? Combinazioni", fontsize=18, y=1.02)
plt.ylabel("Persone", fontsize=16)
plt.xlabel("Combinazioni", fontsize=16)
plt.savefig("svg/Q056-Combinazioni.svg")
plt.savefig("png/Q056-Combinazioni.png")
plt.savefig("pdf/Q056-Combinazioni.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Data of the combinations
print "Data:"
print resulting_combinations
print
# Data of the combinations: percentage
print "Data %:"
print resulting_combinations_percentage

# %%
# Save+show the output to a text file
# %save Q056-Combinazioni.py str(output)
shutil.move("Q056-Combinazioni.py", "text/Q056-Combinazioni.txt")
# Out:
# The following commands were written to file `Q056-Combinazioni.py`:
# Data:
# NaN                                                             110
# Sito web del makerspace, Social media, Partecipazione a fiere ed eventi, Conoscenze personai (passaparola)      7
# Sito web del makerspace, Social media, Partecipazione a fiere ed eventi      5
# Sito web del makerspace, Altre piattaforme web, Social media, Partecipazione a fiere ed eventi, Conoscenze personai (passaparola)      2
# Social media, Partecipazione a fiere ed eventi, Conoscenze personai (passaparola)      2
# Sito web del makerspace, Partecipazione a fiere ed eventi         1
# Sito web del makerspace, Social media                             1
# Sito web del makerspace, Altre piattaforme web, Social media, Partecipazione a fiere ed eventi      1
# Sito web del makerspace, Social media, Conoscenze personai (passaparola)      1
# ...
