# %% [markdown]
# # Q043 - Come vendi i tuoi prodotti?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q043[SQ001] - Q043[SQ006] - Q039[other]

sale_columns = ['Q043[SQ001]','Q043[SQ002]','Q043[SQ003]','Q043[SQ004]','Q043[SQ005]','Q043[SQ006]']
sale_options = ['Fiere',
                  'Mostre-mercato',
                  'Personal marketplace',
                  'Piattaforme e-commerce',
                  'Passaparola',
                  'Negozio (anche temporary shop)']
sale = data[sale_columns]
sale.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
sale_other = data['Q043[other]'].str.lower().value_counts()
# Out:
# -c:11: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %%
sale[0:4]
# Out:
#   Q043[SQ001] Q043[SQ002] Q043[SQ003] Q043[SQ004] Q043[SQ005] Q043[SQ006]
# 0          No          No          No          No          No          No
# 1          No          No          No          No          No          No
# 2          No          No          No          No          Si          No
# 3          No          No          Si          No          No          Si

# %%
# Gather data
sale_b = {}
for k,i in enumerate(sale_columns):
    sale_b[k] = sale[i].value_counts()
    print "Data:",sale_options[k]
    print sale_b[k]
    print
    print "Data %:",sale_options[k]
    print sale[i].value_counts(normalize=True)*100
    print
    
yes = []
no = []

# Get data for plotting, and check that we have all the values for Yes and No
for k,i in enumerate(sale_columns):
    if len(sale_b[k].index) == 2:
        if sale_b[k].index[0] == "Si":
            yes.append(sale_b[k].iloc[0])
            no.append(sale_b[k].iloc[1])
        elif sale_b[k].index[1] == "Si":
            yes.append(sale_b[k].iloc[1])
            no.append(sale_b[k].iloc[0])
    elif len(sale_b[k].index) == 1:
        if sale_b[k].index[0] == "Si":
            yes.append(sale_b[k].iloc[0])
            no.append(0)
        elif sale_b[k].index[0] == "No":
            yes.append(0)
            no.append(sale_b[k].iloc[0])
    else:
        yes.append(0)
        no.append(0)

# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel('Modi di vendita')
plt.ylabel('Persone')
plt.title('Maker: Come vendi')
plt.xticks(range(len(sale_options)),sale_options,rotation=90)
ind = np.arange(len(sale_columns))   # the x locations for the groups
width = 0.35                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 2) # Set color palette
rect1 = plt.bar(ind,yes,width,color=my_colors[1],align='center') # Plot Yes
rect2 = plt.bar(ind+width,no,width,color=my_colors[0],align='center') # Plot No 
plt.legend( (rect1, rect2), ('Si', 'No') )
plt.savefig("pdf/Q043-MakerComeVendi01.pdf")
# Out:
# Data: Fiere
# No    98
# Si    35
# dtype: int64
#
# Data %: Fiere
# No    73.134328
# Si    26.119403
# dtype: float64
#
# Data: Mostre-mercato
# No    90
# Si    43
# dtype: int64
#
# Data %: Mostre-mercato
# No    67.164179
# Si    32.089552
# dtype: float64
#
# Data: Personal marketplace
# No    110
# Si     23
# dtype: int64
#
# Data %: Personal marketplace
# No    82.089552
# Si    17.164179
# dtype: float64
#
# Data: Piattaforme e-commerce
# No    82
# Si    51
# dtype: int64
#
# Data %: Piattaforme e-commerce
# No    61.194030
# Si    38.059701
# dtype: float64
#
# Data: Passaparola
# No    81
# Si    52
# dtype: int64
#
# Data %: Passaparola
# No    60.447761
# Si    38.805970
# dtype: float64
#
# Data: Negozio (anche temporary shop)
# No    95
# Si    38
# dtype: int64
#
# Data %: Negozio (anche temporary shop)
# No    70.895522
# Si    28.358209
# dtype: float64

# %%
# Get "other" data
sale_other = data["Q043[other]"].str.lower().value_counts()
print "Data:"
print sale_other
print ""
print "Data %:"
print data["Q043[other]"].str.lower().value_counts(normalize=True) * 100

# Plot bar
plt.figure(figsize=(8,6))
plt.title('Maker: Approcci alla progettazione. Altro')
plt.xticks(range(len(sale_other.index)),sale_other.index,rotation=90)
plt.xlabel('Approcci')
plt.ylabel('Persone')
ind = np.arange(len(sale_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(sale_other)) # Set color palette
rect1 = plt.bar(ind,sale_other,width,color=my_colors,align='center')
plt.savefig("pdf/Q043-MakerComeVendi02.pdf") # Save pdf
# Out:
# Data:
# non vendo                                        6
# diretta su commissione                           1
# nn vendo prodotti.                               1
# non produco per vendere                          1
# sito web personale                               1
# finira non vendo                                 1
# corsi laboratori workshop                        1
# non li vendo                                     1
# con la fattura                                   1
# non vendo ma condivido su internet i progetti    1
# non vendo prodotti                               1
# fablab                                           1
# non vendo, solamente progetti scolastici.        1
# non li vendo. li progetto.                       1
# non vendo, produco su richiesta                  1
# direttamente alle aziende                        1
# dtype: int64
#
# Data %:
# non vendo                                        4.477612
# ...
