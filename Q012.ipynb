# %% [markdown]
# # Q012 - Qual è il tuo reddito annuale (espresso in fasce)?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get the distribution of way of living
income = data["Q012"].value_counts(dropna=False)
print "Data:"
print income
print ""
print "Data %:"
print data["Q012"].value_counts(normalize=True,dropna=False) * 100

# %%
# Save+show the output to a text file
# %save Q012-MakerReddito01.py str(output)
shutil.move("Q012-MakerReddito01.py", "text/Q012-MakerReddito01.txt")
# Out:
# The following commands were written to file `Q012-MakerReddito01.py`:
# Data:
# Meno di 25.000 €     49
# Meno di 10.000 €     31
# Meno di 50.000 €     23
# Non ho reddito       14
# NaN                  12
# Meno di 100.000 €     3
# Oltre 100.000 €       2
# dtype: int64
#
# Data %:
# Meno di 25.000 €     36.567164
# Meno di 10.000 €     23.134328
# Meno di 50.000 €     17.164179
# Non ho reddito       10.447761
# NaN                   8.955224
# Meno di 100.000 €     2.238806
# Oltre 100.000 €       1.492537
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Reddito', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u"Qual è il tuo reddito annuale (espresso in fasce)?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(income)) # Set color palette
income.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q012-MakerReddito01.svg")
plt.savefig("png/Q012-MakerReddito01.png")
plt.savefig("pdf/Q012-MakerReddito01.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file

# Order of the choices
income_order = [np.nan,"Non ho reddito",u"Meno di 10.000 €",u"Meno di 25.000 €",u"Meno di 50.000 €",u"Meno di 100.000 €",u"Oltre 100.000 €"]

income2 = income.reindex(income_order)

# Get the distribution of way of living, reindexed
print "Data:"
print income2
print ""
print "Data %:"
income2_normalized = data["Q012"].value_counts(normalize=True) * 100
print income2_normalized.reindex(income_order)

# %%
# Save+show the output to a text file
# %save Q012-MakerReddito02.py str(Q012b)
shutil.move("Q012-MakerReddito02.py", "text/Q012-MakerReddito02.txt")
# Out:
# The following commands were written to file `Q012-MakerReddito02.py`:
# Data:
# NaN                  12
# Non ho reddito       14
# Meno di 10.000 €     31
# Meno di 25.000 €     49
# Meno di 50.000 €     23
# Meno di 100.000 €     3
# Oltre 100.000 €       2
# dtype: int64
#
# Data %:
# NaN                        NaN
# Non ho reddito       10.447761
# Meno di 10.000 €     23.134328
# Meno di 25.000 €     36.567164
# Meno di 50.000 €     17.164179
# Meno di 100.000 €     2.238806
# Oltre 100.000 €       1.492537
# dtype: float64

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel(u'Reddito', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title(u"Qual è il tuo reddito annuale (espresso in fasce)?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(income2)) # Set color palette
income2.plot(kind="bar",color=my_colors)
plt.savefig("svg/Q012-MakerReddito02.svg")
plt.savefig("png/Q012-MakerReddito02.png")
plt.savefig("pdf/Q012-MakerReddito02.pdf")
