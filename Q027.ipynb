# %% [markdown]
# # Q027 - Quali sono le motivazioni che ti spingono a occuparti di making?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# %%
# Load csv file first
data = pd.read_csv("data/results-makers.csv", encoding="utf-8")

# %%
# Re-format colums to fix a mistake
# Comment/delete this if not part of the Italian research
substitutes = ['id','submitdate','lastpage','startlanguage','startdate','datestamp','ipaddr',
               'Q001','Q002','Q003','Q004','Q005','Q006','Q007','Q007[other]','Q008','Q009[SQ001]',
               'Q009[SQ002]','Q009[SQ003]','Q009[SQ004]','Q009[SQ005]','Q009[SQ006]','Q009[other]',
               'Q010','Q011','Q011[other]','Q012','Q013','Q014','Q015','Q016','Q016[other]','Q017',
               'Q018','Q019[SQ001]','Q019[SQ002]','Q019[SQ003]','Q019[SQ004]','Q019[SQ005]','Q019[SQ006]',
               'Q019[SQ007]','Q019[SQ008]','Q019[SQ009]','Q019[other]','Q020[SQ001]','Q021[SQ001]',
               'Q021[SQ002]','Q021[SQ003]','Q021[SQ004]','Q021[SQ005]','Q022[SQ001]','Q022[SQ002]',
               'Q022[SQ003]','Q022[SQ004]','Q022[SQ005]','Q023[SQ001]','Q023[SQ002]','Q023[SQ003]',
               'Q023[SQ004]','Q023[SQ005]','Q024[SQ001]','Q024[SQ002]','Q024[SQ003]','Q024[SQ004]',
               'Q024[SQ005]','Q024[other]','Q025','Q026','Q027[SQ001]','Q027[SQ002]','Q027[SQ003]',
               'Q027[SQ004]','Q027[SQ005]','Q027[SQ006]','Q027[SQ007]','Q027[SQ008]','Q027[other]',
               'Q028[SQ001]','Q028[SQ002]','Q028[SQ003]','Q028[SQ004]','Q028[SQ005]','Q028[SQ006]',
               'Q028[SQ007]','Q028[SQ008]','Q028[SQ009]','Q028[SQ010]','Q028[SQ011]','Q028[other]',
               'Q029[SQ001]','Q029[SQ002]','Q029[SQ003]','Q029[SQ004]','Q029[SQ005]','Q030[SQ001]',
               'Q030[SQ002]','Q030[SQ003]','Q030[SQ004]','Q030[SQ005]','Q030[SQ006]','Q030[SQ007]',
               'Q031','Q032','Q032[other]','Q033[SQ001]','Q033[SQ002]','Q033[SQ003]','Q033[SQ004]',
               'Q033[other]','Q034','Q035','Q036[SQ001]','Q036[SQ002]','Q036[SQ013]','Q036[SQ003]',
               'Q036[SQ004]','Q036[SQ005]','Q036[SQ006]','Q036[SQ007]','Q036[SQ008]','Q036[SQ009]',
               'Q036[SQ010]','Q036[SQ011]','Q036[SQ012]','Q036[other]','Q037[SQ001]','Q037[SQ002]',
               'Q037[SQ003]','Q037[SQ004]','Q037[SQ005]','Q037[other]','Q038','Q039[SQ001]','Q039[SQ002]',
               'Q039[SQ003]','Q039[SQ004]','Q039[SQ005]','Q039[other]','Q040[SQ001]','Q040[SQ002]',
               'Q040[SQ003]','Q041[SQ001]','Q041[SQ002]','Q041[SQ003]','Q042[SQ001]','Q042[SQ002]',
               'Q042[SQ003]','Q042[SQ004]','Q042[other]','Q043[SQ001]','Q043[SQ002]','Q043[SQ003]',
               'Q043[SQ004]','Q043[SQ005]','Q043[SQ006]','Q043[other]','Q044[SQ001]','Q044[SQ002]',
               'Q044[SQ003]','Q044[SQ004]','Q044[SQ005]','Q044[SQ006]','Q044[SQ007]','Q044[SQ008]',
               'Q044[SQ009]','Q045','Q046','Q047[SQ001]','Q047[SQ002]','Q047[SQ003]','Q047[SQ004]',
               'Q047[other]','Q048[SQ001]','Q048[SQ002]','Q048[SQ003]','Q048[SQ004]','Q048[SQ005]',
               'Q048[other]','Q049[SQ001]','Q049[SQ002]','Q049[SQ003]','Q049[SQ004]','Q049[other]',
               'Q050[SQ001]','Q050[SQ002]','Q050[SQ003]','Q050[SQ004]','Q050[SQ005]','Q050[SQ006]',
               'Q050[SQ007]','Q050[SQ008]','Q050[other]','Q051[SQ001]','Q051[SQ002]','Q051[SQ003]',
               'Q051[SQ004]','Q051[SQ005]','Q051[SQ006]','Q051[other]','Q052[SQ001]','Q052[SQ002]',
               'Q052[SQ003]','Q052[SQ004]','Q052[SQ005]','Q052[SQ006]','Q052[SQ007]','Q052[SQ008]',
               'Q052[SQ009]','Q052[SQ010]','Q052[SQ011]','Q052[other]','Q053[SQ001]','Q053[SQ002]',
               'Q053[SQ003]','Q053[SQ004]','Q053[other]','Q054[SQ001]','Q054[SQ002]','Q054[SQ003]',
               'Q054[SQ004]','Q054[SQ005]','Q054[SQ006]','Q054[SQ007]','Q054[SQ008]','Q054[SQ009]',
               'Q054[SQ010]','Q054[other]','Q055[SQ001]','Q055[SQ002]','Q055[SQ003]','Q055[SQ004]',
               'Q055[SQ005]','Q055[SQ006]','Q055[SQ007]','Q055[SQ008]','Q055[SQ009]','Q055[SQ010]',
               'Q055[other]','Q056[SQ001]','Q056[SQ002]','Q056[SQ003]','Q056[SQ004]','Q056[SQ005]',
               'Q056[other]','Q057[SQ001]','Q057[SQ002]','Q057[other]','Q058[SQ001]','Q058[SQ002]',
               'Q058[SQ003]','Q058[SQ004]','Q058[SQ005]','Q058[other]','Q059[SQ001]','Q059[SQ002]',
               'Q059[SQ003]','Q059[other]','Q060','Q061','Q062[SQ001]','Q062[SQ002]','Q062[SQ003]',
               'Q062[SQ004]','Q062[SQ005]','Q062[other]','Q063[SQ001]','Q063[SQ002]','Q063[SQ003]',
               'Q064','Q065','Q065[filecount]','Q066[SQ001]','Q066[SQ002]','Q066[SQ003]','Q067','Q067[filecount]'
               ]

data.columns = substitutes

# %%
# Check data
data[0:4] # Equals to data.head()
# Out:
#    id           submitdate  lastpage startlanguage            startdate  \
# 0   1  2014-07-01 02:33:43        12            it  2014-07-01 02:03:09
# 1   2                  NaN         3            it  2014-07-01 02:36:40
# 2   4                  NaN         1            it  2014-07-03 03:05:31
# 3   5                  NaN       NaN            it  2014-07-03 03:57:01
#
#              datestamp ipaddr                        Q001 Q002  Q003     Q004  \
# 0  2014-07-01 02:33:43    NaN       Gestore di makerspace  NaN    41  Maschio
# 1  2014-07-01 02:38:02    NaN  Progettista autoproduttore  NaN   NaN      NaN
# 2  2014-07-03 03:06:04    NaN  Progettista autoproduttore  NaN   NaN      NaN
# 3  2014-07-03 03:57:01    NaN                         NaN  NaN   NaN      NaN
#
#        Q005           Q006                         Q007 Q007[other]  \
# 0  italiana  reggio emilia  Laurea triennale (Bachelor)         NaN
# 1       NaN            NaN                          NaN         NaN
# 2       NaN            NaN                          NaN         NaN
# 3       NaN            NaN                          NaN         NaN
#
#                     Q008 Q009[SQ001] Q009[SQ002] Q009[SQ003] Q009[SQ004]  \
# 0  architettura e design          Sì          Sì          Sì          Sì
# 1           hpijipoopkoè          No          No          No          No
# 2                    NaN         NaN         NaN         NaN         NaN
# 3                    NaN         NaN         NaN         NaN         NaN
#
#   Q009[SQ005] Q009[SQ006] Q009[other]  \
# 0          No          No         NaN
# 1          No          No         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
#
#                                                 Q010                 Q011  \
# 0  arte cinema design architettura pedagogia musi...  In coppia con figli
# 1                                      jopèkoèkèokèk                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
#
#   Q011[other]              Q012                          Q013  \
# 0         NaN  Meno di 50.000 €                            Si
# 1         NaN               NaN  No, è un’attività secondaria
# 2         NaN               NaN                           NaN
# 3         NaN               NaN                           NaN
#
#                                            Q014        Q015  \
# 0                                           NaN         NaN
# 1  Sono un lavoratore dipendente (microimpresa)  jpkèpkpèpè
# 2                                           NaN         NaN
# 3                                           NaN         NaN
#
#                                                Q016 Q016[other]  \
# 0  Collaborazione con/senza Partita IVA (Freelance)         NaN
# 1                              Contratto a progetto         NaN
# 2                                               NaN         NaN
# 3                                               NaN         NaN
#
#             Q017                                               Q018  \
# 0  Da 1 a 5 anni  1 collega fisso e molti collaboratori temporan...
# 1            NaN                                ipjopkoèkpoèkpè+lp+
# 2            NaN                                                NaN
# 3            NaN                                                NaN
#
#   Q019[SQ001] Q019[SQ002] Q019[SQ003] Q019[SQ004] Q019[SQ005] Q019[SQ006]  \
# 0          No          No          No          No          No          No
# 1          No          No          No          No          Sì          No
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q019[SQ007] Q019[SQ008] Q019[SQ009] Q019[other] Q020[SQ001] Q021[SQ001]  \
# 0          No          No          Sì         NaN         80%     nessuna
# 1          No          No          No         NaN         20%         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#        Q021[SQ002]      Q021[SQ003]                              Q021[SQ004]  \
# 0  arduino+sensori  disegno 2d e 3d  3d print , laser cut, frese, scanner 3D
# 1              NaN              NaN                                      NaN
# 2              NaN              NaN                                      NaN
# 3              NaN              NaN                                      NaN
#
#                                      Q021[SQ005] Q022[SQ001] Q022[SQ002]  \
# 0  macchina da cucire, trapani , seghe circolari     Nessuno  Elementare
# 1                                            NaN         NaN         NaN
# 2                                            NaN         NaN         NaN
# 3                                            NaN         NaN         NaN
#
#      Q022[SQ003]    Q022[SQ004] Q022[SQ005] Q023[SQ001]  \
# 0  Professionale  Professionale  Amatoriale         NaN
# 1            NaN            NaN         NaN         NaN
# 2            NaN            NaN         NaN         NaN
# 3            NaN            NaN         NaN         NaN
#
#                               Q023[SQ002] Q023[SQ003]  \
# 0  Autodidatta (Online/offline community)      Lavoro
# 1                                     NaN         NaN
# 2                                     NaN         NaN
# 3                                     NaN         NaN
#
#                               Q023[SQ004]  \
# 0  Autodidatta (Online/offline community)
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
#
#                               Q023[SQ005] Q024[SQ001] Q024[SQ002] Q024[SQ003]  \
# 0  Autodidatta (Online/offline community)          Sì          Sì          Sì
# 1                                     NaN         NaN         NaN         NaN
# 2                                     NaN         NaN         NaN         NaN
# 3                                     NaN         NaN         NaN         NaN
#
#   Q024[SQ004] Q024[SQ005] Q024[other]  \
# 0          No          No         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
#
#                                                 Q025  \
# 0  seguo social , leggo riviste di settore e blog...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                                                 Q026 Q027[SQ001] Q027[SQ002]  \
# 0  Una persona  che si ingegna per fare cose e so...          Sì          No
# 1                                                NaN         NaN         NaN
# 2                                                NaN         NaN         NaN
# 3                                                NaN         NaN         NaN
#
#   Q027[SQ003] Q027[SQ004] Q027[SQ005] Q027[SQ006] Q027[SQ007] Q027[SQ008]  \
# 0          Sì          Sì          No          No          Sì          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q027[other] Q028[SQ001] Q028[SQ002] Q028[SQ003] Q028[SQ004] Q028[SQ005]  \
# 0         NaN          No          Sì          Sì          Sì          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q028[SQ006] Q028[SQ007] Q028[SQ008] Q028[SQ009] Q028[SQ010] Q028[SQ011]  \
# 0          Sì          Sì          No          No          No          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q028[other]              Q029[SQ001]             Q029[SQ002]  \
# 0         NaN  Completamente d’accordo  Parzialmente d’accordo
# 1         NaN                      NaN                     NaN
# 2         NaN                      NaN                     NaN
# 3         NaN                      NaN                     NaN
#
#               Q029[SQ003]             Q029[SQ004]             Q029[SQ005]  \
# 0  Parzialmente d’accordo  Parzialmente d’accordo  Parzialmente d’accordo
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
#
#   Q030[SQ001] Q030[SQ002] Q030[SQ003] Q030[SQ004] Q030[SQ005] Q030[SQ006]  \
# 0       Molto       Molto       Molto       Molto       Molto       Molto
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q030[SQ007]                   Q031     Q032 Q032[other] Q033[SQ001]  \
# 0       Molto  Si, sono socio/membro  Fab Lab         NaN          No
# 1         NaN                    NaN      NaN         NaN         NaN
# 2         NaN                    NaN      NaN         NaN         NaN
# 3         NaN                    NaN      NaN         NaN         NaN
#
#   Q033[SQ002] Q033[SQ003] Q033[SQ004] Q033[other]          Q034  \
# 0          No          No          No     manager  Tra 50 e 100
# 1         NaN         NaN         NaN         NaN           NaN
# 2         NaN         NaN         NaN         NaN           NaN
# 3         NaN         NaN         NaN         NaN           NaN
#
#               Q035 Q036[SQ001] Q036[SQ002] Q036[SQ013] Q036[SQ003]  \
# 0  Si, sono membro          Sì          Sì          No          Sì
# 1              NaN         NaN         NaN         NaN         NaN
# 2              NaN         NaN         NaN         NaN         NaN
# 3              NaN         NaN         NaN         NaN         NaN
#
#   Q036[SQ004] Q036[SQ005] Q036[SQ006] Q036[SQ007] Q036[SQ008] Q036[SQ009]  \
# 0          No          No          No          No          No          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q036[SQ010] Q036[SQ011] Q036[SQ012] Q036[other] Q037[SQ001] Q037[SQ002]  \
# 0          No          No          No         NaN          Sì          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q037[SQ003] Q037[SQ004] Q037[SQ005]  Q037[other]           Q038 Q039[SQ001]  \
# 0          Sì          No          Sì          NaN  Tra 100 e 500          Sì
# 1         NaN         NaN         NaN          NaN            NaN         NaN
# 2         NaN         NaN         NaN          NaN            NaN         NaN
# 3         NaN         NaN         NaN          NaN            NaN         NaN
#
#   Q039[SQ002] Q039[SQ003] Q039[SQ004] Q039[SQ005] Q039[other] Q040[SQ001]  \
# 0          Sì          Sì          No          Sì         NaN         80%
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q040[SQ002] Q040[SQ003] Q041[SQ001] Q041[SQ002] Q041[SQ003] Q042[SQ001]  \
# 0         20%         NaN         70%         30%         NaN          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q042[SQ002] Q042[SQ003] Q042[SQ004] Q042[other] Q043[SQ001] Q043[SQ002]  \
# 0          Sì          No          Sì         NaN          No          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q043[SQ003] Q043[SQ004] Q043[SQ005] Q043[SQ006] Q043[other] Q044[SQ001]  \
# 0          No          No          No          No   non vendo          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q044[SQ002] Q044[SQ003] Q044[SQ004] Q044[SQ005] Q044[SQ006] Q044[SQ007]  \
# 0          Sì          Sì          No          No          Sì          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q044[SQ008] Q044[SQ009]                     Q045              Q046  \
# 0          Sì          Sì  industrial design , ICT  Meno di 50 unità
# 1         NaN         NaN                      NaN               NaN
# 2         NaN         NaN                      NaN               NaN
# 3         NaN         NaN                      NaN               NaN
#
#   Q047[SQ001] Q047[SQ002] Q047[SQ003] Q047[SQ004] Q047[other] Q048[SQ001]  \
# 0          No          No          No          No  networking          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q048[SQ002] Q048[SQ003] Q048[SQ004] Q048[SQ005] Q048[other] Q049[SQ001]  \
# 0          Sì          Sì          Sì          Sì         NaN          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q049[SQ002] Q049[SQ003] Q049[SQ004] Q049[other] Q050[SQ001] Q050[SQ002]  \
# 0          Sì          No          Sì         NaN          Sì          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q050[SQ003] Q050[SQ004] Q050[SQ005] Q050[SQ006] Q050[SQ007] Q050[SQ008]  \
# 0          No          No          No          Sì          No          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q050[other] Q051[SQ001] Q051[SQ002] Q051[SQ003] Q051[SQ004] Q051[SQ005]  \
# 0         NaN          Sì          Sì          No          Sì          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q051[SQ006] Q051[other] Q052[SQ001] Q052[SQ002] Q052[SQ003] Q052[SQ004]  \
# 0          No         NaN          No          Sì          No          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q052[SQ005] Q052[SQ006] Q052[SQ007] Q052[SQ008] Q052[SQ009] Q052[SQ010]  \
# 0          No          No          Sì          No          Sì          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q052[SQ011] Q052[other] Q053[SQ001] Q053[SQ002] Q053[SQ003] Q053[SQ004]  \
# 0          Sì         NaN          Sì          No          Sì          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q053[other] Q054[SQ001] Q054[SQ002] Q054[SQ003] Q054[SQ004] Q054[SQ005]  \
# 0         NaN          Sì          Sì          Sì          Sì          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q054[SQ006] Q054[SQ007] Q054[SQ008] Q054[SQ009] Q054[SQ010]  Q054[other]  \
# 0          Sì          Sì          No          Sì          Sì          NaN
# 1         NaN         NaN         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN         NaN         NaN          NaN
#
#   Q055[SQ001] Q055[SQ002] Q055[SQ003] Q055[SQ004] Q055[SQ005] Q055[SQ006]  \
# 0          Sì          Sì          Sì          Sì          Sì          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q055[SQ007] Q055[SQ008] Q055[SQ009] Q055[SQ010]  Q055[other] Q056[SQ001]  \
# 0          Sì          Sì          Sì          Sì          NaN          Sì
# 1         NaN         NaN         NaN         NaN          NaN         NaN
# 2         NaN         NaN         NaN         NaN          NaN         NaN
# 3         NaN         NaN         NaN         NaN          NaN         NaN
#
#   Q056[SQ002] Q056[SQ003] Q056[SQ004] Q056[SQ005]  Q056[other] Q057[SQ001]  \
# 0          No          Sì          Sì          Sì          NaN          Sì
# 1         NaN         NaN         NaN         NaN          NaN         NaN
# 2         NaN         NaN         NaN         NaN          NaN         NaN
# 3         NaN         NaN         NaN         NaN          NaN         NaN
#
#   Q057[SQ002] Q057[other] Q058[SQ001] Q058[SQ002] Q058[SQ003] Q058[SQ004]  \
# 0          Sì         NaN          Sì          Sì          Sì          Sì
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q058[SQ005]  Q058[other] Q059[SQ001] Q059[SQ002] Q059[SQ003] Q059[other]  \
# 0          Sì          NaN          Sì          Sì          Sì         NaN
# 1         NaN          NaN         NaN         NaN         NaN         NaN
# 2         NaN          NaN         NaN         NaN         NaN         NaN
# 3         NaN          NaN         NaN         NaN         NaN         NaN
#
#     Q060                                               Q061 Q062[SQ001]  \
# 0  Molto  facilitazione e design di processo per abilita...          Sì
# 1    NaN                                                NaN         NaN
# 2    NaN                                                NaN         NaN
# 3    NaN                                                NaN         NaN
#
#   Q062[SQ002] Q062[SQ003] Q062[SQ004] Q062[SQ005] Q062[other] Q063[SQ001]  \
# 0          Sì          Sì          No          Sì         NaN    fab city
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#                   Q063[SQ002] Q063[SQ003]  \
# 0  www.fablabreggioemilia.org         NaN
# 1                         NaN         NaN
# 2                         NaN         NaN
# 3                         NaN         NaN
#
#                                                 Q064 Q065  Q065[filecount]  \
# 0  Vetrina dinamica con cinematismi vari attivabi...   []                0
# 1                                                NaN  NaN              NaN
# 2                                                NaN  NaN              NaN
# 3                                                NaN  NaN              NaN
#
#              Q066[SQ001]                        Q066[SQ002]  \
# 0  Fab Lab Reggio Emilia  Reggio Emilia , Via Spallanzani 1
# 1                    NaN                                NaN
# 2                    NaN                                NaN
# 3                    NaN                                NaN
#
#                   Q066[SQ003] Q067  Q067[filecount]
# 0  www.fablabreggioemilia.org  NaN                0
# 1                         NaN  NaN              NaN
# 2                         NaN  NaN              NaN
# 3                         NaN  NaN              NaN
#
# [4 rows x 276 columns]

# %%
# Range: Q027[SQ001] - Q027[SQ008] - Q027[other]

motivations_columns = ['Q027[SQ001]','Q027[SQ002]','Q027[SQ003]','Q027[SQ004]','Q027[SQ005]','Q027[SQ006]','Q027[SQ007]','Q027[SQ008]']
motivations_options = [u"Voglio sperimentare",u"Voglio apprendere",u"Voglio divertirmi",u"Voglio creare un nuovo prodotto/servizio o un’impresa",
u"Voglio conoscere persone",u"Voglio collaborare con altri", 
u"Voglio dedicarmi a progetti che hanno un impatto positivo sulla comunità locale",
u"Voglio trovare soluzioni alternative ai modelli di consumo vigenti"]

motivations = data[motivations_columns]
motivations.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
motivations_other = data['Q027[other]'].str.lower().value_counts()
# Out:
# -c:10: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %%
motivations[0:4]
# Out:
#   Q027[SQ001] Q027[SQ002] Q027[SQ003] Q027[SQ004] Q027[SQ005] Q027[SQ006]  \
# 0          Si          No          Si          Si          No          No
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Q027[SQ007] Q027[SQ008]
# 0          Si          Si
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
#
# [4 rows x 8 columns]

# %%
# Gather data
motivations_b = {}
for k,i in enumerate(motivations_columns):
    motivations_b[k] = motivations[i].value_counts()
    print "Data:",motivations_options[k]
    print motivations_b[k]
    print
    print "Data %:",motivations_options[k]
    print motivations[i].value_counts(normalize=True)*100
    print
    
yes = []
no = []

# Get data for plotting, and check that we have all the values for Yes and No
for k,i in enumerate(motivations_columns):
    if len(motivations_b[k].index) == 2:
        if motivations_b[k].index[0] == "Si":
            yes.append(motivations_b[k].iloc[0])
            no.append(motivations_b[k].iloc[1])
        elif motivations_b[k].index[1] == "Si":
            yes.append(motivations_b[k].iloc[1])
            no.append(motivations_b[k].iloc[0])
    elif len(motivations_b[k].index) == 1:
        if motivations_b[k].index[0] == "Si":
            yes.append(motivations_b[k].iloc[0])
            no.append(0)
        elif motivations_b[k].index[0] == "No":
            yes.append(0)
            no.append(motivations_b[k].iloc[0])
    else:
        yes.append(0)
        no.append(0)

# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel('Motivi')
plt.ylabel('Persone')
plt.title('Maker: Motivi per il Making')
plt.xticks(range(len(motivations_options)),motivations_options,rotation=90)
ind = np.arange(len(motivations_columns))   # the x locations for the groups
width = 0.35                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 2) # Set color palette
rect1 = plt.bar(ind,yes,width,color=my_colors[0],align='center') # Plot Yes
rect2 = plt.bar(ind+width,no,width,color=my_colors[1],align='center') # Plot No 
plt.legend( (rect1, rect2), ('Si', 'No') )
plt.savefig("pdf/Q027-MakerMotiviMaking01.pdf")
# Out:
# Data: Voglio sperimentare
# Si    62
# No    22
# dtype: int64
# Data %: Voglio sperimentare
# Si    35.428571
# No    12.571429
# dtype: float64
#
# Data: Voglio apprendere
# Si    49
# No    35
# dtype: int64
#
# Data %: Voglio apprendere
# Si    28
# No    20
# dtype: float64
#
# Data: Voglio divertirmi
# Si    44
# No    40
# dtype: int64
#
# Data %: Voglio divertirmi
# Si    25.142857
# No    22.857143
# dtype: float64
#
# Data: Voglio creare un nuovo prodotto/servizio o un’impresa
# Si    57
# No    27
# dtype: int64
#
# Data %: Voglio creare un nuovo prodotto/servizio o un’impresa
# Si    32.571429
# No    15.428571
# dtype: float64
#
# Data: Voglio conoscere persone
# No    59
# Si    25
# dtype: int64
#
# Data %: Voglio conoscere persone
# No    33.714286
# Si    14.285714
# dtype: float64
#
# Data: Voglio collaborare con altri
# No    48
# Si    36
# dtype: int64
#
# Data %: Voglio collaborare con altri
# No    27.428571
# Si    20.571429
# dtype: float64
#
# Data: Voglio dedicarmi a progetti che hanno un impatto positivo sulla comunità locale
# No    47
# Si    37
# dtype: int64
#
# Data %: Voglio dedicarmi a progetti che hanno un impatto positivo sulla comunità locale
# No    26.857143
# Si    21.142857
# dtype: float64
#
# Data: Voglio trovare soluzioni alternative ai modelli di consumo vigenti
# No    46
# Si    38
# dtype: int64
#
# Data %: Voglio trovare soluzioni alternative ai modelli di consumo vigenti
# No    26.285714
# Si    21.714286
# dtype: float64

# %%
# Get "other" data
motivations_other = data["Q027[other]"].str.lower().value_counts()
print "Data:"
print motivations_other
print ""
print "Data %:"
print data["Q027[other]"].str.lower().value_counts(normalize=True) * 100

# Plot bar
plt.figure(figsize=(8,6))
plt.title('Maker: Motivi per il Making. Altro')
plt.xticks(range(len(motivations_other.index)),motivations_other.index,rotation=90)
plt.xlabel('Motivi')
plt.ylabel('Persone')
ind = np.arange(len(motivations_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(motivations_other)) # Set color palette
rect1 = plt.bar(ind,motivations_other,width,color=my_colors,align='center')
plt.savefig("pdf/Q027-MakerMotiviMaking02.pdf") # Save pdf
# Out:
# Data:
# voglio creare                                                   1
# cambiare paradigma                                              1
# voglio un lavoro che implichi totalmente l'interazione delle mie conoscenze, dei miei interessi e del mio saper fare    1
# dtype: int64
#
# Data %:
# voglio creare                                                   0.571429
# cambiare paradigma                                              0.571429
# voglio un lavoro che implichi totalmente l'interazione delle mie conoscenze, dei miei interessi e del mio saper fare    0.571429
# dtype: float64
