# %% [markdown]
# # Q027 - Quali sono le motivazioni che ti spingono a occuparti di making?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q027[SQ001] - Q027[SQ008] - Q027[other]

motivations_columns = ['Q027[SQ001]','Q027[SQ002]','Q027[SQ003]','Q027[SQ004]','Q027[SQ005]','Q027[SQ006]','Q027[SQ007]','Q027[SQ008]']
motivations_options = [u"Voglio sperimentare",u"Voglio apprendere",u"Voglio divertirmi",u"Voglio creare un nuovo prodotto/servizio o un’impresa",
u"Voglio conoscere persone",u"Voglio collaborare con altri", 
u"Voglio dedicarmi a progetti che hanno un impatto positivo sulla comunità locale",
u"Voglio trovare soluzioni alternative ai modelli di consumo vigenti"]

motivations = data[motivations_columns]
motivations.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
motivations_other = data['Q027[other]'].str.lower().value_counts()
# Out:
# -c:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#motivations[0:4]

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Gather data
motivations_b = {}
for k,i in enumerate(motivations_columns):
    motivations_b[k] = motivations[i].value_counts(dropna=False)
    print "Data:",motivations_options[k].encode('utf-8')
    print motivations_b[k]
    print
    print "Data %:",motivations_options[k].encode('utf-8')
    print motivations[i].value_counts(normalize=True,dropna=False)*100
    print

# %%
# Save+show the output to a text file
# %save Q027-MakerMotiviMaking01.py str(output)
shutil.move("Q027-MakerMotiviMaking01.py", "text/Q027-MakerMotiviMaking01.txt")
# Out:
# The following commands were written to file `Q027-MakerMotiviMaking01.py`:
# Data: Voglio sperimentare
# Si     100
# No      34
# NaN      0
# dtype: int64
#
# Data %: Voglio sperimentare
# Si     74.626866
# No     25.373134
# NaN     0.000000
# dtype: float64
#
# Data: Voglio apprendere
# Si     81
# No     53
# NaN     0
# dtype: int64
#
# Data %: Voglio apprendere
# Si     60.447761
# No     39.552239
# NaN     0.000000
# dtype: float64
#
# Data: Voglio divertirmi
# Si     72
# No     62
# NaN     0
# dtype: int64
#
# Data %: Voglio divertirmi
# Si     53.731343
# No     46.268657
# NaN     0.000000
# dtype: float64
#
# Data: Voglio creare un nuovo prodotto/servizio o un’impresa
# Si     87
# No     47
# NaN     0
# dtype: int64
#
# Data %: Voglio creare un nuovo prodotto/servizio o un’impresa
# Si     64.925373
# No     35.074627
# NaN     0.000000
# dtype: float64
#
# Data: Voglio conoscere persone
# No     94
# Si     40
# NaN     0
# dtype: int64
#
# ...

# %%
yes = []
no = []
nanvalue = []

for k,i in enumerate(motivations_columns):
    motivations_presents = motivations_b[k].index.tolist()
    
    # Convert NaN to "NaN"
    for o,h in enumerate(motivations_presents):
        if type(h) is float:
            motivations_presents.pop(o)
            motivations_presents.append("NaN")
    
    # Reassign new list with "NaN"
    motivations_b[k].index = motivations_presents
    
    # Check for empty values, and put a 0 instead
    if "Si" not in motivations_presents:
        yes.append(0)
    if "No" not in motivations_presents:
        no.append(0)
    if "NaN" not in motivations_presents:
        nanvalue.append(0)
    
    for j in motivations_presents:
        if j == "Si":
            yes.append(motivations_b[k].ix["Si"])
        elif j == "No":
            no.append(motivations_b[k].ix["No"])
        elif j == "NaN":
            nanvalue.append(motivations_b[k].ix["NaN"])

# %%
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel('Motivi', fontsize=16)
plt.ylabel('Persone', fontsize=16)
plt.title('Quali sono le motivazioni che ti spingono a occuparti di making?', fontsize=18, y=1.02)
plt.xticks(range(len(motivations_options)+1),motivations_options,rotation=90)
ind = np.arange(len(motivations_columns))   # the x locations for the groups
width = 0.35                              # the width of the bars

my_colors = seaborn.color_palette("Set1", 3) # Set color palette
rect1 = plt.bar(ind,yes,width,color=my_colors[0],align='center') # Plot Yes
rect2 = plt.bar(ind+width,no,width,color=my_colors[1],align='center') # Plot No
rect3 = plt.bar(ind+width*2,nanvalue,width,color=my_colors[2],align='center') # Plot NaN
plt.legend( (rect1, rect2, rect3), ('Si', 'No', 'NaN') )
plt.savefig("svg/Q027-MakerMotiviMaking01.svg")
plt.savefig("png/Q027-MakerMotiviMaking01.png")
plt.savefig("pdf/Q027-MakerMotiviMaking01.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Get "other" data
motivations_other = data["Q027[other]"].str.lower().value_counts()
print "Data:"
print motivations_other
print ""
print "Data %:"
print data["Q027[other]"].str.lower().value_counts(normalize=True) * 100

# %%
# Save+show the output to a text file
# %save Q027-MakerMotiviMaking02.py str(output)
shutil.move("Q027-MakerMotiviMaking02.py", "text/Q027-MakerMotiviMaking02.txt")
# Out:
# The following commands were written to file `Q027-MakerMotiviMaking02.py`:
# Data:
# voglio creare                                                   1
# cambiare paradigma                                              1
# adoro le sfide ... almeno di questo tipo                        1
# per promuovere le mie competenze progettuali come architetto    1
# fame di conoscenza                                              1
# voglio un lavoro che implichi totalmente l'interazione delle mie conoscenze, dei miei interessi e del mio saper fare    1
# mettermi alla prova                                             1
# dtype: int64
#
# Data %:
# voglio creare                                                   0.746269
# cambiare paradigma                                              0.746269
# adoro le sfide ... almeno di questo tipo                        0.746269
# per promuovere le mie competenze progettuali come architetto    0.746269
# ...

# %%
# Plot bar
plt.figure(figsize=(8,6))
plt.title('Quali sono le motivazioni che ti spingono a occuparti di making? Altro', fontsize=18, y=1.02)
plt.xticks(range(len(motivations_other.index)),motivations_other.index,rotation=90)
plt.xlabel('Motivi', fontsize=16)
plt.ylabel('Persone', fontsize=16)
ind = np.arange(len(motivations_other))   # the x locations for the groups
width = 0.35                       # the width of the bars

my_colors = seaborn.color_palette("husl", len(motivations_other)) # Set color palette
rect1 = plt.bar(ind,motivations_other,width,color=my_colors,align='center')
plt.savefig("svg/Q027-MakerMotiviMaking02.svg")
plt.savefig("png/Q027-MakerMotiviMaking02.png")
plt.savefig("pdf/Q027-MakerMotiviMaking02.pdf")
