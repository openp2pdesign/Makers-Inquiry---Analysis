# %% [markdown]
# # Q043 - Come vendi i tuoi prodotti?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/results-makers-40.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Range: Q043[SQ001] - Q043[SQ006] - Q039[other]

sale_columns = ['Q043[SQ001]','Q043[SQ002]','Q043[SQ003]','Q043[SQ004]','Q043[SQ005]','Q043[SQ006]']
sale_options = ['Fiere',
                  'Mostre-mercato',
                  'Personal marketplace',
                  'Piattaforme e-commerce',
                  'Passaparola',
                  'Negozio (anche temporary shop)']
sale = data[sale_columns]
sale.replace(u'Sì', 'Si', inplace=True) # Get rid of accented characters 
sale_other = data['Q043[other]'].str.lower().value_counts()
# Out:
# -c:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#sale[0:4]

# %% [markdown]
# ## Combinations...

# %%
# Create all the possible combinations from the main options
# See http://stackoverflow.com/questions/17176887/python-get-all-permutation-of-a-list-w-o-repetitions

import itertools 

all_combinations = {}
all_combinations_columns = []

for i in range(1, len(sale_columns)+1):
    comb = list(itertools.combinations(sale_columns, i))
    for k in comb:
        # Each combination
        all_combinations[k] = {}
        all_combinations[k]["col_list"] = list(k)
        # Build the string and boolean list of each combination
        comb_list = []
        comb_bool_list = []
        # Put default False value
        for l in sale_columns:
            comb_bool_list.append(False)
        for j in k:
            pos = sale_columns.index(j) # Get position
            comb_list.append(sale_options[pos])
            comb_bool_list[pos] = True
        all_combinations[k]["list"] = comb_list
        all_combinations[k]["bool_list"] = comb_bool_list
        all_combinations[k]["str"] = ", ".join(comb_list)

# %%
# Check which combinations correspond each row
str_values = []
for i in sale.index:
    current_bool_list = list(sale.ix[i].isin(["Si"]))
    for i in all_combinations:
        if current_bool_list == all_combinations[i]["bool_list"]:
            str_values.append(all_combinations[i]["str"])

# %%
# Add combination column
sale["Combination"] = pd.Series(str_values)
# Out:
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Gather data
resulting_combinations = sale["Combination"].value_counts(dropna=False)
resulting_combinations_percentage = sale["Combination"].value_counts(normalize=True,dropna=False)*100

# %%
# Plotting the first 10 values of the most popular combinations
resulting_combinations[0:10].plot(kind='bar',figsize=(20,10),rot=90)
plt.title(u"Come vendi i tuoi prodotti? Combinazioni", fontsize=18, y=1.02)
plt.ylabel("Persone", fontsize=16)
plt.xlabel("Combinazioni", fontsize=16)
plt.savefig("svg/Q043-Combinazioni.svg")
plt.savefig("png/Q043-Combinazioni.png")
plt.savefig("pdf/Q043-Combinazioni.pdf")

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
# Data of the combinations
print "Data:"
print resulting_combinations
print
# Data of the combinations: percentage
print "Data %:"
print resulting_combinations_percentage

# %%
# Save+show the output to a text file
# %save Q043-Combinazioni.py str(output)
shutil.move("Q043-Combinazioni.py", "text/Q043-Combinazioni.txt")
# Out:
# The following commands were written to file `Q043-Combinazioni.py`:
# Data:
# NaN                                                             37
# Passaparola                                                     13
# Piattaforme e-commerce                                          10
# Fiere, Mostre-mercato, Personal marketplace, Piattaforme e-commerce, Passaparola, Negozio (anche temporary shop)     5
# Mostre-mercato                                                   5
# Mostre-mercato, Piattaforme e-commerce, Negozio (anche temporary shop)     5
# Fiere, Mostre-mercato, Passaparola, Negozio (anche temporary shop)     4
# Personal marketplace, Piattaforme e-commerce                     3
# Fiere, Mostre-mercato, Piattaforme e-commerce, Passaparola       3
# Fiere                                                            3
# Piattaforme e-commerce, Passaparola, Negozio (anche temporary shop)     3
# ...
